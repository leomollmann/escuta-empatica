# %%
import nltk

nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /Users/leonardoscholler/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
texts = []

for i in range(1,24):
    with open(f'../dados/synthetic_chats/{i}.txt', 'r') as file:
        texts.append(file.read())

texts
# Out:
# ["- I just finished a really good book, it was so captivating.\n- That's awesome! What was the book about?\n- It was a mystery thriller with a plot twist I never saw coming.\n- I love when books surprise me like that. It's such a good feeling.\n- Definitely, it keeps you on your toes. Have you read any good books lately?\n- Not recently, I've been so busy with work that I haven't had much time for reading.\n- I totally get that, sometimes life just gets in the way of our hobbies.\n- Yeah, but it's important to make time for things we enjoy too.\n- You're right, I need to prioritize some me-time soon.\n- You deserve it! What's something you like to do for yourself when you have free time?\n- I love going for long walks in nature, it really helps me clear my mind.\n- That sounds so relaxing. I should try that sometime.\n- You definitely should, it's so refreshing. Let me know if you want to join me sometime.\n- I'd love to, thanks for the invite. We should plan a walk soon.\n- Absolutely, just let me know when you're free. It'll be great to catch up and relax.\n- Sounds like a plan! I'll reach out to you soon so we can set a date.\n- Looking forward to it. Take care and have a great day!\n- You too, talk to you soon!",
#  "- I had the best day at work today, I got a promotion!\n- That's awesome, I'm so happy for you! You deserve it.\n- Thank you! It's been a long time coming, but I finally made it.\n- Hard work pays off, right?\n- Definitely! What about you, how's everything going on your end?\n- Not as great... I've been feeling a bit overwhelmed with everything lately.\n- I'm sorry to hear that, anything you want to talk about?\n- Thanks, I appreciate it. I think I just need some time to relax and unwind.\n- That sounds like a good idea, self-care is important.\n- Yeah, I might take a mini vacation or something to clear my mind.\n- That sounds like a great plan, a change of scenery can do wonders.\n- Absolutely. Maybe go somewhere peaceful and quiet, away from the chaos.\n- That sounds perfect, where do you have in mind?\n- I've been wanting to visit the mountains for a while, just to disconnect and recharge.\n- That sounds amazing, I hope you have a wonderful time.\n- Thank you, I'll make sure to make the most of it.\n- You definitely deserve some time for yourself. Enjoy the tranquility of the mountains.\n- Thanks, I will. It's always good to take a step back and reset.\n- Definitely, take care of yourself and have a great trip.\n- I will, thanks for listening and for your kind words. It means a lot.\n- Anytime, that's what friends are for. Safe travels and take care!",
#  "- I just got a promotion at work! I'm so excited!\n- That's amazing! Congratulations! What will your new role be?\n- Thank you! I'll be a team lead in the marketing department.\n- That's really impressive. You worked hard for that, I'm sure.\n- Yeah, it's been a lot of long days and late nights, but it was all worth it.\n- I'm really happy for you. You deserve it.\n- Thanks, I appreciate that. I'm just a little nervous about the added responsibilities.\n- Don't worry, you'll do great. You have the skills and experience for it.\n- You're right, I can do this. Thanks for the pep talk.\n- Anytime! And if you ever need help, I'm here for you.\n- That means a lot to me. I'm lucky to have a supportive friend like you.\n- We've got each other's backs. I know you'll excel in your new role.\n- Thanks for the vote of confidence. I'm feeling more ready to take on this challenge now.\n- You've got this! I can't wait to see all the amazing things you'll accomplish in your new position.",
#  "- I went to the beach yesterday, it was so relaxing.\n- That sounds lovely! I wish I could have joined you.\n- Yeah, it was nice to just unwind and feel the sun on my skin.\n- I could really use a day like that, work has been so stressful lately.\n- I hear you, work has been overwhelming for me too.\n- Hopefully things will slow down soon for both of us.\n- I hope so, I need a break.\n- Me too, maybe we can plan a weekend getaway or something.\n- That sounds like a great idea, we both deserve some time off.\n- Definitely, we can start looking into it and plan something fun.\n- I'm looking forward to it, it will be nice to have something to look forward to.\n- Agreed, let's make it happen and take a well-deserved break.\n- Absolutely, we deserve it. Can't wait to relax and have some fun.",
#  "- I just finished watching a really good movie last night.\n- Oh yeah? What was it about?\n- It was a thriller about a detective trying to solve a murder mystery.\n- Sounds interesting, I'll have to check it out.\n- You should, it kept me on the edge of my seat the whole time.\n- I love movies like that, really gets your heart pounding.\n- Definitely, I couldn't stop thinking about it after it ended.\n- It's always great when a movie leaves a lasting impression.\n- I agree, it's what makes a movie truly memorable.\n- Do you have any other recommendations for movies like that?\n- I have a few in mind, we should plan a movie night soon.\n- That sounds like a fantastic idea, I'm in!\n- Awesome, let's make it happen next weekend.\n- Sounds like a plan, can't wait.",
#  "- I had a really rough day at work today, everything seemed to go wrong.\n- I'm sorry to hear that, it must have been really stressful.\n- Yeah, but at least it's over now.\n- That's true, hopefully tomorrow will be better.\n- I hope so. Do you have any plans for the weekend?\n- Not really, just going to relax and catch up on some reading.\n- Sounds nice. I'm actually going out of town for the weekend.\n- Oh, that sounds fun! Where are you going?\n- I'm going to visit my parents, it's been a while since I've seen them.\n- That's great, I'm sure they'll be happy to see you.\n- Yeah, I hope so. It'll be nice to spend some time with them.\n- Well, I hope you have a safe trip and enjoy your time with your parents.\n- Thank you, I appreciate that. Have a good weekend too.\n- Thanks, talk to you soon.",
#  "- I had a really great time at the concert last night.\n- That's awesome! Who did you see?\n- I went to see my favorite band, they were amazing!\n- I'm so jealous, I've always wanted to see them live.\n- You should definitely try to catch them next time they come around.\n- I'll keep an eye out for their tour dates, thanks for the tip.\n- No problem, I love sharing good music with friends.\n- Me too, we should go to a concert together sometime.\n- That would be so much fun, let's make it happen.\n- Definitely, I'll start looking for upcoming shows.\n- Sounds like a plan, can't wait to rock out with you.\n- It's going to be epic, looking forward to it.\n- Me too, let's make it a night to remember.",
#  "- I just got a promotion at work, I'm so excited!\n- That's amazing news! Congrats, you must be thrilled.\n- Thank you! I've been working really hard for this.\n- I can imagine, it's so well-deserved.\n- I appreciate that. It's been quite a journey to get here.\n- I bet! What are you planning to do to celebrate?\n- I'm thinking of going out for a nice dinner with my family.\n- That sounds perfect. What's your favorite restaurant?\n- There's this Italian place downtown that we love.\n- Oh, I know the one! The food is delicious there.\n- Definitely! We always have a great time when we go.\n- Well, enjoy your celebration dinner! You deserve it.\n- Thank you so much, I really appreciate your kind words.\n- Anytime! Let's plan to catch up next week and you can tell me all about it.\n- Absolutely, I would love that. Thanks again for your support.\n- Of course, talk to you soon!",
#  "- I had a great time at the party last night, the music was amazing.\n- I wish I could have gone, but I had to work late last night.\n- That's a bummer, maybe next time you can join us.\n- Definitely, I need a fun night out.\n- We missed you on the dance floor, it was so much fun.\n- I'm sure it was, I heard it was a blast.\n- You should come to the next one, it's happening next Friday.\n- I'll check my schedule, but I think I can make it.\n- Awesome, it's going to be even better than last night.\n- I can't wait, I need a night of dancing and fun.\n- It's a date then, see you next Friday at the party.\n- Sounds good, looking forward to it.",
#  "- I just found out I got a promotion at work, I'm so excited!\n- That's amazing news! Congratulations, you definitely deserve it.\n- Thanks so much! I've been working really hard for this opportunity.\n- I can imagine, all your dedication paid off.\n- It really did, I can't wait to start with my new responsibilities.\n- I bet you're going to excel in your new role.\n- I hope so, it's definitely a challenge I'm ready to take on.\n- I have no doubt you'll succeed, you're a hard worker and a quick learner.\n- Aw, thanks for the encouragement, I appreciate it.\n- Of course, anytime. I'm really happy for you.\n- Thanks, it means a lot to have your support.\n- Anytime, let me know if you need any help adjusting to your new position.\n- I will, thank you so much. I'm really grateful for our friendship.\n- Me too, cheers to your new promotion!",
#  "- I just got a promotion at work, I'm really excited!\n- That's amazing, congratulations! You've been working so hard for this.\n- Thank you! Yeah, it feels really good to see my efforts paying off.\n- I'm happy for you. Do you have any plans to celebrate?\n- Not yet, but I'm thinking of going out for dinner with some friends this weekend.\n- Sounds like a fun time. Where are you thinking of going?\n- I'm not sure yet, maybe that new Italian restaurant downtown.\n- Oh, I've heard great things about that place. I hope you have a great time.\n- Thank you, I'm really looking forward to it.\n- You deserve it. Enjoy celebrating your success!\n- Thanks, I will. It's nice to have something positive to focus on for a change.\n- Absolutely, you've earned it. Keep up the good work.\n- I will, thanks for being so supportive. It means a lot.\n- Anytime! I'm here for you. Let's catch up soon and you can tell me all about your celebration.\n- Definitely, I'd love that. Thanks again, you're a great friend.\n- You're welcome, anytime. Enjoy your celebration and talk to you soon.",
#  "- I just got a promotion at work, I'm so excited!\n- That's amazing, congratulations! You've been working so hard for it.\n- Thank you! It's been a long road, but I finally made it.\n- I'm really happy for you. How are you planning to celebrate?\n- I haven't thought about it yet, maybe a nice dinner with my family.\n- That sounds lovely. You definitely deserve to treat yourself.\n- Yes, it's been a tough journey but it's all worth it now.\n- Absolutely. Hard work pays off in the end.\n- I'm just glad to see my efforts finally being recognized.\n- You deserve every bit of it. Your dedication is truly inspiring.\n- Thank you so much for your kind words, it means a lot.\n- You're welcome. I'm always here to support you.\n- I really appreciate that. It's great to have friends like you by my side.",
#  "- I just got a promotion at work, I'm so excited!\n- That's amazing, congratulations! You've been working so hard for it.\n- Thank you! It feels really rewarding to see my efforts pay off.\n- I bet it does. So, with the promotion, do you think you'll have to work longer hours?\n- Actually, no. My boss assured me that I can maintain a good work-life balance.\n- That's great to hear. You deserve to enjoy the perks of your promotion.\n- Definitely. It's important to have time for myself and my loved ones.\n- Speaking of which, any plans for the weekend to celebrate?\n- Yes, my friends are throwing a small party for me tomorrow night.\n- That sounds like a lot of fun. I'll make sure to bring a good bottle of wine to toast to your success.\n- That would be lovely. I'm looking forward to spending time with everyone.\n- Well, enjoy your celebration. You deserve it!\n- Thanks, I appreciate your support. Have a great weekend too!",
#  "- I just got a promotion at work, I'm so excited!\n- That's awesome! Congratulations, you must be really proud of yourself.\n- Thank you! I've been working so hard for it.\n- Hard work pays off. Are you going to celebrate this weekend?\n- Definitely! I'm planning to go out for dinner with some friends.\n- Sounds fun! Where are you thinking of going?\n- I was thinking of trying that new Italian restaurant downtown.\n- I've heard great things about it. What day are you planning to go?\n- Saturday night, around 7 PM. Would you like to join us?\n- I would love to, but unfortunately I already have plans that evening.\n- That's okay, maybe next time. I'll let you know how it goes.\n- Please do! Have a great time celebrating, you deserve it.\n- Thanks, I appreciate that. Hopefully we can catch up soon.",
#  "- I had a really tough day at work today, everything seemed to go wrong.\n- I'm sorry to hear that, sometimes work can be really stressful.\n- Yeah, I just feel like I can't catch a break lately.\n- Have you tried taking some time off to relax and recharge?\n- I wish I could, but I have so much on my plate right now.\n- Maybe just taking a short break or doing something you enjoy could help.\n- That's a good idea. I might go for a hike this weekend to clear my mind.\n- That sounds like a great idea, nature always helps me feel better.\n- It really does. I think I just need some time away from all the stress.\n- Well, I hope you have a great hike and come back feeling refreshed.\n- Thank you, I appreciate that. Sometimes just getting outside can make all the difference.\n- Absolutely, nature has a way of bringing us back to center. Just remember to take care of yourself.",
#  "- I can't believe what happened to me yesterday, my car broke down on the highway and I had to wait hours for a tow truck.\n- Oh no, that sounds like a nightmare. Are you okay now?\n- Yeah, thankfully I'm fine but it was definitely a stressful situation.\n- Well, at least you weren't hurt. It's always a scary experience when your car breaks down.\n- Definitely. Have you ever had a similar experience?\n- Thankfully not on the highway, but I have had my fair share of car troubles in the past.\n- It's always unexpected and inconvenient when it happens.\n- For sure, but it's just a part of life I guess. We have to deal with these things as they come.\n- That's true. Life throws us curveballs sometimes, we just have to roll with the punches.\n- Exactly. It's all about staying positive and finding a solution to whatever comes our way.\n- That's a good attitude to have. Well, I'm glad you're okay now after your car troubles.\n- Thank you, I appreciate it. It's nice to have friends who are there for support during tough times.\n- Of course, that's what friends are for. I'm always here for you if you need anything.\n- Thanks, I'm lucky to have you as a friend. Let's grab a coffee sometime soon to catch up.\n- That sounds like a plan. Let's set a date, I could use some good company and caffeine.\n- Perfect, looking forward to it. Have a good day!\n- You too, take care!",
#  "- Just got a promotion at work, feeling really happy about it.\n- That's fantastic news! Congratulations. You've been working really hard for it.\n- Thank you! It's been a long journey but definitely worth it in the end.\n- I'm so happy to hear that. It's always great to see hard work pay off.\n- Definitely. How about you, anything exciting happening in your life?\n- Not really, just dealing with some personal stuff. But it's nothing I can't handle.\n- I'm here for you if you need to talk about it. Don't hesitate to reach out.\n- Thanks, I appreciate that. It means a lot to me.\n- Anytime, that's what friends are for. We'll get through this together.\n- You're right. Having a good support system makes all the difference.\n- Absolutely. We're in this together, through the good and the bad times.\n- I'm grateful to have you as a friend. Your support means everything to me.\n- The feeling is mutual. We'll always have each other's backs.\n- Thank you, I needed to hear that today.\n- Anytime, friend. We're in this journey of life together.",
#  "- I had a really rough day at work today, everything seemed to go wrong.\n- I'm sorry to hear that. Bad days happen to everyone, hopefully tomorrow will be better.\n- I hope so too. At least I have a long weekend coming up, so it will be a nice break.\n- That's great! Any plans for the long weekend?\n- Not really, just planning to relax at home and catch up on some reading. What about you?\n- I'm thinking of going on a short road trip with some friends. It should be a fun time.\n- Sounds like a great idea. Where are you guys planning to go?\n- We're thinking of driving up to the mountains for some hiking and camping. It's always nice to get away from the city.\n- That sounds like a perfect way to unwind and disconnect for a bit. Enjoy your trip!\n- Thanks! I'll make sure to take lots of pictures. Have a relaxing long weekend at home as well.\n- Thanks, I definitely will. Take care and have a safe trip!\n- See ya.",
#  "- I had a rough day at work today, everything seemed to go wrong.\n- I'm sorry to hear that. Hopefully, tomorrow will be better for you.\n- I hope so too. How was your day?\n- It was not too bad, just the usual routine.\n- That's good to hear. It's always nice to have a calm day sometimes.\n- Definitely. Do you have any plans for the weekend?\n- Not really, just thinking of catching up on some Netflix shows. How about you?\n- I have a family gathering on Sunday, so that'll take up most of my weekend.\n- Family time is always nice. Hopefully it'll be a good get-together.\n- Yeah, I hope so too. It's been a while since we all got together.\n- Well, enjoy your time with your family. I'm sure it'll be a great day.\n- Thanks. And hopefully, you'll have a more relaxing weekend ahead. Take care!\n- You too, talk to you soon.",
#  "- I just got a promotion at work! I'm so excited.\n- That's amazing, congratulations! You've been working so hard for it.\n- Thanks! It's been a long journey but it finally paid off.\n- I'm really happy for you. You deserve it.\n- How about you, how's everything going on your end?\n- Things have been a bit tough lately, but I'm managing.\n- If you ever need to talk or vent, I'm here for you.\n- Thanks, I really appreciate that.\n- We should celebrate your promotion, maybe go out for dinner this weekend?\n- That sounds like a great idea. Let's do it on Saturday night?\n- Perfect, I'll make a reservation at your favorite restaurant.\n- You really didn't have to, but I'm looking forward to it.\n- It's the least I can do to celebrate your success.\n- I'm lucky to have a friend like you in my life.\n- Aw, you're going to make me tear up. Cheers to many more years of friendship!",
#  "- I just got a promotion at work, I'm so excited!\n- That's fantastic news, congratulations! You must be thrilled.\n- Thank you, yes, I've been working really hard for it.\n- It's great to see your efforts paying off.\n- Definitely, it feels good to be recognized.\n- You deserve it, you've been dedicated and determined.\n- Thanks, I appreciate your support.\n- Of course, I'm always rooting for you.\n- It means a lot to me, thank you.\n- You're welcome, I'm happy for you.\n- Thanks again, it's nice to have someone to share this with.\n- Anytime, that's what friends are for.",
#  "- I finally got that promotion at work I've been working towards for months!\n- That's fantastic news, congrats! I'm so happy for you.\n- Thank you! It feels like a weight has been lifted off my shoulders.\n- I can only imagine the sense of relief. You've put in so much hard work for this.\n- It's been a long journey, but it was all worth it in the end.\n- Definitely. Your dedication and perseverance really paid off.\n- It's just such a relief to finally see some progress in my career.\n- Well-deserved, my friend. You deserve all the success that's coming your way.\n- Your support means a lot to me, thank you for always being there.\n- Anytime! I'll always be here cheering you on, through the highs and the lows.\n- I appreciate that more than you know. It means the world to have friends like you.\n- Of course, we're in this together. Here's to more success and happiness in the future.\n- Cheers to that! I couldn't ask for a better friend. Thank you for everything.",
#  "- I just got a promotion at work, I am so excited!\n- That's incredible! Congratulations! You've worked so hard for it.\n- Thank you! It's been a long journey, but it finally paid off.\n- You definitely deserve it. How do you plan to celebrate?\n- I'm thinking of going out for a nice dinner with my family and close friends.\n- That sounds perfect! What's your favorite type of cuisine?\n- I love Italian food, especially pasta and pizza.\n- Same here! Nothing beats a good bowl of pasta. Do you have a favorite restaurant in mind?\n- There's this cozy little Italian place downtown that I've been wanting to try.\n- Sounds lovely! When are you planning to go there?\n- I was thinking maybe this weekend, to make it a special celebration.\n- Count me in! I'd love to join you and raise a toast to your success.\n- That would be amazing. Let's make it a night to remember.\n- Absolutely! I'm so happy for you, and I can't wait to celebrate with you.\n- Thank you for your support. It means a lot to me. Let's make it a night to remember."]

# %%
processed_texts = []
for text in texts:
    split_text = text.split('===')[0].strip().split('\n')

    # Extracting alternating messages
    intrigue_messages = split_text[::2]
    peacemaker_messages = split_text[1::2]

    # Creating schema
    result = []
    for i in range(len(intrigue_messages)):
        result.append({
            "agent": "pessoa A",
            "message": intrigue_messages[i].replace('- ', '')
        })
        if i < len(peacemaker_messages):
            result.append({
                "agent": "pessoa B",
                "message": peacemaker_messages[i].replace('- ', '')
            })
    
    print(len(result))
    processed_texts.append(result[0:12])

processed_texts
# Out:
# 18
# 21
# 14
# 13
# 14
# 14
# 13
# 16
# 12
# 14
# 16
# 13
# 13
# 13
# 12
# 17
# 15
# 12
# 13
# 15
# 12
# 13
# 15
# [[{'agent': 'pessoa A',
#    'message': 'I just finished a really good book, it was so captivating.'},
#   {'agent': 'pessoa B', 'message': "That's awesome! What was the book about?"},
#   {'agent': 'pessoa A',
#    'message': 'It was a mystery thriller with a plot twist I never saw coming.'},
#   {'agent': 'pessoa B',
#    'message': "I love when books surprise me like that. It's such a good feeling."},
#   {'agent': 'pessoa A',
#    'message': 'Definitely, it keeps you on your toes. Have you read any good books lately?'},
#   {'agent': 'pessoa B',
#    'message': "Not recently, I've been so busy with work that I haven't had much time for reading."},
#   {'agent': 'pessoa A',
#    'message': 'I totally get that, sometimes life just gets in the way of our hobbies.'},
#   {'agent': 'pessoa B',
#    'message': "Yeah, but it's important to make time for things we enjoy too."},
#   {'agent': 'pessoa A',
#    'message': "You're right, I need to prioritize some me-time soon."},
#   {'agent': 'pessoa B',
#    'message': "You deserve it! What's something you like to do for yourself when you have free time?"},
#   {'agent': 'pessoa A',
#    'message': 'I love going for long walks in nature, it really helps me clear my mind.'},
#   {'agent': 'pessoa B',
#    'message': 'That sounds so relaxing. I should try that sometime.'}],
#  [{'agent': 'pessoa A',
#    'message': 'I had the best day at work today, I got a promotion!'},
#   {'agent': 'pessoa B',
#    'message': "That's awesome, I'm so happy for you! You deserve it."},
#   {'agent': 'pessoa A',
#    'message': "Thank you! It's been a long time coming, but I finally made it."},
#   {'agent': 'pessoa B', 'message': 'Hard work pays off, right?'},
#   {'agent': 'pessoa A',
#    'message': "Definitely! What about you, how's everything going on your end?"},
#   {'agent': 'pessoa B',
#    'message': "Not as great... I've been feeling a bit overwhelmed with everything lately."},
#   {'agent': 'pessoa A',
#    'message': "I'm sorry to hear that, anything you want to talk about?"},
#   {'agent': 'pessoa B',
#    'message': 'Thanks, I appreciate it. I think I just need some time to relax and unwind.'},
#   {'agent': 'pessoa A',
#    'message': 'That sounds like a good idea, self-care is important.'},
#   {'agent': 'pessoa B',
#    'message': 'Yeah, I might take a mini vacation or something to clear my mind.'},
#   {'agent': 'pessoa A',
#    'message': 'That sounds like a great plan, a change of scenery can do wonders.'},
#   {'agent': 'pessoa B',
#    'message': 'Absolutely. Maybe go somewhere peaceful and quiet, away from the chaos.'}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work! I'm so excited!"},
#   {'agent': 'pessoa B',
#    'message': "That's amazing! Congratulations! What will your new role be?"},
#   {'agent': 'pessoa A',
#    'message': "Thank you! I'll be a team lead in the marketing department."},
#   {'agent': 'pessoa B',
#    'message': "That's really impressive. You worked hard for that, I'm sure."},
#   {'agent': 'pessoa A',
#    'message': "Yeah, it's been a lot of long days and late nights, but it was all worth it."},
#   {'agent': 'pessoa B',
#    'message': "I'm really happy for you. You deserve it."},
#   {'agent': 'pessoa A',
#    'message': "Thanks, I appreciate that. I'm just a little nervous about the added responsibilities."},
#   {'agent': 'pessoa B',
#    'message': "Don't worry, you'll do great. You have the skills and experience for it."},
#   {'agent': 'pessoa A',
#    'message': "You're right, I can do this. Thanks for the pep talk."},
#   {'agent': 'pessoa B',
#    'message': "Anytime! And if you ever need help, I'm here for you."},
#   {'agent': 'pessoa A',
#    'message': "That means a lot to me. I'm lucky to have a supportive friend like you."},
#   {'agent': 'pessoa B',
#    'message': "We've got each other's backs. I know you'll excel in your new role."}],
#  [{'agent': 'pessoa A',
#    'message': 'I went to the beach yesterday, it was so relaxing.'},
#   {'agent': 'pessoa B',
#    'message': 'That sounds lovely! I wish I could have joined you.'},
#   {'agent': 'pessoa A',
#    'message': 'Yeah, it was nice to just unwind and feel the sun on my skin.'},
#   {'agent': 'pessoa B',
#    'message': 'I could really use a day like that, work has been so stressful lately.'},
#   {'agent': 'pessoa A',
#    'message': 'I hear you, work has been overwhelming for me too.'},
#   {'agent': 'pessoa B',
#    'message': 'Hopefully things will slow down soon for both of us.'},
#   {'agent': 'pessoa A', 'message': 'I hope so, I need a break.'},
#   {'agent': 'pessoa B',
#    'message': 'Me too, maybe we can plan a weekend getaway or something.'},
#   {'agent': 'pessoa A',
#    'message': 'That sounds like a great idea, we both deserve some time off.'},
#   {'agent': 'pessoa B',
#    'message': 'Definitely, we can start looking into it and plan something fun.'},
#   {'agent': 'pessoa A',
#    'message': "I'm looking forward to it, it will be nice to have something to look forward to."},
#   {'agent': 'pessoa B',
#    'message': "Agreed, let's make it happen and take a well-deserved break."}],
#  [{'agent': 'pessoa A',
#    'message': 'I just finished watching a really good movie last night.'},
#   {'agent': 'pessoa B', 'message': 'Oh yeah? What was it about?'},
#   {'agent': 'pessoa A',
#    'message': 'It was a thriller about a detective trying to solve a murder mystery.'},
#   {'agent': 'pessoa B',
#    'message': "Sounds interesting, I'll have to check it out."},
#   {'agent': 'pessoa A',
#    'message': 'You should, it kept me on the edge of my seat the whole time.'},
#   {'agent': 'pessoa B',
#    'message': 'I love movies like that, really gets your heart pounding.'},
#   {'agent': 'pessoa A',
#    'message': "Definitely, I couldn't stop thinking about it after it ended."},
#   {'agent': 'pessoa B',
#    'message': "It's always great when a movie leaves a lasting impression."},
#   {'agent': 'pessoa A',
#    'message': "I agree, it's what makes a movie truly memorable."},
#   {'agent': 'pessoa B',
#    'message': 'Do you have any other recommendations for movies like that?'},
#   {'agent': 'pessoa A',
#    'message': 'I have a few in mind, we should plan a movie night soon.'},
#   {'agent': 'pessoa B',
#    'message': "That sounds like a fantastic idea, I'm in!"}],
#  [{'agent': 'pessoa A',
#    'message': 'I had a really rough day at work today, everything seemed to go wrong.'},
#   {'agent': 'pessoa B',
#    'message': "I'm sorry to hear that, it must have been really stressful."},
#   {'agent': 'pessoa A', 'message': "Yeah, but at least it's over now."},
#   {'agent': 'pessoa B',
#    'message': "That's true, hopefully tomorrow will be better."},
#   {'agent': 'pessoa A',
#    'message': 'I hope so. Do you have any plans for the weekend?'},
#   {'agent': 'pessoa B',
#    'message': 'Not really, just going to relax and catch up on some reading.'},
#   {'agent': 'pessoa A',
#    'message': "Sounds nice. I'm actually going out of town for the weekend."},
#   {'agent': 'pessoa B',
#    'message': 'Oh, that sounds fun! Where are you going?'},
#   {'agent': 'pessoa A',
#    'message': "I'm going to visit my parents, it's been a while since I've seen them."},
#   {'agent': 'pessoa B',
#    'message': "That's great, I'm sure they'll be happy to see you."},
#   {'agent': 'pessoa A',
#    'message': "Yeah, I hope so. It'll be nice to spend some time with them."},
#   {'agent': 'pessoa B',
#    'message': 'Well, I hope you have a safe trip and enjoy your time with your parents.'}],
#  [{'agent': 'pessoa A',
#    'message': 'I had a really great time at the concert last night.'},
#   {'agent': 'pessoa B', 'message': "That's awesome! Who did you see?"},
#   {'agent': 'pessoa A',
#    'message': 'I went to see my favorite band, they were amazing!'},
#   {'agent': 'pessoa B',
#    'message': "I'm so jealous, I've always wanted to see them live."},
#   {'agent': 'pessoa A',
#    'message': 'You should definitely try to catch them next time they come around.'},
#   {'agent': 'pessoa B',
#    'message': "I'll keep an eye out for their tour dates, thanks for the tip."},
#   {'agent': 'pessoa A',
#    'message': 'No problem, I love sharing good music with friends.'},
#   {'agent': 'pessoa B',
#    'message': 'Me too, we should go to a concert together sometime.'},
#   {'agent': 'pessoa A',
#    'message': "That would be so much fun, let's make it happen."},
#   {'agent': 'pessoa B',
#    'message': "Definitely, I'll start looking for upcoming shows."},
#   {'agent': 'pessoa A',
#    'message': "Sounds like a plan, can't wait to rock out with you."},
#   {'agent': 'pessoa B',
#    'message': "It's going to be epic, looking forward to it."}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work, I'm so excited!"},
#   {'agent': 'pessoa B',
#    'message': "That's amazing news! Congrats, you must be thrilled."},
#   {'agent': 'pessoa A',
#    'message': "Thank you! I've been working really hard for this."},
#   {'agent': 'pessoa B', 'message': "I can imagine, it's so well-deserved."},
#   {'agent': 'pessoa A',
#    'message': "I appreciate that. It's been quite a journey to get here."},
#   {'agent': 'pessoa B',
#    'message': 'I bet! What are you planning to do to celebrate?'},
#   {'agent': 'pessoa A',
#    'message': "I'm thinking of going out for a nice dinner with my family."},
#   {'agent': 'pessoa B',
#    'message': "That sounds perfect. What's your favorite restaurant?"},
#   {'agent': 'pessoa A',
#    'message': "There's this Italian place downtown that we love."},
#   {'agent': 'pessoa B',
#    'message': 'Oh, I know the one! The food is delicious there.'},
#   {'agent': 'pessoa A',
#    'message': 'Definitely! We always have a great time when we go.'},
#   {'agent': 'pessoa B',
#    'message': 'Well, enjoy your celebration dinner! You deserve it.'}],
#  [{'agent': 'pessoa A',
#    'message': 'I had a great time at the party last night, the music was amazing.'},
#   {'agent': 'pessoa B',
#    'message': 'I wish I could have gone, but I had to work late last night.'},
#   {'agent': 'pessoa A',
#    'message': "That's a bummer, maybe next time you can join us."},
#   {'agent': 'pessoa B', 'message': 'Definitely, I need a fun night out.'},
#   {'agent': 'pessoa A',
#    'message': 'We missed you on the dance floor, it was so much fun.'},
#   {'agent': 'pessoa B', 'message': "I'm sure it was, I heard it was a blast."},
#   {'agent': 'pessoa A',
#    'message': "You should come to the next one, it's happening next Friday."},
#   {'agent': 'pessoa B',
#    'message': "I'll check my schedule, but I think I can make it."},
#   {'agent': 'pessoa A',
#    'message': "Awesome, it's going to be even better than last night."},
#   {'agent': 'pessoa B',
#    'message': "I can't wait, I need a night of dancing and fun."},
#   {'agent': 'pessoa A',
#    'message': "It's a date then, see you next Friday at the party."},
#   {'agent': 'pessoa B', 'message': 'Sounds good, looking forward to it.'}],
#  [{'agent': 'pessoa A',
#    'message': "I just found out I got a promotion at work, I'm so excited!"},
#   {'agent': 'pessoa B',
#    'message': "That's amazing news! Congratulations, you definitely deserve it."},
#   {'agent': 'pessoa A',
#    'message': "Thanks so much! I've been working really hard for this opportunity."},
#   {'agent': 'pessoa B',
#    'message': 'I can imagine, all your dedication paid off.'},
#   {'agent': 'pessoa A',
#    'message': "It really did, I can't wait to start with my new responsibilities."},
#   {'agent': 'pessoa B',
#    'message': "I bet you're going to excel in your new role."},
#   {'agent': 'pessoa A',
#    'message': "I hope so, it's definitely a challenge I'm ready to take on."},
#   {'agent': 'pessoa B',
#    'message': "I have no doubt you'll succeed, you're a hard worker and a quick learner."},
#   {'agent': 'pessoa A',
#    'message': 'Aw, thanks for the encouragement, I appreciate it.'},
#   {'agent': 'pessoa B',
#    'message': "Of course, anytime. I'm really happy for you."},
#   {'agent': 'pessoa A',
#    'message': 'Thanks, it means a lot to have your support.'},
#   {'agent': 'pessoa B',
#    'message': 'Anytime, let me know if you need any help adjusting to your new position.'}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work, I'm really excited!"},
#   {'agent': 'pessoa B',
#    'message': "That's amazing, congratulations! You've been working so hard for this."},
#   {'agent': 'pessoa A',
#    'message': 'Thank you! Yeah, it feels really good to see my efforts paying off.'},
#   {'agent': 'pessoa B',
#    'message': "I'm happy for you. Do you have any plans to celebrate?"},
#   {'agent': 'pessoa A',
#    'message': "Not yet, but I'm thinking of going out for dinner with some friends this weekend."},
#   {'agent': 'pessoa B',
#    'message': 'Sounds like a fun time. Where are you thinking of going?'},
#   {'agent': 'pessoa A',
#    'message': "I'm not sure yet, maybe that new Italian restaurant downtown."},
#   {'agent': 'pessoa B',
#    'message': "Oh, I've heard great things about that place. I hope you have a great time."},
#   {'agent': 'pessoa A',
#    'message': "Thank you, I'm really looking forward to it."},
#   {'agent': 'pessoa B',
#    'message': 'You deserve it. Enjoy celebrating your success!'},
#   {'agent': 'pessoa A',
#    'message': "Thanks, I will. It's nice to have something positive to focus on for a change."},
#   {'agent': 'pessoa B',
#    'message': "Absolutely, you've earned it. Keep up the good work."}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work, I'm so excited!"},
#   {'agent': 'pessoa B',
#    'message': "That's amazing, congratulations! You've been working so hard for it."},
#   {'agent': 'pessoa A',
#    'message': "Thank you! It's been a long road, but I finally made it."},
#   {'agent': 'pessoa B',
#    'message': "I'm really happy for you. How are you planning to celebrate?"},
#   {'agent': 'pessoa A',
#    'message': "I haven't thought about it yet, maybe a nice dinner with my family."},
#   {'agent': 'pessoa B',
#    'message': 'That sounds lovely. You definitely deserve to treat yourself.'},
#   {'agent': 'pessoa A',
#    'message': "Yes, it's been a tough journey but it's all worth it now."},
#   {'agent': 'pessoa B',
#    'message': 'Absolutely. Hard work pays off in the end.'},
#   {'agent': 'pessoa A',
#    'message': "I'm just glad to see my efforts finally being recognized."},
#   {'agent': 'pessoa B',
#    'message': 'You deserve every bit of it. Your dedication is truly inspiring.'},
#   {'agent': 'pessoa A',
#    'message': 'Thank you so much for your kind words, it means a lot.'},
#   {'agent': 'pessoa B',
#    'message': "You're welcome. I'm always here to support you."}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work, I'm so excited!"},
#   {'agent': 'pessoa B',
#    'message': "That's amazing, congratulations! You've been working so hard for it."},
#   {'agent': 'pessoa A',
#    'message': 'Thank you! It feels really rewarding to see my efforts pay off.'},
#   {'agent': 'pessoa B',
#    'message': "I bet it does. So, with the promotion, do you think you'll have to work longer hours?"},
#   {'agent': 'pessoa A',
#    'message': 'Actually, no. My boss assured me that I can maintain a good work-life balance.'},
#   {'agent': 'pessoa B',
#    'message': "That's great to hear. You deserve to enjoy the perks of your promotion."},
#   {'agent': 'pessoa A',
#    'message': "Definitely. It's important to have time for myself and my loved ones."},
#   {'agent': 'pessoa B',
#    'message': 'Speaking of which, any plans for the weekend to celebrate?'},
#   {'agent': 'pessoa A',
#    'message': 'Yes, my friends are throwing a small party for me tomorrow night.'},
#   {'agent': 'pessoa B',
#    'message': "That sounds like a lot of fun. I'll make sure to bring a good bottle of wine to toast to your success."},
#   {'agent': 'pessoa A',
#    'message': "That would be lovely. I'm looking forward to spending time with everyone."},
#   {'agent': 'pessoa B',
#    'message': 'Well, enjoy your celebration. You deserve it!'}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work, I'm so excited!"},
#   {'agent': 'pessoa B',
#    'message': "That's awesome! Congratulations, you must be really proud of yourself."},
#   {'agent': 'pessoa A',
#    'message': "Thank you! I've been working so hard for it."},
#   {'agent': 'pessoa B',
#    'message': 'Hard work pays off. Are you going to celebrate this weekend?'},
#   {'agent': 'pessoa A',
#    'message': "Definitely! I'm planning to go out for dinner with some friends."},
#   {'agent': 'pessoa B',
#    'message': 'Sounds fun! Where are you thinking of going?'},
#   {'agent': 'pessoa A',
#    'message': 'I was thinking of trying that new Italian restaurant downtown.'},
#   {'agent': 'pessoa B',
#    'message': "I've heard great things about it. What day are you planning to go?"},
#   {'agent': 'pessoa A',
#    'message': 'Saturday night, around 7 PM. Would you like to join us?'},
#   {'agent': 'pessoa B',
#    'message': 'I would love to, but unfortunately I already have plans that evening.'},
#   {'agent': 'pessoa A',
#    'message': "That's okay, maybe next time. I'll let you know how it goes."},
#   {'agent': 'pessoa B',
#    'message': 'Please do! Have a great time celebrating, you deserve it.'}],
#  [{'agent': 'pessoa A',
#    'message': 'I had a really tough day at work today, everything seemed to go wrong.'},
#   {'agent': 'pessoa B',
#    'message': "I'm sorry to hear that, sometimes work can be really stressful."},
#   {'agent': 'pessoa A',
#    'message': "Yeah, I just feel like I can't catch a break lately."},
#   {'agent': 'pessoa B',
#    'message': 'Have you tried taking some time off to relax and recharge?'},
#   {'agent': 'pessoa A',
#    'message': 'I wish I could, but I have so much on my plate right now.'},
#   {'agent': 'pessoa B',
#    'message': 'Maybe just taking a short break or doing something you enjoy could help.'},
#   {'agent': 'pessoa A',
#    'message': "That's a good idea. I might go for a hike this weekend to clear my mind."},
#   {'agent': 'pessoa B',
#    'message': 'That sounds like a great idea, nature always helps me feel better.'},
#   {'agent': 'pessoa A',
#    'message': 'It really does. I think I just need some time away from all the stress.'},
#   {'agent': 'pessoa B',
#    'message': 'Well, I hope you have a great hike and come back feeling refreshed.'},
#   {'agent': 'pessoa A',
#    'message': 'Thank you, I appreciate that. Sometimes just getting outside can make all the difference.'},
#   {'agent': 'pessoa B',
#    'message': 'Absolutely, nature has a way of bringing us back to center. Just remember to take care of yourself.'}],
#  [{'agent': 'pessoa A',
#    'message': "I can't believe what happened to me yesterday, my car broke down on the highway and I had to wait hours for a tow truck."},
#   {'agent': 'pessoa B',
#    'message': 'Oh no, that sounds like a nightmare. Are you okay now?'},
#   {'agent': 'pessoa A',
#    'message': "Yeah, thankfully I'm fine but it was definitely a stressful situation."},
#   {'agent': 'pessoa B',
#    'message': "Well, at least you weren't hurt. It's always a scary experience when your car breaks down."},
#   {'agent': 'pessoa A',
#    'message': 'Definitely. Have you ever had a similar experience?'},
#   {'agent': 'pessoa B',
#    'message': 'Thankfully not on the highway, but I have had my fair share of car troubles in the past.'},
#   {'agent': 'pessoa A',
#    'message': "It's always unexpected and inconvenient when it happens."},
#   {'agent': 'pessoa B',
#    'message': "For sure, but it's just a part of life I guess. We have to deal with these things as they come."},
#   {'agent': 'pessoa A',
#    'message': "That's true. Life throws us curveballs sometimes, we just have to roll with the punches."},
#   {'agent': 'pessoa B',
#    'message': "Exactly. It's all about staying positive and finding a solution to whatever comes our way."},
#   {'agent': 'pessoa A',
#    'message': "That's a good attitude to have. Well, I'm glad you're okay now after your car troubles."},
#   {'agent': 'pessoa B',
#    'message': "Thank you, I appreciate it. It's nice to have friends who are there for support during tough times."}],
#  [{'agent': 'pessoa A',
#    'message': 'Just got a promotion at work, feeling really happy about it.'},
#   {'agent': 'pessoa B',
#    'message': "That's fantastic news! Congratulations. You've been working really hard for it."},
#   {'agent': 'pessoa A',
#    'message': "Thank you! It's been a long journey but definitely worth it in the end."},
#   {'agent': 'pessoa B',
#    'message': "I'm so happy to hear that. It's always great to see hard work pay off."},
#   {'agent': 'pessoa A',
#    'message': 'Definitely. How about you, anything exciting happening in your life?'},
#   {'agent': 'pessoa B',
#    'message': "Not really, just dealing with some personal stuff. But it's nothing I can't handle."},
#   {'agent': 'pessoa A',
#    'message': "I'm here for you if you need to talk about it. Don't hesitate to reach out."},
#   {'agent': 'pessoa B',
#    'message': 'Thanks, I appreciate that. It means a lot to me.'},
#   {'agent': 'pessoa A',
#    'message': "Anytime, that's what friends are for. We'll get through this together."},
#   {'agent': 'pessoa B',
#    'message': "You're right. Having a good support system makes all the difference."},
#   {'agent': 'pessoa A',
#    'message': "Absolutely. We're in this together, through the good and the bad times."},
#   {'agent': 'pessoa B',
#    'message': "I'm grateful to have you as a friend. Your support means everything to me."}],
#  [{'agent': 'pessoa A',
#    'message': 'I had a really rough day at work today, everything seemed to go wrong.'},
#   {'agent': 'pessoa B',
#    'message': "I'm sorry to hear that. Bad days happen to everyone, hopefully tomorrow will be better."},
#   {'agent': 'pessoa A',
#    'message': 'I hope so too. At least I have a long weekend coming up, so it will be a nice break.'},
#   {'agent': 'pessoa B',
#    'message': "That's great! Any plans for the long weekend?"},
#   {'agent': 'pessoa A',
#    'message': 'Not really, just planning to relax at home and catch up on some reading. What about you?'},
#   {'agent': 'pessoa B',
#    'message': "I'm thinking of going on a short road trip with some friends. It should be a fun time."},
#   {'agent': 'pessoa A',
#    'message': 'Sounds like a great idea. Where are you guys planning to go?'},
#   {'agent': 'pessoa B',
#    'message': "We're thinking of driving up to the mountains for some hiking and camping. It's always nice to get away from the city."},
#   {'agent': 'pessoa A',
#    'message': 'That sounds like a perfect way to unwind and disconnect for a bit. Enjoy your trip!'},
#   {'agent': 'pessoa B',
#    'message': "Thanks! I'll make sure to take lots of pictures. Have a relaxing long weekend at home as well."},
#   {'agent': 'pessoa A',
#    'message': 'Thanks, I definitely will. Take care and have a safe trip!'},
#   {'agent': 'pessoa B', 'message': 'See ya.'}],
#  [{'agent': 'pessoa A',
#    'message': 'I had a rough day at work today, everything seemed to go wrong.'},
#   {'agent': 'pessoa B',
#    'message': "I'm sorry to hear that. Hopefully, tomorrow will be better for you."},
#   {'agent': 'pessoa A', 'message': 'I hope so too. How was your day?'},
#   {'agent': 'pessoa B',
#    'message': 'It was not too bad, just the usual routine.'},
#   {'agent': 'pessoa A',
#    'message': "That's good to hear. It's always nice to have a calm day sometimes."},
#   {'agent': 'pessoa B',
#    'message': 'Definitely. Do you have any plans for the weekend?'},
#   {'agent': 'pessoa A',
#    'message': 'Not really, just thinking of catching up on some Netflix shows. How about you?'},
#   {'agent': 'pessoa B',
#    'message': "I have a family gathering on Sunday, so that'll take up most of my weekend."},
#   {'agent': 'pessoa A',
#    'message': "Family time is always nice. Hopefully it'll be a good get-together."},
#   {'agent': 'pessoa B',
#    'message': "Yeah, I hope so too. It's been a while since we all got together."},
#   {'agent': 'pessoa A',
#    'message': "Well, enjoy your time with your family. I'm sure it'll be a great day."},
#   {'agent': 'pessoa B',
#    'message': "Thanks. And hopefully, you'll have a more relaxing weekend ahead. Take care!"}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work! I'm so excited."},
#   {'agent': 'pessoa B',
#    'message': "That's amazing, congratulations! You've been working so hard for it."},
#   {'agent': 'pessoa A',
#    'message': "Thanks! It's been a long journey but it finally paid off."},
#   {'agent': 'pessoa B',
#    'message': "I'm really happy for you. You deserve it."},
#   {'agent': 'pessoa A',
#    'message': "How about you, how's everything going on your end?"},
#   {'agent': 'pessoa B',
#    'message': "Things have been a bit tough lately, but I'm managing."},
#   {'agent': 'pessoa A',
#    'message': "If you ever need to talk or vent, I'm here for you."},
#   {'agent': 'pessoa B', 'message': 'Thanks, I really appreciate that.'},
#   {'agent': 'pessoa A',
#    'message': 'We should celebrate your promotion, maybe go out for dinner this weekend?'},
#   {'agent': 'pessoa B',
#    'message': "That sounds like a great idea. Let's do it on Saturday night?"},
#   {'agent': 'pessoa A',
#    'message': "Perfect, I'll make a reservation at your favorite restaurant."},
#   {'agent': 'pessoa B',
#    'message': "You really didn't have to, but I'm looking forward to it."}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work, I'm so excited!"},
#   {'agent': 'pessoa B',
#    'message': "That's fantastic news, congratulations! You must be thrilled."},
#   {'agent': 'pessoa A',
#    'message': "Thank you, yes, I've been working really hard for it."},
#   {'agent': 'pessoa B',
#    'message': "It's great to see your efforts paying off."},
#   {'agent': 'pessoa A',
#    'message': 'Definitely, it feels good to be recognized.'},
#   {'agent': 'pessoa B',
#    'message': "You deserve it, you've been dedicated and determined."},
#   {'agent': 'pessoa A', 'message': 'Thanks, I appreciate your support.'},
#   {'agent': 'pessoa B', 'message': "Of course, I'm always rooting for you."},
#   {'agent': 'pessoa A', 'message': 'It means a lot to me, thank you.'},
#   {'agent': 'pessoa B', 'message': "You're welcome, I'm happy for you."},
#   {'agent': 'pessoa A',
#    'message': "Thanks again, it's nice to have someone to share this with."},
#   {'agent': 'pessoa B', 'message': "Anytime, that's what friends are for."}],
#  [{'agent': 'pessoa A',
#    'message': "I finally got that promotion at work I've been working towards for months!"},
#   {'agent': 'pessoa B',
#    'message': "That's fantastic news, congrats! I'm so happy for you."},
#   {'agent': 'pessoa A',
#    'message': 'Thank you! It feels like a weight has been lifted off my shoulders.'},
#   {'agent': 'pessoa B',
#    'message': "I can only imagine the sense of relief. You've put in so much hard work for this."},
#   {'agent': 'pessoa A',
#    'message': "It's been a long journey, but it was all worth it in the end."},
#   {'agent': 'pessoa B',
#    'message': 'Definitely. Your dedication and perseverance really paid off.'},
#   {'agent': 'pessoa A',
#    'message': "It's just such a relief to finally see some progress in my career."},
#   {'agent': 'pessoa B',
#    'message': "Well-deserved, my friend. You deserve all the success that's coming your way."},
#   {'agent': 'pessoa A',
#    'message': 'Your support means a lot to me, thank you for always being there.'},
#   {'agent': 'pessoa B',
#    'message': "Anytime! I'll always be here cheering you on, through the highs and the lows."},
#   {'agent': 'pessoa A',
#    'message': 'I appreciate that more than you know. It means the world to have friends like you.'},
#   {'agent': 'pessoa B',
#    'message': "Of course, we're in this together. Here's to more success and happiness in the future."}],
#  [{'agent': 'pessoa A',
#    'message': 'I just got a promotion at work, I am so excited!'},
#   {'agent': 'pessoa B',
#    'message': "That's incredible! Congratulations! You've worked so hard for it."},
#   {'agent': 'pessoa A',
#    'message': "Thank you! It's been a long journey, but it finally paid off."},
#   {'agent': 'pessoa B',
#    'message': 'You definitely deserve it. How do you plan to celebrate?'},
#   {'agent': 'pessoa A',
#    'message': "I'm thinking of going out for a nice dinner with my family and close friends."},
#   {'agent': 'pessoa B',
#    'message': "That sounds perfect! What's your favorite type of cuisine?"},
#   {'agent': 'pessoa A',
#    'message': 'I love Italian food, especially pasta and pizza.'},
#   {'agent': 'pessoa B',
#    'message': 'Same here! Nothing beats a good bowl of pasta. Do you have a favorite restaurant in mind?'},
#   {'agent': 'pessoa A',
#    'message': "There's this cozy little Italian place downtown that I've been wanting to try."},
#   {'agent': 'pessoa B',
#    'message': 'Sounds lovely! When are you planning to go there?'},
#   {'agent': 'pessoa A',
#    'message': 'I was thinking maybe this weekend, to make it a special celebration.'},
#   {'agent': 'pessoa B',
#    'message': "Count me in! I'd love to join you and raise a toast to your success."}]]

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

sid = SentimentIntensityAnalyzer()

for text in processed_texts:
    for message in text:

        tokens = word_tokenize(message['message'].lower())
        filtered_tokens = [token for token in tokens if token not in stopwords.words('english')]

        lemmatizer = WordNetLemmatizer()
        lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

        processed_text = ' '.join(lemmatized_tokens)
        message.update(sid.polarity_scores(processed_text))

processed_texts
# Out:
# [[{'agent': 'pessoa A',
#    'message': 'I just finished a really good book, it was so captivating.',
#    'neg': 0.0,
#    'neu': 0.556,
#    'pos': 0.444,
#    'compound': 0.4927},
#   {'agent': 'pessoa B',
#    'message': "That's awesome! What was the book about?",
#    'neg': 0.0,
#    'neu': 0.313,
#    'pos': 0.687,
#    'compound': 0.6588},
#   {'agent': 'pessoa A',
#    'message': 'It was a mystery thriller with a plot twist I never saw coming.',
#    'neg': 0.0,
#    'neu': 0.811,
#    'pos': 0.189,
#    'compound': 0.1027},
#   {'agent': 'pessoa B',
#    'message': "I love when books surprise me like that. It's such a good feeling.",
#    'neg': 0.0,
#    'neu': 0.132,
#    'pos': 0.868,
#    'compound': 0.9042},
#   {'agent': 'pessoa A',
#    'message': 'Definitely, it keeps you on your toes. Have you read any good books lately?',
#    'neg': 0.0,
#    'neu': 0.472,
#    'pos': 0.528,
#    'compound': 0.6808},
#   {'agent': 'pessoa B',
#    'message': "Not recently, I've been so busy with work that I haven't had much time for reading.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa A',
#    'message': 'I totally get that, sometimes life just gets in the way of our hobbies.',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': "Yeah, but it's important to make time for things we enjoy too.",
#    'neg': 0.0,
#    'neu': 0.357,
#    'pos': 0.643,
#    'compound': 0.7351},
#   {'agent': 'pessoa A',
#    'message': "You're right, I need to prioritize some me-time soon.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': "You deserve it! What's something you like to do for yourself when you have free time?",
#    'neg': 0.0,
#    'neu': 0.396,
#    'pos': 0.604,
#    'compound': 0.7263},
#   {'agent': 'pessoa A',
#    'message': 'I love going for long walks in nature, it really helps me clear my mind.',
#    'neg': 0.0,
#    'neu': 0.373,
#    'pos': 0.627,
#    'compound': 0.8771},
#   {'agent': 'pessoa B',
#    'message': 'That sounds so relaxing. I should try that sometime.',
#    'neg': 0.0,
#    'neu': 0.484,
#    'pos': 0.516,
#    'compound': 0.4939}],
#  [{'agent': 'pessoa A',
#    'message': 'I had the best day at work today, I got a promotion!',
#    'neg': 0.0,
#    'neu': 0.527,
#    'pos': 0.473,
#    'compound': 0.6696},
#   {'agent': 'pessoa B',
#    'message': "That's awesome, I'm so happy for you! You deserve it.",
#    'neg': 0.0,
#    'neu': 0.27,
#    'pos': 0.73,
#    'compound': 0.8439},
#   {'agent': 'pessoa A',
#    'message': "Thank you! It's been a long time coming, but I finally made it.",
#    'neg': 0.0,
#    'neu': 0.682,
#    'pos': 0.318,
#    'compound': 0.4199},
#   {'agent': 'pessoa B',
#    'message': 'Hard work pays off, right?',
#    'neg': 0.583,
#    'neu': 0.417,
#    'pos': 0.0,
#    'compound': -0.2023},
#   {'agent': 'pessoa A',
#    'message': "Definitely! What about you, how's everything going on your end?",
#    'neg': 0.0,
#    'neu': 0.572,
#    'pos': 0.428,
#    'compound': 0.4574},
#   {'agent': 'pessoa B',
#    'message': "Not as great... I've been feeling a bit overwhelmed with everything lately.",
#    'neg': 0.0,
#    'neu': 0.424,
#    'pos': 0.576,
#    'compound': 0.7003},
#   {'agent': 'pessoa A',
#    'message': "I'm sorry to hear that, anything you want to talk about?",
#    'neg': 0.197,
#    'neu': 0.606,
#    'pos': 0.197,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': 'Thanks, I appreciate it. I think I just need some time to relax and unwind.',
#    'neg': 0.0,
#    'neu': 0.32,
#    'pos': 0.68,
#    'compound': 0.8176},
#   {'agent': 'pessoa A',
#    'message': 'That sounds like a good idea, self-care is important.',
#    'neg': 0.0,
#    'neu': 0.294,
#    'pos': 0.706,
#    'compound': 0.7351},
#   {'agent': 'pessoa B',
#    'message': 'Yeah, I might take a mini vacation or something to clear my mind.',
#    'neg': 0.0,
#    'neu': 0.556,
#    'pos': 0.444,
#    'compound': 0.5859},
#   {'agent': 'pessoa A',
#    'message': 'That sounds like a great plan, a change of scenery can do wonders.',
#    'neg': 0.0,
#    'neu': 0.431,
#    'pos': 0.569,
#    'compound': 0.765},
#   {'agent': 'pessoa B',
#    'message': 'Absolutely. Maybe go somewhere peaceful and quiet, away from the chaos.',
#    'neg': 0.287,
#    'neu': 0.465,
#    'pos': 0.248,
#    'compound': -0.128}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work! I'm so excited!",
#    'neg': 0.0,
#    'neu': 0.573,
#    'pos': 0.427,
#    'compound': 0.4559},
#   {'agent': 'pessoa B',
#    'message': "That's amazing! Congratulations! What will your new role be?",
#    'neg': 0.0,
#    'neu': 0.266,
#    'pos': 0.734,
#    'compound': 0.8513},
#   {'agent': 'pessoa A',
#    'message': "Thank you! I'll be a team lead in the marketing department.",
#    'neg': 0.0,
#    'neu': 0.642,
#    'pos': 0.358,
#    'compound': 0.4199},
#   {'agent': 'pessoa B',
#    'message': "That's really impressive. You worked hard for that, I'm sure.",
#    'neg': 0.144,
#    'neu': 0.346,
#    'pos': 0.51,
#    'compound': 0.6404},
#   {'agent': 'pessoa A',
#    'message': "Yeah, it's been a lot of long days and late nights, but it was all worth it.",
#    'neg': 0.0,
#    'neu': 0.594,
#    'pos': 0.406,
#    'compound': 0.4767},
#   {'agent': 'pessoa B',
#    'message': "I'm really happy for you. You deserve it.",
#    'neg': 0.0,
#    'neu': 0.429,
#    'pos': 0.571,
#    'compound': 0.6115},
#   {'agent': 'pessoa A',
#    'message': "Thanks, I appreciate that. I'm just a little nervous about the added responsibilities.",
#    'neg': 0.158,
#    'neu': 0.351,
#    'pos': 0.491,
#    'compound': 0.5849},
#   {'agent': 'pessoa B',
#    'message': "Don't worry, you'll do great. You have the skills and experience for it.",
#    'neg': 0.34,
#    'neu': 0.412,
#    'pos': 0.248,
#    'compound': -0.2235},
#   {'agent': 'pessoa A',
#    'message': "You're right, I can do this. Thanks for the pep talk.",
#    'neg': 0.0,
#    'neu': 0.58,
#    'pos': 0.42,
#    'compound': 0.4404},
#   {'agent': 'pessoa B',
#    'message': "Anytime! And if you ever need help, I'm here for you.",
#    'neg': 0.0,
#    'neu': 0.572,
#    'pos': 0.428,
#    'compound': 0.4574},
#   {'agent': 'pessoa A',
#    'message': "That means a lot to me. I'm lucky to have a supportive friend like you.",
#    'neg': 0.0,
#    'neu': 0.219,
#    'pos': 0.781,
#    'compound': 0.8658},
#   {'agent': 'pessoa B',
#    'message': "We've got each other's backs. I know you'll excel in your new role.",
#    'neg': 0.0,
#    'neu': 0.727,
#    'pos': 0.273,
#    'compound': 0.4588}],
#  [{'agent': 'pessoa A',
#    'message': 'I went to the beach yesterday, it was so relaxing.',
#    'neg': 0.0,
#    'neu': 0.484,
#    'pos': 0.516,
#    'compound': 0.4939},
#   {'agent': 'pessoa B',
#    'message': 'That sounds lovely! I wish I could have joined you.',
#    'neg': 0.0,
#    'neu': 0.306,
#    'pos': 0.694,
#    'compound': 0.7777},
#   {'agent': 'pessoa A',
#    'message': 'Yeah, it was nice to just unwind and feel the sun on my skin.',
#    'neg': 0.0,
#    'neu': 0.444,
#    'pos': 0.556,
#    'compound': 0.6124},
#   {'agent': 'pessoa B',
#    'message': 'I could really use a day like that, work has been so stressful lately.',
#    'neg': 0.274,
#    'neu': 0.497,
#    'pos': 0.229,
#    'compound': -0.1372},
#   {'agent': 'pessoa A',
#    'message': 'I hear you, work has been overwhelming for me too.',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': 'Hopefully things will slow down soon for both of us.',
#    'neg': 0.0,
#    'neu': 0.526,
#    'pos': 0.474,
#    'compound': 0.4019},
#   {'agent': 'pessoa A',
#    'message': 'I hope so, I need a break.',
#    'neg': 0.0,
#    'neu': 0.408,
#    'pos': 0.592,
#    'compound': 0.4404},
#   {'agent': 'pessoa B',
#    'message': 'Me too, maybe we can plan a weekend getaway or something.',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa A',
#    'message': 'That sounds like a great idea, we both deserve some time off.',
#    'neg': 0.0,
#    'neu': 0.377,
#    'pos': 0.623,
#    'compound': 0.765},
#   {'agent': 'pessoa B',
#    'message': 'Definitely, we can start looking into it and plan something fun.',
#    'neg': 0.0,
#    'neu': 0.4,
#    'pos': 0.6,
#    'compound': 0.7184},
#   {'agent': 'pessoa A',
#    'message': "I'm looking forward to it, it will be nice to have something to look forward to.",
#    'neg': 0.0,
#    'neu': 0.682,
#    'pos': 0.318,
#    'compound': 0.4215},
#   {'agent': 'pessoa B',
#    'message': "Agreed, let's make it happen and take a well-deserved break.",
#    'neg': 0.0,
#    'neu': 0.769,
#    'pos': 0.231,
#    'compound': 0.2732}],
#  [{'agent': 'pessoa A',
#    'message': 'I just finished watching a really good movie last night.',
#    'neg': 0.0,
#    'neu': 0.653,
#    'pos': 0.347,
#    'compound': 0.4927},
#   {'agent': 'pessoa B',
#    'message': 'Oh yeah? What was it about?',
#    'neg': 0.0,
#    'neu': 0.281,
#    'pos': 0.719,
#    'compound': 0.3736},
#   {'agent': 'pessoa A',
#    'message': 'It was a thriller about a detective trying to solve a murder mystery.',
#    'neg': 0.431,
#    'neu': 0.275,
#    'pos': 0.294,
#    'compound': -0.5423},
#   {'agent': 'pessoa B',
#    'message': "Sounds interesting, I'll have to check it out.",
#    'neg': 0.0,
#    'neu': 0.526,
#    'pos': 0.474,
#    'compound': 0.4019},
#   {'agent': 'pessoa A',
#    'message': 'You should, it kept me on the edge of my seat the whole time.',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': 'I love movies like that, really gets your heart pounding.',
#    'neg': 0.0,
#    'neu': 0.427,
#    'pos': 0.573,
#    'compound': 0.7717},
#   {'agent': 'pessoa A',
#    'message': "Definitely, I couldn't stop thinking about it after it ended.",
#    'neg': 0.0,
#    'neu': 0.466,
#    'pos': 0.534,
#    'compound': 0.5556},
#   {'agent': 'pessoa B',
#    'message': "It's always great when a movie leaves a lasting impression.",
#    'neg': 0.0,
#    'neu': 0.455,
#    'pos': 0.545,
#    'compound': 0.7184},
#   {'agent': 'pessoa A',
#    'message': "I agree, it's what makes a movie truly memorable.",
#    'neg': 0.0,
#    'neu': 0.426,
#    'pos': 0.574,
#    'compound': 0.6597},
#   {'agent': 'pessoa B',
#    'message': 'Do you have any other recommendations for movies like that?',
#    'neg': 0.0,
#    'neu': 0.444,
#    'pos': 0.556,
#    'compound': 0.3612},
#   {'agent': 'pessoa A',
#    'message': 'I have a few in mind, we should plan a movie night soon.',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': "That sounds like a fantastic idea, I'm in!",
#    'neg': 0.0,
#    'neu': 0.319,
#    'pos': 0.681,
#    'compound': 0.75}],
#  [{'agent': 'pessoa A',
#    'message': 'I had a really rough day at work today, everything seemed to go wrong.',
#    'neg': 0.279,
#    'neu': 0.721,
#    'pos': 0.0,
#    'compound': -0.4767},
#   {'agent': 'pessoa B',
#    'message': "I'm sorry to hear that, it must have been really stressful.",
#    'neg': 0.55,
#    'neu': 0.45,
#    'pos': 0.0,
#    'compound': -0.5984},
#   {'agent': 'pessoa A',
#    'message': "Yeah, but at least it's over now.",
#    'neg': 0.0,
#    'neu': 0.476,
#    'pos': 0.524,
#    'compound': 0.296},
#   {'agent': 'pessoa B',
#    'message': "That's true, hopefully tomorrow will be better.",
#    'neg': 0.0,
#    'neu': 0.192,
#    'pos': 0.808,
#    'compound': 0.8126},
#   {'agent': 'pessoa A',
#    'message': 'I hope so. Do you have any plans for the weekend?',
#    'neg': 0.0,
#    'neu': 0.408,
#    'pos': 0.592,
#    'compound': 0.4404},
#   {'agent': 'pessoa B',
#    'message': 'Not really, just going to relax and catch up on some reading.',
#    'neg': 0.0,
#    'neu': 0.557,
#    'pos': 0.443,
#    'compound': 0.4902},
#   {'agent': 'pessoa A',
#    'message': "Sounds nice. I'm actually going out of town for the weekend.",
#    'neg': 0.0,
#    'neu': 0.682,
#    'pos': 0.318,
#    'compound': 0.4215},
#   {'agent': 'pessoa B',
#    'message': 'Oh, that sounds fun! Where are you going?',
#    'neg': 0.0,
#    'neu': 0.455,
#    'pos': 0.545,
#    'compound': 0.5562},
#   {'agent': 'pessoa A',
#    'message': "I'm going to visit my parents, it's been a while since I've seen them.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': "That's great, I'm sure they'll be happy to see you.",
#    'neg': 0.0,
#    'neu': 0.284,
#    'pos': 0.716,
#    'compound': 0.8779},
#   {'agent': 'pessoa A',
#    'message': "Yeah, I hope so. It'll be nice to spend some time with them.",
#    'neg': 0.0,
#    'neu': 0.275,
#    'pos': 0.725,
#    'compound': 0.7845},
#   {'agent': 'pessoa B',
#    'message': 'Well, I hope you have a safe trip and enjoy your time with your parents.',
#    'neg': 0.0,
#    'neu': 0.213,
#    'pos': 0.787,
#    'compound': 0.8779}],
#  [{'agent': 'pessoa A',
#    'message': 'I had a really great time at the concert last night.',
#    'neg': 0.0,
#    'neu': 0.532,
#    'pos': 0.468,
#    'compound': 0.659},
#   {'agent': 'pessoa B',
#    'message': "That's awesome! Who did you see?",
#    'neg': 0.0,
#    'neu': 0.313,
#    'pos': 0.687,
#    'compound': 0.6588},
#   {'agent': 'pessoa A',
#    'message': 'I went to see my favorite band, they were amazing!',
#    'neg': 0.0,
#    'neu': 0.297,
#    'pos': 0.703,
#    'compound': 0.7959},
#   {'agent': 'pessoa B',
#    'message': "I'm so jealous, I've always wanted to see them live.",
#    'neg': 0.333,
#    'neu': 0.667,
#    'pos': 0.0,
#    'compound': -0.4588},
#   {'agent': 'pessoa A',
#    'message': 'You should definitely try to catch them next time they come around.',
#    'neg': 0.0,
#    'neu': 0.69,
#    'pos': 0.31,
#    'compound': 0.4019},
#   {'agent': 'pessoa B',
#    'message': "I'll keep an eye out for their tour dates, thanks for the tip.",
#    'neg': 0.0,
#    'neu': 0.674,
#    'pos': 0.326,
#    'compound': 0.4404},
#   {'agent': 'pessoa A',
#    'message': 'No problem, I love sharing good music with friends.',
#    'neg': 0.161,
#    'neu': 0.06,
#    'pos': 0.78,
#    'compound': 0.886},
#   {'agent': 'pessoa B',
#    'message': 'Me too, we should go to a concert together sometime.',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa A',
#    'message': "That would be so much fun, let's make it happen.",
#    'neg': 0.0,
#    'neu': 0.645,
#    'pos': 0.355,
#    'compound': 0.5106},
#   {'agent': 'pessoa B',
#    'message': "Definitely, I'll start looking for upcoming shows.",
#    'neg': 0.0,
#    'neu': 0.649,
#    'pos': 0.351,
#    'compound': 0.4019},
#   {'agent': 'pessoa A',
#    'message': "Sounds like a plan, can't wait to rock out with you.",
#    'neg': 0.0,
#    'neu': 0.706,
#    'pos': 0.294,
#    'compound': 0.3612},
#   {'agent': 'pessoa B',
#    'message': "It's going to be epic, looking forward to it.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work, I'm so excited!",
#    'neg': 0.0,
#    'neu': 0.598,
#    'pos': 0.402,
#    'compound': 0.4003},
#   {'agent': 'pessoa B',
#    'message': "That's amazing news! Congrats, you must be thrilled.",
#    'neg': 0.0,
#    'neu': 0.224,
#    'pos': 0.776,
#    'compound': 0.8858},
#   {'agent': 'pessoa A',
#    'message': "Thank you! I've been working really hard for this.",
#    'neg': 0.226,
#    'neu': 0.401,
#    'pos': 0.373,
#    'compound': 0.273},
#   {'agent': 'pessoa B',
#    'message': "I can imagine, it's so well-deserved.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa A',
#    'message': "I appreciate that. It's been quite a journey to get here.",
#    'neg': 0.0,
#    'neu': 0.597,
#    'pos': 0.403,
#    'compound': 0.4019},
#   {'agent': 'pessoa B',
#    'message': 'I bet! What are you planning to do to celebrate?',
#    'neg': 0.0,
#    'neu': 0.334,
#    'pos': 0.666,
#    'compound': 0.6114},
#   {'agent': 'pessoa A',
#    'message': "I'm thinking of going out for a nice dinner with my family.",
#    'neg': 0.0,
#    'neu': 0.641,
#    'pos': 0.359,
#    'compound': 0.4215},
#   {'agent': 'pessoa B',
#    'message': "That sounds perfect. What's your favorite restaurant?",
#    'neg': 0.0,
#    'neu': 0.309,
#    'pos': 0.691,
#    'compound': 0.7717},
#   {'agent': 'pessoa A',
#    'message': "There's this Italian place downtown that we love.",
#    'neg': 0.0,
#    'neu': 0.488,
#    'pos': 0.512,
#    'compound': 0.6369},
#   {'agent': 'pessoa B',
#    'message': 'Oh, I know the one! The food is delicious there.',
#    'neg': 0.0,
#    'neu': 0.501,
#    'pos': 0.499,
#    'compound': 0.6114},
#   {'agent': 'pessoa A',
#    'message': 'Definitely! We always have a great time when we go.',
#    'neg': 0.0,
#    'neu': 0.297,
#    'pos': 0.703,
#    'compound': 0.7959},
#   {'agent': 'pessoa B',
#    'message': 'Well, enjoy your celebration dinner! You deserve it.',
#    'neg': 0.0,
#    'neu': 0.349,
#    'pos': 0.651,
#    'compound': 0.68}],
#  [{'agent': 'pessoa A',
#    'message': 'I had a great time at the party last night, the music was amazing.',
#    'neg': 0.0,
#    'neu': 0.274,
#    'pos': 0.726,
#    'compound': 0.891},
#   {'agent': 'pessoa B',
#    'message': 'I wish I could have gone, but I had to work late last night.',
#    'neg': 0.0,
#    'neu': 0.69,
#    'pos': 0.31,
#    'compound': 0.4019},
#   {'agent': 'pessoa A',
#    'message': "That's a bummer, maybe next time you can join us.",
#    'neg': 0.295,
#    'neu': 0.455,
#    'pos': 0.25,
#    'compound': -0.1027},
#   {'agent': 'pessoa B',
#    'message': 'Definitely, I need a fun night out.',
#    'neg': 0.0,
#    'neu': 0.25,
#    'pos': 0.75,
#    'compound': 0.7184},
#   {'agent': 'pessoa A',
#    'message': 'We missed you on the dance floor, it was so much fun.',
#    'neg': 0.259,
#    'neu': 0.353,
#    'pos': 0.388,
#    'compound': 0.2732},
#   {'agent': 'pessoa B',
#    'message': "I'm sure it was, I heard it was a blast.",
#    'neg': 0.0,
#    'neu': 0.566,
#    'pos': 0.434,
#    'compound': 0.3182},
#   {'agent': 'pessoa A',
#    'message': "You should come to the next one, it's happening next Friday.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': "I'll check my schedule, but I think I can make it.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa A',
#    'message': "Awesome, it's going to be even better than last night.",
#    'neg': 0.0,
#    'neu': 0.417,
#    'pos': 0.583,
#    'compound': 0.7906},
#   {'agent': 'pessoa B',
#    'message': "I can't wait, I need a night of dancing and fun.",
#    'neg': 0.0,
#    'neu': 0.645,
#    'pos': 0.355,
#    'compound': 0.5106},
#   {'agent': 'pessoa A',
#    'message': "It's a date then, see you next Friday at the party.",
#    'neg': 0.0,
#    'neu': 0.649,
#    'pos': 0.351,
#    'compound': 0.4019},
#   {'agent': 'pessoa B',
#    'message': 'Sounds good, looking forward to it.',
#    'neg': 0.0,
#    'neu': 0.508,
#    'pos': 0.492,
#    'compound': 0.4404}],
#  [{'agent': 'pessoa A',
#    'message': "I just found out I got a promotion at work, I'm so excited!",
#    'neg': 0.0,
#    'neu': 0.65,
#    'pos': 0.35,
#    'compound': 0.4003},
#   {'agent': 'pessoa B',
#    'message': "That's amazing news! Congratulations, you definitely deserve it.",
#    'neg': 0.0,
#    'neu': 0.219,
#    'pos': 0.781,
#    'compound': 0.8932},
#   {'agent': 'pessoa A',
#    'message': "Thanks so much! I've been working really hard for this opportunity.",
#    'neg': 0.142,
#    'neu': 0.334,
#    'pos': 0.524,
#    'compound': 0.6785},
#   {'agent': 'pessoa B',
#    'message': 'I can imagine, all your dedication paid off.',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa A',
#    'message': "It really did, I can't wait to start with my new responsibilities.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': "I bet you're going to excel in your new role.",
#    'neg': 0.0,
#    'neu': 0.625,
#    'pos': 0.375,
#    'compound': 0.4588},
#   {'agent': 'pessoa A',
#    'message': "I hope so, it's definitely a challenge I'm ready to take on.",
#    'neg': 0.0,
#    'neu': 0.242,
#    'pos': 0.758,
#    'compound': 0.8126},
#   {'agent': 'pessoa B',
#    'message': "I have no doubt you'll succeed, you're a hard worker and a quick learner.",
#    'neg': 0.322,
#    'neu': 0.413,
#    'pos': 0.264,
#    'compound': 0.0772},
#   {'agent': 'pessoa A',
#    'message': 'Aw, thanks for the encouragement, I appreciate it.',
#    'neg': 0.0,
#    'neu': 0.106,
#    'pos': 0.894,
#    'compound': 0.8126},
#   {'agent': 'pessoa B',
#    'message': "Of course, anytime. I'm really happy for you.",
#    'neg': 0.0,
#    'neu': 0.5,
#    'pos': 0.5,
#    'compound': 0.6115},
#   {'agent': 'pessoa A',
#    'message': 'Thanks, it means a lot to have your support.',
#    'neg': 0.0,
#    'neu': 0.263,
#    'pos': 0.737,
#    'compound': 0.6808},
#   {'agent': 'pessoa B',
#    'message': 'Anytime, let me know if you need any help adjusting to your new position.',
#    'neg': 0.0,
#    'neu': 0.722,
#    'pos': 0.278,
#    'compound': 0.4019}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work, I'm really excited!",
#    'neg': 0.0,
#    'neu': 0.626,
#    'pos': 0.374,
#    'compound': 0.4561},
#   {'agent': 'pessoa B',
#    'message': "That's amazing, congratulations! You've been working so hard for this.",
#    'neg': 0.113,
#    'neu': 0.242,
#    'pos': 0.645,
#    'compound': 0.8221},
#   {'agent': 'pessoa A',
#    'message': 'Thank you! Yeah, it feels really good to see my efforts paying off.',
#    'neg': 0.0,
#    'neu': 0.379,
#    'pos': 0.621,
#    'compound': 0.8012},
#   {'agent': 'pessoa B',
#    'message': "I'm happy for you. Do you have any plans to celebrate?",
#    'neg': 0.0,
#    'neu': 0.213,
#    'pos': 0.787,
#    'compound': 0.8126},
#   {'agent': 'pessoa A',
#    'message': "Not yet, but I'm thinking of going out for dinner with some friends this weekend.",
#    'neg': 0.0,
#    'neu': 0.652,
#    'pos': 0.348,
#    'compound': 0.4939},
#   {'agent': 'pessoa B',
#    'message': 'Sounds like a fun time. Where are you thinking of going?',
#    'neg': 0.0,
#    'neu': 0.408,
#    'pos': 0.592,
#    'compound': 0.7003},
#   {'agent': 'pessoa A',
#    'message': "I'm not sure yet, maybe that new Italian restaurant downtown.",
#    'neg': 0.0,
#    'neu': 0.753,
#    'pos': 0.247,
#    'compound': 0.3182},
#   {'agent': 'pessoa B',
#    'message': "Oh, I've heard great things about that place. I hope you have a great time.",
#    'neg': 0.0,
#    'neu': 0.351,
#    'pos': 0.649,
#    'compound': 0.9022},
#   {'agent': 'pessoa A',
#    'message': "Thank you, I'm really looking forward to it.",
#    'neg': 0.0,
#    'neu': 0.615,
#    'pos': 0.385,
#    'compound': 0.3612},
#   {'agent': 'pessoa B',
#    'message': 'You deserve it. Enjoy celebrating your success!',
#    'neg': 0.0,
#    'neu': 0.084,
#    'pos': 0.916,
#    'compound': 0.8977},
#   {'agent': 'pessoa A',
#    'message': "Thanks, I will. It's nice to have something positive to focus on for a change.",
#    'neg': 0.0,
#    'neu': 0.301,
#    'pos': 0.699,
#    'compound': 0.8519},
#   {'agent': 'pessoa B',
#    'message': "Absolutely, you've earned it. Keep up the good work.",
#    'neg': 0.0,
#    'neu': 0.633,
#    'pos': 0.367,
#    'compound': 0.4404}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work, I'm so excited!",
#    'neg': 0.0,
#    'neu': 0.598,
#    'pos': 0.402,
#    'compound': 0.4003},
#   {'agent': 'pessoa B',
#    'message': "That's amazing, congratulations! You've been working so hard for it.",
#    'neg': 0.113,
#    'neu': 0.242,
#    'pos': 0.645,
#    'compound': 0.8221},
#   {'agent': 'pessoa A',
#    'message': "Thank you! It's been a long road, but I finally made it.",
#    'neg': 0.0,
#    'neu': 0.642,
#    'pos': 0.358,
#    'compound': 0.4199},
#   {'agent': 'pessoa B',
#    'message': "I'm really happy for you. How are you planning to celebrate?",
#    'neg': 0.0,
#    'neu': 0.274,
#    'pos': 0.726,
#    'compound': 0.8384},
#   {'agent': 'pessoa A',
#    'message': "I haven't thought about it yet, maybe a nice dinner with my family.",
#    'neg': 0.0,
#    'neu': 0.682,
#    'pos': 0.318,
#    'compound': 0.4215},
#   {'agent': 'pessoa B',
#    'message': 'That sounds lovely. You definitely deserve to treat yourself.',
#    'neg': 0.0,
#    'neu': 0.179,
#    'pos': 0.821,
#    'compound': 0.8481},
#   {'agent': 'pessoa A',
#    'message': "Yes, it's been a tough journey but it's all worth it now.",
#    'neg': 0.165,
#    'neu': 0.33,
#    'pos': 0.505,
#    'compound': 0.4767},
#   {'agent': 'pessoa B',
#    'message': 'Absolutely. Hard work pays off in the end.',
#    'neg': 0.528,
#    'neu': 0.472,
#    'pos': 0.0,
#    'compound': -0.3306},
#   {'agent': 'pessoa A',
#    'message': "I'm just glad to see my efforts finally being recognized.",
#    'neg': 0.0,
#    'neu': 0.625,
#    'pos': 0.375,
#    'compound': 0.4588},
#   {'agent': 'pessoa B',
#    'message': 'You deserve every bit of it. Your dedication is truly inspiring.',
#    'neg': 0.0,
#    'neu': 0.412,
#    'pos': 0.588,
#    'compound': 0.6908},
#   {'agent': 'pessoa A',
#    'message': 'Thank you so much for your kind words, it means a lot.',
#    'neg': 0.0,
#    'neu': 0.404,
#    'pos': 0.596,
#    'compound': 0.7096},
#   {'agent': 'pessoa B',
#    'message': "You're welcome. I'm always here to support you.",
#    'neg': 0.0,
#    'neu': 0.345,
#    'pos': 0.655,
#    'compound': 0.6908}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work, I'm so excited!",
#    'neg': 0.0,
#    'neu': 0.598,
#    'pos': 0.402,
#    'compound': 0.4003},
#   {'agent': 'pessoa B',
#    'message': "That's amazing, congratulations! You've been working so hard for it.",
#    'neg': 0.113,
#    'neu': 0.242,
#    'pos': 0.645,
#    'compound': 0.8221},
#   {'agent': 'pessoa A',
#    'message': 'Thank you! It feels really rewarding to see my efforts pay off.',
#    'neg': 0.118,
#    'neu': 0.337,
#    'pos': 0.546,
#    'compound': 0.7257},
#   {'agent': 'pessoa B',
#    'message': "I bet it does. So, with the promotion, do you think you'll have to work longer hours?",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa A',
#    'message': 'Actually, no. My boss assured me that I can maintain a good work-life balance.',
#    'neg': 0.0,
#    'neu': 0.481,
#    'pos': 0.519,
#    'compound': 0.6597},
#   {'agent': 'pessoa B',
#    'message': "That's great to hear. You deserve to enjoy the perks of your promotion.",
#    'neg': 0.0,
#    'neu': 0.407,
#    'pos': 0.593,
#    'compound': 0.8074},
#   {'agent': 'pessoa A',
#    'message': "Definitely. It's important to have time for myself and my loved ones.",
#    'neg': 0.0,
#    'neu': 0.263,
#    'pos': 0.737,
#    'compound': 0.8126},
#   {'agent': 'pessoa B',
#    'message': 'Speaking of which, any plans for the weekend to celebrate?',
#    'neg': 0.0,
#    'neu': 0.448,
#    'pos': 0.552,
#    'compound': 0.5719},
#   {'agent': 'pessoa A',
#    'message': 'Yes, my friends are throwing a small party for me tomorrow night.',
#    'neg': 0.0,
#    'neu': 0.317,
#    'pos': 0.683,
#    'compound': 0.8225},
#   {'agent': 'pessoa B',
#    'message': "That sounds like a lot of fun. I'll make sure to bring a good bottle of wine to toast to your success.",
#    'neg': 0.0,
#    'neu': 0.352,
#    'pos': 0.648,
#    'compound': 0.9287},
#   {'agent': 'pessoa A',
#    'message': "That would be lovely. I'm looking forward to spending time with everyone.",
#    'neg': 0.0,
#    'neu': 0.648,
#    'pos': 0.352,
#    'compound': 0.5859},
#   {'agent': 'pessoa B',
#    'message': 'Well, enjoy your celebration. You deserve it!',
#    'neg': 0.0,
#    'neu': 0.263,
#    'pos': 0.737,
#    'compound': 0.68}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work, I'm so excited!",
#    'neg': 0.0,
#    'neu': 0.598,
#    'pos': 0.402,
#    'compound': 0.4003},
#   {'agent': 'pessoa B',
#    'message': "That's awesome! Congratulations, you must be really proud of yourself.",
#    'neg': 0.0,
#    'neu': 0.204,
#    'pos': 0.796,
#    'compound': 0.9133},
#   {'agent': 'pessoa A',
#    'message': "Thank you! I've been working so hard for it.",
#    'neg': 0.226,
#    'neu': 0.323,
#    'pos': 0.451,
#    'compound': 0.3382},
#   {'agent': 'pessoa B',
#    'message': 'Hard work pays off. Are you going to celebrate this weekend?',
#    'neg': 0.295,
#    'neu': 0.316,
#    'pos': 0.389,
#    'compound': 0.4404},
#   {'agent': 'pessoa A',
#    'message': "Definitely! I'm planning to go out for dinner with some friends.",
#    'neg': 0.0,
#    'neu': 0.392,
#    'pos': 0.608,
#    'compound': 0.7345},
#   {'agent': 'pessoa B',
#    'message': 'Sounds fun! Where are you thinking of going?',
#    'neg': 0.0,
#    'neu': 0.455,
#    'pos': 0.545,
#    'compound': 0.5562},
#   {'agent': 'pessoa A',
#    'message': 'I was thinking of trying that new Italian restaurant downtown.',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': "I've heard great things about it. What day are you planning to go?",
#    'neg': 0.0,
#    'neu': 0.594,
#    'pos': 0.406,
#    'compound': 0.6249},
#   {'agent': 'pessoa A',
#    'message': 'Saturday night, around 7 PM. Would you like to join us?',
#    'neg': 0.0,
#    'neu': 0.515,
#    'pos': 0.485,
#    'compound': 0.5719},
#   {'agent': 'pessoa B',
#    'message': 'I would love to, but unfortunately I already have plans that evening.',
#    'neg': 0.226,
#    'neu': 0.377,
#    'pos': 0.396,
#    'compound': 0.4215},
#   {'agent': 'pessoa A',
#    'message': "That's okay, maybe next time. I'll let you know how it goes.",
#    'neg': 0.0,
#    'neu': 0.808,
#    'pos': 0.192,
#    'compound': 0.2263},
#   {'agent': 'pessoa B',
#    'message': 'Please do! Have a great time celebrating, you deserve it.',
#    'neg': 0.0,
#    'neu': 0.161,
#    'pos': 0.839,
#    'compound': 0.8858}],
#  [{'agent': 'pessoa A',
#    'message': 'I had a really tough day at work today, everything seemed to go wrong.',
#    'neg': 0.411,
#    'neu': 0.589,
#    'pos': 0.0,
#    'compound': -0.5984},
#   {'agent': 'pessoa B',
#    'message': "I'm sorry to hear that, sometimes work can be really stressful.",
#    'neg': 0.495,
#    'neu': 0.505,
#    'pos': 0.0,
#    'compound': -0.5984},
#   {'agent': 'pessoa A',
#    'message': "Yeah, I just feel like I can't catch a break lately.",
#    'neg': 0.0,
#    'neu': 0.561,
#    'pos': 0.439,
#    'compound': 0.5719},
#   {'agent': 'pessoa B',
#    'message': 'Have you tried taking some time off to relax and recharge?',
#    'neg': 0.0,
#    'neu': 0.58,
#    'pos': 0.42,
#    'compound': 0.4404},
#   {'agent': 'pessoa A',
#    'message': 'I wish I could, but I have so much on my plate right now.',
#    'neg': 0.0,
#    'neu': 0.597,
#    'pos': 0.403,
#    'compound': 0.4019},
#   {'agent': 'pessoa B',
#    'message': 'Maybe just taking a short break or doing something you enjoy could help.',
#    'neg': 0.0,
#    'neu': 0.504,
#    'pos': 0.496,
#    'compound': 0.7096},
#   {'agent': 'pessoa A',
#    'message': "That's a good idea. I might go for a hike this weekend to clear my mind.",
#    'neg': 0.0,
#    'neu': 0.56,
#    'pos': 0.44,
#    'compound': 0.6705},
#   {'agent': 'pessoa B',
#    'message': 'That sounds like a great idea, nature always helps me feel better.',
#    'neg': 0.0,
#    'neu': 0.291,
#    'pos': 0.709,
#    'compound': 0.9042},
#   {'agent': 'pessoa A',
#    'message': 'It really does. I think I just need some time away from all the stress.',
#    'neg': 0.359,
#    'neu': 0.641,
#    'pos': 0.0,
#    'compound': -0.4215},
#   {'agent': 'pessoa B',
#    'message': 'Well, I hope you have a great hike and come back feeling refreshed.',
#    'neg': 0.0,
#    'neu': 0.274,
#    'pos': 0.726,
#    'compound': 0.8625},
#   {'agent': 'pessoa A',
#    'message': 'Thank you, I appreciate that. Sometimes just getting outside can make all the difference.',
#    'neg': 0.0,
#    'neu': 0.49,
#    'pos': 0.51,
#    'compound': 0.6369},
#   {'agent': 'pessoa B',
#    'message': 'Absolutely, nature has a way of bringing us back to center. Just remember to take care of yourself.',
#    'neg': 0.0,
#    'neu': 0.714,
#    'pos': 0.286,
#    'compound': 0.4939}],
#  [{'agent': 'pessoa A',
#    'message': "I can't believe what happened to me yesterday, my car broke down on the highway and I had to wait hours for a tow truck.",
#    'neg': 0.203,
#    'neu': 0.797,
#    'pos': 0.0,
#    'compound': -0.4215},
#   {'agent': 'pessoa B',
#    'message': 'Oh no, that sounds like a nightmare. Are you okay now?',
#    'neg': 0.0,
#    'neu': 0.405,
#    'pos': 0.595,
#    'compound': 0.5267},
#   {'agent': 'pessoa A',
#    'message': "Yeah, thankfully I'm fine but it was definitely a stressful situation.",
#    'neg': 0.223,
#    'neu': 0.135,
#    'pos': 0.642,
#    'compound': 0.6369},
#   {'agent': 'pessoa B',
#    'message': "Well, at least you weren't hurt. It's always a scary experience when your car breaks down.",
#    'neg': 0.212,
#    'neu': 0.464,
#    'pos': 0.323,
#    'compound': 0.1719},
#   {'agent': 'pessoa A',
#    'message': 'Definitely. Have you ever had a similar experience?',
#    'neg': 0.0,
#    'neu': 0.526,
#    'pos': 0.474,
#    'compound': 0.4019},
#   {'agent': 'pessoa B',
#    'message': 'Thankfully not on the highway, but I have had my fair share of car troubles in the past.',
#    'neg': 0.208,
#    'neu': 0.231,
#    'pos': 0.562,
#    'compound': 0.5574},
#   {'agent': 'pessoa A',
#    'message': "It's always unexpected and inconvenient when it happens.",
#    'neg': 0.375,
#    'neu': 0.625,
#    'pos': 0.0,
#    'compound': -0.34},
#   {'agent': 'pessoa B',
#    'message': "For sure, but it's just a part of life I guess. We have to deal with these things as they come.",
#    'neg': 0.0,
#    'neu': 0.753,
#    'pos': 0.247,
#    'compound': 0.3182},
#   {'agent': 'pessoa A',
#    'message': "That's true. Life throws us curveballs sometimes, we just have to roll with the punches.",
#    'neg': 0.0,
#    'neu': 0.714,
#    'pos': 0.286,
#    'compound': 0.4215},
#   {'agent': 'pessoa B',
#    'message': "Exactly. It's all about staying positive and finding a solution to whatever comes our way.",
#    'neg': 0.0,
#    'neu': 0.543,
#    'pos': 0.457,
#    'compound': 0.7096},
#   {'agent': 'pessoa A',
#    'message': "That's a good attitude to have. Well, I'm glad you're okay now after your car troubles.",
#    'neg': 0.153,
#    'neu': 0.284,
#    'pos': 0.562,
#    'compound': 0.7351},
#   {'agent': 'pessoa B',
#    'message': "Thank you, I appreciate it. It's nice to have friends who are there for support during tough times.",
#    'neg': 0.086,
#    'neu': 0.115,
#    'pos': 0.799,
#    'compound': 0.9081}],
#  [{'agent': 'pessoa A',
#    'message': 'Just got a promotion at work, feeling really happy about it.',
#    'neg': 0.0,
#    'neu': 0.421,
#    'pos': 0.579,
#    'compound': 0.6697},
#   {'agent': 'pessoa B',
#    'message': "That's fantastic news! Congratulations. You've been working really hard for it.",
#    'neg': 0.117,
#    'neu': 0.345,
#    'pos': 0.538,
#    'compound': 0.7963},
#   {'agent': 'pessoa A',
#    'message': "Thank you! It's been a long journey but definitely worth it in the end.",
#    'neg': 0.0,
#    'neu': 0.351,
#    'pos': 0.649,
#    'compound': 0.75},
#   {'agent': 'pessoa B',
#    'message': "I'm so happy to hear that. It's always great to see hard work pay off.",
#    'neg': 0.169,
#    'neu': 0.361,
#    'pos': 0.47,
#    'compound': 0.7906},
#   {'agent': 'pessoa A',
#    'message': 'Definitely. How about you, anything exciting happening in your life?',
#    'neg': 0.0,
#    'neu': 0.337,
#    'pos': 0.663,
#    'compound': 0.7096},
#   {'agent': 'pessoa B',
#    'message': "Not really, just dealing with some personal stuff. But it's nothing I can't handle.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa A',
#    'message': "I'm here for you if you need to talk about it. Don't hesitate to reach out.",
#    'neg': 0.156,
#    'neu': 0.581,
#    'pos': 0.263,
#    'compound': 0.1877},
#   {'agent': 'pessoa B',
#    'message': 'Thanks, I appreciate that. It means a lot to me.',
#    'neg': 0.0,
#    'neu': 0.263,
#    'pos': 0.737,
#    'compound': 0.6808},
#   {'agent': 'pessoa A',
#    'message': "Anytime, that's what friends are for. We'll get through this together.",
#    'neg': 0.0,
#    'neu': 0.61,
#    'pos': 0.39,
#    'compound': 0.4939},
#   {'agent': 'pessoa B',
#    'message': "You're right. Having a good support system makes all the difference.",
#    'neg': 0.0,
#    'neu': 0.472,
#    'pos': 0.528,
#    'compound': 0.6808},
#   {'agent': 'pessoa A',
#    'message': "Absolutely. We're in this together, through the good and the bad times.",
#    'neg': 0.328,
#    'neu': 0.375,
#    'pos': 0.297,
#    'compound': -0.0865},
#   {'agent': 'pessoa B',
#    'message': "I'm grateful to have you as a friend. Your support means everything to me.",
#    'neg': 0.0,
#    'neu': 0.252,
#    'pos': 0.748,
#    'compound': 0.836}],
#  [{'agent': 'pessoa A',
#    'message': 'I had a really rough day at work today, everything seemed to go wrong.',
#    'neg': 0.279,
#    'neu': 0.721,
#    'pos': 0.0,
#    'compound': -0.4767},
#   {'agent': 'pessoa B',
#    'message': "I'm sorry to hear that. Bad days happen to everyone, hopefully tomorrow will be better.",
#    'neg': 0.293,
#    'neu': 0.366,
#    'pos': 0.341,
#    'compound': 0.2023},
#   {'agent': 'pessoa A',
#    'message': 'I hope so too. At least I have a long weekend coming up, so it will be a nice break.',
#    'neg': 0.0,
#    'neu': 0.467,
#    'pos': 0.533,
#    'compound': 0.6908},
#   {'agent': 'pessoa B',
#    'message': "That's great! Any plans for the long weekend?",
#    'neg': 0.0,
#    'neu': 0.477,
#    'pos': 0.523,
#    'compound': 0.6588},
#   {'agent': 'pessoa A',
#    'message': 'Not really, just planning to relax at home and catch up on some reading. What about you?',
#    'neg': 0.0,
#    'neu': 0.611,
#    'pos': 0.389,
#    'compound': 0.4902},
#   {'agent': 'pessoa B',
#    'message': "I'm thinking of going on a short road trip with some friends. It should be a fun time.",
#    'neg': 0.0,
#    'neu': 0.519,
#    'pos': 0.481,
#    'compound': 0.7579},
#   {'agent': 'pessoa A',
#    'message': 'Sounds like a great idea. Where are you guys planning to go?',
#    'neg': 0.0,
#    'neu': 0.431,
#    'pos': 0.569,
#    'compound': 0.765},
#   {'agent': 'pessoa B',
#    'message': "We're thinking of driving up to the mountains for some hiking and camping. It's always nice to get away from the city.",
#    'neg': 0.0,
#    'neu': 0.797,
#    'pos': 0.203,
#    'compound': 0.4215},
#   {'agent': 'pessoa A',
#    'message': 'That sounds like a perfect way to unwind and disconnect for a bit. Enjoy your trip!',
#    'neg': 0.0,
#    'neu': 0.382,
#    'pos': 0.618,
#    'compound': 0.8655},
#   {'agent': 'pessoa B',
#    'message': "Thanks! I'll make sure to take lots of pictures. Have a relaxing long weekend at home as well.",
#    'neg': 0.0,
#    'neu': 0.426,
#    'pos': 0.574,
#    'compound': 0.8687},
#   {'agent': 'pessoa A',
#    'message': 'Thanks, I definitely will. Take care and have a safe trip!',
#    'neg': 0.0,
#    'neu': 0.143,
#    'pos': 0.857,
#    'compound': 0.8999},
#   {'agent': 'pessoa B',
#    'message': 'See ya.',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0}],
#  [{'agent': 'pessoa A',
#    'message': 'I had a rough day at work today, everything seemed to go wrong.',
#    'neg': 0.307,
#    'neu': 0.693,
#    'pos': 0.0,
#    'compound': -0.4767},
#   {'agent': 'pessoa B',
#    'message': "I'm sorry to hear that. Hopefully, tomorrow will be better for you.",
#    'neg': 0.131,
#    'neu': 0.303,
#    'pos': 0.566,
#    'compound': 0.6486},
#   {'agent': 'pessoa A',
#    'message': 'I hope so too. How was your day?',
#    'neg': 0.0,
#    'neu': 0.256,
#    'pos': 0.744,
#    'compound': 0.4404},
#   {'agent': 'pessoa B',
#    'message': 'It was not too bad, just the usual routine.',
#    'neg': 0.636,
#    'neu': 0.364,
#    'pos': 0.0,
#    'compound': -0.5423},
#   {'agent': 'pessoa A',
#    'message': "That's good to hear. It's always nice to have a calm day sometimes.",
#    'neg': 0.0,
#    'neu': 0.429,
#    'pos': 0.571,
#    'compound': 0.7906},
#   {'agent': 'pessoa B',
#    'message': 'Definitely. Do you have any plans for the weekend?',
#    'neg': 0.0,
#    'neu': 0.426,
#    'pos': 0.574,
#    'compound': 0.4019},
#   {'agent': 'pessoa A',
#    'message': 'Not really, just thinking of catching up on some Netflix shows. How about you?',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': "I have a family gathering on Sunday, so that'll take up most of my weekend.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa A',
#    'message': "Family time is always nice. Hopefully it'll be a good get-together.",
#    'neg': 0.0,
#    'neu': 0.373,
#    'pos': 0.627,
#    'compound': 0.8126},
#   {'agent': 'pessoa B',
#    'message': "Yeah, I hope so too. It's been a while since we all got together.",
#    'neg': 0.0,
#    'neu': 0.44,
#    'pos': 0.56,
#    'compound': 0.6249},
#   {'agent': 'pessoa A',
#    'message': "Well, enjoy your time with your family. I'm sure it'll be a great day.",
#    'neg': 0.0,
#    'neu': 0.299,
#    'pos': 0.701,
#    'compound': 0.8934},
#   {'agent': 'pessoa B',
#    'message': "Thanks. And hopefully, you'll have a more relaxing weekend ahead. Take care!",
#    'neg': 0.0,
#    'neu': 0.246,
#    'pos': 0.754,
#    'compound': 0.906}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work! I'm so excited.",
#    'neg': 0.0,
#    'neu': 0.598,
#    'pos': 0.402,
#    'compound': 0.4003},
#   {'agent': 'pessoa B',
#    'message': "That's amazing, congratulations! You've been working so hard for it.",
#    'neg': 0.113,
#    'neu': 0.242,
#    'pos': 0.645,
#    'compound': 0.8221},
#   {'agent': 'pessoa A',
#    'message': "Thanks! It's been a long journey but it finally paid off.",
#    'neg': 0.0,
#    'neu': 0.61,
#    'pos': 0.39,
#    'compound': 0.4926},
#   {'agent': 'pessoa B',
#    'message': "I'm really happy for you. You deserve it.",
#    'neg': 0.0,
#    'neu': 0.429,
#    'pos': 0.571,
#    'compound': 0.6115},
#   {'agent': 'pessoa A',
#    'message': "How about you, how's everything going on your end?",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': "Things have been a bit tough lately, but I'm managing.",
#    'neg': 0.231,
#    'neu': 0.769,
#    'pos': 0.0,
#    'compound': -0.128},
#   {'agent': 'pessoa A',
#    'message': "If you ever need to talk or vent, I'm here for you.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': 'Thanks, I really appreciate that.',
#    'neg': 0.0,
#    'neu': 0.145,
#    'pos': 0.855,
#    'compound': 0.7089},
#   {'agent': 'pessoa A',
#    'message': 'We should celebrate your promotion, maybe go out for dinner this weekend?',
#    'neg': 0.0,
#    'neu': 0.575,
#    'pos': 0.425,
#    'compound': 0.5719},
#   {'agent': 'pessoa B',
#    'message': "That sounds like a great idea. Let's do it on Saturday night?",
#    'neg': 0.0,
#    'neu': 0.476,
#    'pos': 0.524,
#    'compound': 0.765},
#   {'agent': 'pessoa A',
#    'message': "Perfect, I'll make a reservation at your favorite restaurant.",
#    'neg': 0.0,
#    'neu': 0.374,
#    'pos': 0.626,
#    'compound': 0.7717},
#   {'agent': 'pessoa B',
#    'message': "You really didn't have to, but I'm looking forward to it.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0}],
#  [{'agent': 'pessoa A',
#    'message': "I just got a promotion at work, I'm so excited!",
#    'neg': 0.0,
#    'neu': 0.598,
#    'pos': 0.402,
#    'compound': 0.4003},
#   {'agent': 'pessoa B',
#    'message': "That's fantastic news, congratulations! You must be thrilled.",
#    'neg': 0.0,
#    'neu': 0.219,
#    'pos': 0.781,
#    'compound': 0.8932},
#   {'agent': 'pessoa A',
#    'message': "Thank you, yes, I've been working really hard for it.",
#    'neg': 0.171,
#    'neu': 0.303,
#    'pos': 0.526,
#    'compound': 0.5434},
#   {'agent': 'pessoa B',
#    'message': "It's great to see your efforts paying off.",
#    'neg': 0.0,
#    'neu': 0.494,
#    'pos': 0.506,
#    'compound': 0.6249},
#   {'agent': 'pessoa A',
#    'message': 'Definitely, it feels good to be recognized.',
#    'neg': 0.0,
#    'neu': 0.263,
#    'pos': 0.737,
#    'compound': 0.6808},
#   {'agent': 'pessoa B',
#    'message': "You deserve it, you've been dedicated and determined.",
#    'neg': 0.0,
#    'neu': 0.27,
#    'pos': 0.73,
#    'compound': 0.6597},
#   {'agent': 'pessoa A',
#    'message': 'Thanks, I appreciate your support.',
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 1.0,
#    'compound': 0.8074},
#   {'agent': 'pessoa B',
#    'message': "Of course, I'm always rooting for you.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa A',
#    'message': 'It means a lot to me, thank you.',
#    'neg': 0.0,
#    'neu': 0.444,
#    'pos': 0.556,
#    'compound': 0.3612},
#   {'agent': 'pessoa B',
#    'message': "You're welcome, I'm happy for you.",
#    'neg': 0.0,
#    'neu': 0.23,
#    'pos': 0.77,
#    'compound': 0.7717},
#   {'agent': 'pessoa A',
#    'message': "Thanks again, it's nice to have someone to share this with.",
#    'neg': 0.0,
#    'neu': 0.202,
#    'pos': 0.798,
#    'compound': 0.7845},
#   {'agent': 'pessoa B',
#    'message': "Anytime, that's what friends are for.",
#    'neg': 0.0,
#    'neu': 0.385,
#    'pos': 0.615,
#    'compound': 0.4939}],
#  [{'agent': 'pessoa A',
#    'message': "I finally got that promotion at work I've been working towards for months!",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': "That's fantastic news, congrats! I'm so happy for you.",
#    'neg': 0.0,
#    'neu': 0.214,
#    'pos': 0.786,
#    'compound': 0.8999},
#   {'agent': 'pessoa A',
#    'message': 'Thank you! It feels like a weight has been lifted off my shoulders.',
#    'neg': 0.0,
#    'neu': 0.43,
#    'pos': 0.57,
#    'compound': 0.6476},
#   {'agent': 'pessoa B',
#    'message': "I can only imagine the sense of relief. You've put in so much hard work for this.",
#    'neg': 0.133,
#    'neu': 0.571,
#    'pos': 0.295,
#    'compound': 0.4019},
#   {'agent': 'pessoa A',
#    'message': "It's been a long journey, but it was all worth it in the end.",
#    'neg': 0.0,
#    'neu': 0.678,
#    'pos': 0.322,
#    'compound': 0.2263},
#   {'agent': 'pessoa B',
#    'message': 'Definitely. Your dedication and perseverance really paid off.',
#    'neg': 0.0,
#    'neu': 0.597,
#    'pos': 0.403,
#    'compound': 0.4019},
#   {'agent': 'pessoa A',
#    'message': "It's just such a relief to finally see some progress in my career.",
#    'neg': 0.0,
#    'neu': 0.404,
#    'pos': 0.596,
#    'compound': 0.7096},
#   {'agent': 'pessoa B',
#    'message': "Well-deserved, my friend. You deserve all the success that's coming your way.",
#    'neg': 0.0,
#    'neu': 0.42,
#    'pos': 0.58,
#    'compound': 0.7845},
#   {'agent': 'pessoa A',
#    'message': 'Your support means a lot to me, thank you for always being there.',
#    'neg': 0.0,
#    'neu': 0.366,
#    'pos': 0.634,
#    'compound': 0.6369},
#   {'agent': 'pessoa B',
#    'message': "Anytime! I'll always be here cheering you on, through the highs and the lows.",
#    'neg': 0.217,
#    'neu': 0.413,
#    'pos': 0.371,
#    'compound': 0.3595},
#   {'agent': 'pessoa A',
#    'message': 'I appreciate that more than you know. It means the world to have friends like you.',
#    'neg': 0.0,
#    'neu': 0.263,
#    'pos': 0.737,
#    'compound': 0.8126},
#   {'agent': 'pessoa B',
#    'message': "Of course, we're in this together. Here's to more success and happiness in the future.",
#    'neg': 0.0,
#    'neu': 0.407,
#    'pos': 0.593,
#    'compound': 0.8074}],
#  [{'agent': 'pessoa A',
#    'message': 'I just got a promotion at work, I am so excited!',
#    'neg': 0.0,
#    'neu': 0.527,
#    'pos': 0.473,
#    'compound': 0.4003},
#   {'agent': 'pessoa B',
#    'message': "That's incredible! Congratulations! You've worked so hard for it.",
#    'neg': 0.142,
#    'neu': 0.405,
#    'pos': 0.454,
#    'compound': 0.6229},
#   {'agent': 'pessoa A',
#    'message': "Thank you! It's been a long journey, but it finally paid off.",
#    'neg': 0.0,
#    'neu': 0.642,
#    'pos': 0.358,
#    'compound': 0.4199},
#   {'agent': 'pessoa B',
#    'message': 'You definitely deserve it. How do you plan to celebrate?',
#    'neg': 0.0,
#    'neu': 0.238,
#    'pos': 0.762,
#    'compound': 0.7506},
#   {'agent': 'pessoa A',
#    'message': "I'm thinking of going out for a nice dinner with my family and close friends.",
#    'neg': 0.0,
#    'neu': 0.5,
#    'pos': 0.5,
#    'compound': 0.7184},
#   {'agent': 'pessoa B',
#    'message': "That sounds perfect! What's your favorite type of cuisine?",
#    'neg': 0.0,
#    'neu': 0.364,
#    'pos': 0.636,
#    'compound': 0.7901},
#   {'agent': 'pessoa A',
#    'message': 'I love Italian food, especially pasta and pizza.',
#    'neg': 0.0,
#    'neu': 0.543,
#    'pos': 0.457,
#    'compound': 0.6369},
#   {'agent': 'pessoa B',
#    'message': 'Same here! Nothing beats a good bowl of pasta. Do you have a favorite restaurant in mind?',
#    'neg': 0.206,
#    'neu': 0.513,
#    'pos': 0.281,
#    'compound': 0.223},
#   {'agent': 'pessoa A',
#    'message': "There's this cozy little Italian place downtown that I've been wanting to try.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'pessoa B',
#    'message': 'Sounds lovely! When are you planning to go there?',
#    'neg': 0.0,
#    'neu': 0.423,
#    'pos': 0.577,
#    'compound': 0.6239},
#   {'agent': 'pessoa A',
#    'message': 'I was thinking maybe this weekend, to make it a special celebration.',
#    'neg': 0.0,
#    'neu': 0.649,
#    'pos': 0.351,
#    'compound': 0.4019},
#   {'agent': 'pessoa B',
#    'message': "Count me in! I'd love to join you and raise a toast to your success.",
#    'neg': 0.0,
#    'neu': 0.278,
#    'pos': 0.722,
#    'compound': 0.8858}]]

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as np

for agent in ['pessoa A', 'pessoa B']:
    for category in ['pos', 'neg', 'neu', 'compound']:

        data = np.array([[d[category] for d in x if d['agent'] == agent] for x in processed_texts])
        for x in data:
            plt.plot(range(len(x)), x, '#ccc')
        data = data.T

        # x values are just indices
        x = np.arange(len(data))

        avg_y = np.mean(data, axis=1)
        min_y = np.min(data, axis=1)
        max_y = np.max(data, axis=1)

        # calculate polynomial fit (degree = 1 for linear)
        coef_avg = np.polyfit(x, avg_y, 1)
        coef_min = np.polyfit(x, min_y, 1)
        coef_max = np.polyfit(x, max_y, 1)

        poly1d_fn_avg = np.poly1d(coef_avg)
        poly1d_fn_min = np.poly1d(coef_min) 
        poly1d_fn_max = np.poly1d(coef_max)


        legends = [Line2D([0], [0], color='#ccc', label='Dados'),
                   Line2D([0], [0], color='blue', label='Tendência dos máximos', linestyle='--'),
                   Line2D([0], [0], color='red', label='Tendência da média', linestyle='--'),
                   Line2D([0], [0], color='blue', label='Tendência dos mínimos', linestyle='--'),
        ]

        plt.plot(x, poly1d_fn_avg(x), '--r')
        plt.plot(x, poly1d_fn_min(x), '--b')
        plt.plot(x, poly1d_fn_max(x), '--b')

        plt.yticks(np.arange(-1, 1.1, 0.2))

        plt.xlabel('Número da interação')
        plt.ylabel('Valor')
        plt.title(f'Propriedades do {agent}:{category}')
        plt.legend(handles=legends)
        plt.show()
