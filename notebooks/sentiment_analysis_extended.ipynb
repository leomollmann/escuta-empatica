# %%
import nltk

nltk.download('punkt')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/leonardoscholler/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/leonardoscholler/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
texts = []

for i in range(1,24):
    with open(f'../dados/juliano_rigatti_en_extended/{i}.txt', 'r') as file:
        texts.append(file.read())

texts
# Out:
# ["- I don't know what to do. I was waiting to get out of my doctoral scholarship at the university, but they're dragging me around and I don't think I can get out. A month ago I had a meeting, they said that they really liked my line of research and that they didn't let me down. Yesterday, everything changed. They want me to pay, but I can't afford it. After years of dedication as a teacher, I was counting on that money. It would be very important for my income. I don't even know what to think.\n- I was listening to you and I think I identified some feelings there. Maybe sadness, frustration, disappointment... Could it be?\n- It could be, yes. There are certainly three. Disappointment, anxiety too.\n- Hmm. Maybe you're also afraid of running out of income?\n- Yes true. He's afraid too. I didn't realize it and it could be influenced in my reactivity towards them.\n- And I imagine that the fear comes because you have a strong need for material security. It makes sense?\n- Total. Good to find that out, I hadn't even realized it.\n- And the disappointment I think came because you need greater reciprocity and attention to the years of dedication and it seems that this is not being met...\n- Yes, in several situations where the university needed me, I was there. Now that I need it, and it's fair, they don't help me.\n- Yes, I understand.\n- It's understandable that you feel let down by the university after all the effort you've put in.\n- Yes, it's just frustrating to feel like my hard work isn't being recognized.\n- I can see how that would be tough to deal with.\n- It really is. I feel like my future is uncertain now.\n- That uncertainty must be causing a lot of stress for you.\n- It definitely is. I feel like I can't plan ahead anymore.\n- It's completely normal to feel overwhelmed in this situation.\n- Thank you for understanding. It helps to talk about it with someone who gets it.\n- I'm here to listen and support you through this difficult time.\n- I appreciate that. It means a lot to me.\n- Just remember, it's okay to feel how you're feeling right now.\n- Thank you. I'll try to remind myself of that.",
#  "- Yesterday I came home and the sink was once again full of dirty dishes. The guy doesn't care. I've already asked him to wash it as he cooks so it doesn't accumulate, but it's no use! I can not take it anymore.\n- I'm listening to you and realizing that there's anger, frustration there, does that make sense?\n- Yes, and tiredness as well.\n- And perhaps these feelings are present because you need reciprocity and respect.\n- That's it, I really need it. Of consideration as well.\n- It sounds like you've been feeling overwhelmed by the situation.\n- Yes, exactly. I feel like I'm the only one taking care of things in the house.\n- It must be exhausting to constantly feel like you're carrying all the responsibility.\n- It really is. I just wish he would listen and understand how I'm feeling.\n- It sounds like you're seeking understanding and support from him.\n- Yes, that's exactly it. I feel like I'm not being heard.\n- It's important to feel heard and validated in your feelings.\n- I just don't know how to get through to him and make him see my perspective.\n- It sounds like communication is a big challenge in this situation.\n- It really is. I feel like we're always talking past each other.\n- Maybe it would help to have a calm and honest conversation about how you're feeling.\n- I think you're right. I need to find a way to express myself clearly without getting too emotional.\n- It's important to communicate your needs in a way that allows for understanding and resolution.",
#  "- She didn't give a signal and crossed in front of me. If I hadn't been paying close attention, I would have gotten it right. I got mad because people ignore others and go in. Why so much of a rush? I don't like honking and swearing in traffic, but sometimes I can't stand it.\n- Yes, I hear anger and fear. Anger at her attitude, but also fear at the possible consequences. That?\n- Fear... it's true. I hadn't thought about fear. And when I feel afraid I usually become more explosive.\n- Yes, maybe because safety is very important to you...\n- Yes, even more so with a child in the car.\n- I can imagine how important it is to keep your child safe. It must be tough when other drivers disregard that.\n- It is tough. I just want to protect my family and it's hard when others don't consider that.\n- It sounds like you have a strong need for security and protection for your loved ones.\n- Yes, exactly. I just want to make sure they are safe.\n- It must be frustrating when others don't share the same values or priorities.\n- Definitely. It feels like no one cares about anyone else these days.\n- It sounds like you're feeling a bit disillusioned with the way people behave on the road.\n- Yes, exactly. It's like everyone is just looking out for themselves.\n- I can understand how that would be really frustrating for you.\n- Thank you for listening. It helps to talk about it.",
#  "- My boss simply doesn’t recognize the effort I make. I stay late, meet deadlines, but he only points out what needs to be done. I'm exhausted and unmotivated. \n- I see this makes you really sad and discouraged. You would like to have the feeling that you are being seen.\n- Exactly, it's as if I were invisible. \n- It seems that what you are really looking for is recognition and consideration. \n- Yes, that would make a big difference to me.\n- It sounds like you are feeling unappreciated and undervalued in your work.\n- Definitely, it's really frustrating to put in so much effort and not feel acknowledged.\n- It must be really tough to continue giving your best when you don't feel like it's making a difference.\n- It really is. I feel like I'm stuck in a cycle of working hard and not getting any recognition.\n- That sounds really disheartening. Have you tried talking to your boss about how you feel?\n- I have, but it doesn't seem to change anything. It's like talking to a wall.\n- It must be really disheartening to feel like your efforts are going unnoticed despite voicing your concerns.\n- It really is. I don't know how much longer I can continue like this.\n- It sounds like you are feeling very overwhelmed by the situation.\n- Yes, I feel like I'm at a breaking point.\n- It's important to take care of yourself in situations like this. Maybe setting some boundaries could help.\n- That's a good idea. I need to prioritize my well-being. Thank you for listening and understanding.",
#  "- Every time I try to talk to my sister about our travel plans, she changes the subject. I feel like she's not taking it seriously. \n- It sounds like you are feeling alone and worried about her commitment, am I right? \n- Yes, that's it. I want her to understand that she is important to me and that I need company in this. \n- Maybe deep down, you are looking for her cooperation so that you feel connected in this project together. \n- Exactly, I want to feel like we’re on the same page.\n- It must be frustrating to feel like you’re not getting the support you need from someone close to you. \n- Yes, it is. I just wish she would prioritize our plans like I do. \n- It seems like you value the idea of teamwork and shared experiences. \n- Yes, I do. It’s important to me to have that bond with my sister. \n- Have you tried expressing these feelings to her directly? \n- I have, but she always dismisses it or changes the subject. \n- It sounds like you’re feeling dismissed and unheard. \n- Yes, exactly. It’s like my feelings don’t matter to her. \n- I can understand how that would be hurtful. \n- It is. I just don’t know how to get her to take me seriously. \n- Maybe she just needs a different approach to understand your perspective.",
#  "- Whenever I see news about the environment, I feel enormous anguish. It seems like no one cares enough to make real changes. \n- You seem to be carrying great concern and sadness regarding the future of our planet, does this resonate with you? \n- Yes, it is a feeling of helplessness. \n- And perhaps this sadness comes from a place where there is a lack of support and communion with the same values \u200b\u200bas yours. \n- That's right, I want everyone to do their part.\n- It must be frustrating to feel like you're the only one who cares about such an important issue.\n- Very frustrating indeed. Sometimes I feel like giving up.\n- It's completely understandable to feel that way when it seems like progress is so slow.\n- Yes, it's hard to stay motivated when it feels like nothing is changing.\n- I hear you. It's important to remember that even small actions can make a difference.\n- You're right. I'll try to focus on the positive changes that are happening.\n- That sounds like a good plan. It's also important to take care of yourself during these challenging times.\n- Thank you for reminding me to take care of myself. I often forget to do that.\n- Self-care is crucial, especially when dealing with such heavy emotions.\n- I will make more of an effort to prioritize my well-being. Thank you for your support.\n- You're welcome. Remember, you're not alone in your feelings about the environment. We can make a difference together.\n- That's a comforting thought. Thank you for listening and understanding.",
#  "- I feel like no one understands me. I try to explain my feelings, but people seem indifferent. \n- It seems like you are seeking connection and feel distant when you are not understood. Does this make sense to you? \n- Yes, exactly that. \n- So, deep down, you want to be heard and understood, even if they don’t agree with you. \n- That’s it, I want to feel part of something.\n- I can imagine how lonely and frustrating it must be to feel like you're talking to a wall.\n- It really is. It's like I'm screaming into the void and no one hears me.\n- It must be exhausting to constantly feel unheard and overlooked.\n- It is. I feel like I'm invisible sometimes.\n- It sounds like you need a safe space where you can truly express yourself without fear of judgment.\n- Yes, exactly. I just want to feel accepted for who I am.\n- It's important to feel validated and respected in your relationships.\n- I wish I had that kind of support from the people around me.\n- It's tough to navigate life feeling like you're on your own.\n- It really is. I just want someone to truly see me and understand me.\n- It's understandable that you crave that deep connection and understanding from others.\n- Thank you for listening and for acknowledging my feelings. It means a lot to me.",
#  "- My son won’t stop crying at night and I don’t know what to do anymore. I'm exhausted. \n- In addition to exhaustion, I understand that you feel lost and insecure.\n- Yes, I'm at my limit, I need help. \n- Maybe you are looking for more clarity and support from someone. \n- Of course, I need to understand what is happening to reduce the tension.\n- It sounds like you're feeling overwhelmed and in need of some relief.\n- Yes, exactly. I can't keep up with this situation.\n- It seems like you're also feeling a bit helpless and frustrated.\n- Yes, I feel like I've tried everything and nothing is working.\n- It must be really hard to see your son in distress and not know how to help.\n- It breaks my heart to hear him cry and not be able to soothe him.\n- It sounds like you're experiencing a lot of empathy for your son's emotions.\n- Absolutely, I just want him to feel better and be happy.\n- It's clear that you care deeply for your son and his well-being.\n- I just wish I knew how to make things better for him.\n- It's understandable that you would feel that way. Being a parent can be tough.\n- Thank you for understanding. I really appreciate your support.",
#  "- I can’t concentrate on my studies. Every five minutes, I pick up my cell phone to see if there's anything new. \n- I notice that you are apprehensive about not being able to study and disappointed with your lack of focus. And that?\n- Yes, that way I won’t pass the year. And it's true, they're disappointed in me too.\n- If you could be less distracted, would that meet your desire for efficiency and safety? \n- That would help a lot, yes.\n- It seems like you're feeling overwhelmed by the pressure to perform well in your studies. \n- Yes, I feel a lot of pressure to succeed and meet everyone's expectations. \n- It sounds like you have a strong need for approval and validation from others. \n- Yes, I always seek recognition for my efforts and hard work. \n- Maybe setting some boundaries with your phone and creating a study routine could help you focus better. \n- That's a good idea. I'll try to implement some new habits to improve my concentration. \n- It's important to take care of yourself and prioritize your well-being during stressful times. \n- Yes, I need to remember to take breaks and not be too hard on myself. \n- Remember that it's okay to ask for help and support when you're feeling overwhelmed. \n- I appreciate your advice, it means a lot to me. \n- I'm glad I could offer you some support. You're not alone in this. \n- Thank you for listening to me and understanding my struggles. \n- Anytime. I'm here to listen and support you through this challenging time.",
#  "- I'm so relieved to have finished the project on time. It was a race against the clock. \n- Wow, you must be feeling accomplished having met the deadline and satisfied with your ability to manage time. \n- Yes, I was worried I wouldn’t make it. \n- So, this also touches on your need for confidence in your abilities and competence to overcome challenges. \n- Exactly, that's it.\n- It must have been quite stressful for you to have that weight on your shoulders.\n- Definitely, I was feeling a lot of pressure.\n- It sounds like you value meeting your commitments and expectations.\n- Yes, I always strive to do my best.\n- I can see that you have a strong sense of responsibility.\n- Thank you for acknowledging that.\n- You're welcome, it's important to recognize your hard work and dedication.\n- I really appreciate your support.\n- I'm here for you, anytime you need to talk.\n- That means a lot to me.\n- I'm glad I can help in some way.\n- Thank you for being such a good listener.\n- It's my pleasure, I'm always here to lend an ear.",
#  "- My son finally started walking. I'm so proud! \n- How wonderful! You seem to be in awe of his achievements. \n- And I am. It's a big milestone. \n- This reflects your need to celebrate special moments and support his growth. \n- Of course, it is very important to me.\n- I see how much joy and pride this brings you. \n- Yes, definitely. It's a big moment for our family. \n- It must also show your need for connection and closeness with your son. \n- Absolutely, it's a bonding experience for us. \n- It's great that you're able to recognize and appreciate these moments. \n- Thank you, it means a lot to me. \n- It sounds like you have a strong emotional connection with your son. \n- Yes, he means the world to me. \n- I can sense the love and care you have for him. \n- Yes, I want to support him in every way I can. \n- It's beautiful to see the special bond you two share. \n- Thank you, I feel truly blessed.",
#  "- I managed to solve that complicated problem at work today. \n- Oops, you must be feeling very confident and also relieved to have found a solution. \n- Actually, it was a big problem. \n- This shows your need for effectiveness and to be recognized for your ability to solve problems. \n- Yes, that motivates me.\n- It's great that you were able to tap into your strengths and tackle the problem head-on.\n- Thank you for acknowledging that. It feels good to be appreciated.\n- I can see how important recognition is to you in your work.\n- Absolutely, it's one of the things that keeps me going.\n- It sounds like you thrive on challenges and pushing yourself to find solutions.\n- Yes, I do enjoy a good challenge and the satisfaction of overcoming it.\n- It's impressive how you can maintain that level of determination and focus.\n- Thank you, it's not always easy but it's rewarding in the end.\n- You must have a lot of inner strength to persevere through difficult situations.\n- I try my best to stay resilient and keep moving forward.\n- Your ability to overcome challenges is truly admirable.",
#  "- I finally managed to save enough to buy my car. \n- Congratulations! You must be feeling very accomplished and even admired by your own abilities. \n- Yes, it was a goal I pursued for a long time. \n- So, this meets your need for autonomy and effectiveness in achieving personal goals. \n- Exactly, it’s an incredible feeling.\n- I imagine that you are also feeling a sense of relief now that you have achieved this goal. \n- Yes, absolutely. It feels like a weight has been lifted off my shoulders. \n- It's important to acknowledge and celebrate your hard work paying off. \n- Thank you, I appreciate your kind words. \n- Enjoy this moment of success and remember that you are capable of reaching your goals. \n- I will, thank you for reminding me of that. \n- You're welcome. I'm here to support and celebrate your accomplishments with you.",
#  "- After months of practice, I played the piano in front of an audience for the first time. \n- This is fantastic! You must be feeling radiant and excited to share more of your talent. \n- Yes, I was nervous, but it went well. \n- It sounds like you are seeking recognition and also want to challenge yourself to grow as a musician. \n- That’s right, I want to continue improving myself.\n- It's great that you have this passion for music and the courage to share your talent with others.\n- Thank you, music means everything to me.\n- I can see that music is a big part of your identity and brings you a lot of joy.\n- Definitely, it's my way of expressing myself and connecting with others.\n- It's wonderful that you have found this creative outlet to express your emotions.\n- Yes, music helps me process my feelings and experiences in a unique way.\n- It's amazing how art can have such a powerful impact on our emotional well-being.\n- Absolutely, music has a way of healing and uplifting the soul.\n- I'm glad you have found something that brings you so much happiness and fulfillment.\n- Thank you for listening and understanding, it means a lot to me.",
#  "- I'm feeling so anxious about this job interview tomorrow. \n- You seem worried about the result and perhaps need more reassurance. And that? \n- Yes, I'm very insecure. \n- Maybe you are looking for confidence and a little peace of mind to face this challenge. \n- That would help a lot.\n- It's completely understandable to feel that way before a big event like a job interview.\n- Yes, I just really want to make a good impression and get this opportunity.\n- It sounds like you have a strong desire for success and validation in this situation.\n- Absolutely. I've been working towards this for a long time and I really want it to pay off.\n- Your hard work and dedication are definitely shining through. It's important to acknowledge that.\n- Thank you, I appreciate you recognizing that. It means a lot.\n- It's important to remember to believe in yourself and your abilities, even in moments of doubt.\n- I will try to keep that in mind. I just really hope it goes well.",
#  "- I can't stop thinking about the mistake I made at work. \n- It sounds like you are afraid of the consequences and need to understand why you did what you did. Am I right? \n- Exactly, I wanted to understand what happened. \n- And this clarity would help you move forward and not make mistakes next time.\n- Yes definitely.\n- It's important to acknowledge that we all make mistakes sometimes.\n- I appreciate your understanding. It's just hard not to dwell on it.\n- I understand, it can be tough to let go of those feelings.\n- I feel like I let my team down.\n- It's natural to feel that way, but remember that everyone makes mistakes.\n- Thanks for reminding me of that. It helps to talk about it.\n- I'm glad I could offer some support. It's important to be kind to yourself during these times.\n- You're right, I need to be kinder to myself.\n- It's important to practice self-compassion and forgive yourself.\n- I will try to do that. Thank you for listening and for your support.",
#  "- I feel so alone since I moved to this new city. \n- Yes, connection and company must be needed. \n- I miss having friends around. \n- I also imagine a sense of community in your new environment. \n- That would definitely make a big difference.\n- It sounds like you're craving a sense of belonging.\n- Yes, exactly. I feel like I don't fit in here.\n- It must be tough to feel like an outsider.\n- It is. I thought moving would be exciting, but it's been harder than I expected.\n- Change can be really challenging, especially when it involves leaving a familiar support system behind.\n- That's true. I didn't realize how much I depended on my friends back home.\n- It's natural to feel that way. Transitioning to a new place takes time and effort.\n- I just wish I had someone here to talk to and hang out with.\n- Isolation can definitely take a toll on mental well-being.\n- Absolutely. I've been feeling really down lately.\n- It's important to prioritize self-care and seek out opportunities for connection.\n- I'll try to put myself out there more and see if I can make some new friends.",
#  "- My mother is sick and I have to take care of her, but I also have to work. It's too much. \n- You seem to be divided between responsibilities...\n- Yes, divided and tired. I'm overwhelmed. \n- Perhaps you are looking for balance and support to manage these demands. \n- That would be ideal.\n- It's understandable that you feel overwhelmed with everything on your plate.\n- Yes, it's a lot to handle all at once.\n- Have you considered seeking help or delegating some tasks to lighten your load?\n- I have, but it's hard to find reliable help sometimes.\n- It must be difficult to juggle so many responsibilities.\n- It really is. I feel like I'm being pulled in different directions.\n- It's important to take care of yourself too during this challenging time.\n- I know, but it's hard to find the time for self-care.\n- Maybe taking small breaks or finding moments of relaxation could help.\n- That's a good idea. I'll try to incorporate that into my routine.\n- Remember that it's okay to ask for help and prioritize your well-being.\n- Thank you for listening and for the advice. It means a lot to me.",
#  "- My partner and I have been arguing a lot lately. I'm frustrated. \n- You seem to be feeling worn out and need harmony. Am I interpreting correctly? \n- Not just harmony, more reciprocity on his part. \n- I understood. As if you wanted support to resolve this together. \n- Exactly, that would help us sort things out.\n- It sounds like you're looking for more collaboration and understanding in your relationship.\n- Yes, that's it. I feel like I'm the only one making an effort to make things work.\n- It must be tough feeling like you're carrying the weight of the relationship on your shoulders.\n- It is, it's exhausting.\n- Have you talked to your partner about how you're feeling?\n- I tried, but it seems like he's not really listening.\n- It's important for both partners to feel heard and understood in a relationship.\n- I know, but I don't know how to make him understand.\n- Maybe setting aside some dedicated time to have an open and honest conversation could help.\n- That's a good idea, I'll try that. Thank you for listening and giving me advice.\n- Of course, I'm here to support you.",
#  "- My dog \u200b\u200bran away and I'm so worried. \n- You seem to be distressed by the lack of information about how he is doing.\n- Yes, I feel desperate thinking about the possibilities. \n- Yes, I wish I could hope that he is okay and have some company to help find him, is that it? \n- Yes, any help would be welcome.\n- It must be really hard not knowing where your dog is. \n- It is, I keep imagining all sorts of scenarios in my head. \n- It makes sense that you feel overwhelmed by all the possibilities. \n- Yes, I just want him to be safe and come back home. \n- I understand, your dog is like family to you. \n- Yes, he is my best friend. \n- I hope you find him soon and everything turns out okay.",
#  "- I'm trying to lose weight, but it's so hard to stick to the diet. \n- It sounds like you are frustrated and need more motivation. That makes sense? \n- Yes, it’s a constant battle. \n- I also understand that you are trying to take care of something very important, which is health, but that you need more efficiency. \n- That's right.\n- Have you tried finding a support system to help you stay motivated during this process?\n- I have tried, but sometimes it feels like no one understands the struggle I'm going through.\n- It must be tough feeling like you're going through this alone.\n- It is. Sometimes I just wish someone would truly listen and give me the encouragement I need.\n- It's important to feel supported and understood when you're going through a challenging journey like this.\n- Yes, it really is. I guess I just need to keep pushing through and find my own inner strength.\n- Remember that it's okay to ask for help when you need it. You don't have to do this alone.\n- Thank you for reminding me of that. It's easy to forget sometimes.\n- It's completely normal to feel overwhelmed at times. Just know that it's okay to reach out for support.\n- I appreciate your words of encouragement. It means a lot to me.\n- I'm glad I could offer some support. Just know that I'm here to listen whenever you need to talk.",
#  "- I feel like my teenage son is moving away from me. \n- You seem to be worried about your connection and even his safety. And that? \n- Yes, I feel like I'm losing my son. \n- I also notice a need for clarity as to why this happened and how it could change.\n- This is very important to me.\n- I can imagine how difficult it must be for you to feel that distance growing.\n- It's heartbreaking, really. I just want to understand what's going on.\n- Have you tried talking to your son about how you're feeling?\n- I have, but he just shuts down and doesn't want to talk.\n- That must be so frustrating for you.\n- It really is. I just want to know how to help him.\n- Maybe he's going through a tough time and doesn't know how to express it.\n- That could be it. I just wish he would open up to me.\n- It's natural to want to be there for your child in times of difficulty.\n- Thank you for understanding. Your empathy means a lot to me.",
#  '- I\'m feeling pressured when deciding to choose a career. \n- Behind the "pressure" I notice that there is a feeling of loneliness and lack of company and even more understanding of the options. \n- No, I already have all the information. I want to be able to decide alone and with more time.\n- Maybe you are looking for space and autonomy to make the right choice for you.\n- Yes, I need that: space and autonomy.\n- It sounds like you value independence and taking your time to make important decisions.\n- Yes, exactly. I want to make sure I\'m choosing the right path for myself.\n- It\'s important to prioritize your own needs and desires when making career decisions.\n- I agree. I just hope I can make the right choice in the end.\n- It\'s okay to feel uncertain, but trust that you have the ability to make the best decision for yourself.\n- Thank you for reassuring me. I really appreciate your support.\n- Of course, I\'m here to listen and help however I can.\n- Your understanding means a lot to me. Thank you.\n- I\'m glad I could help. Remember, it\'s okay to take your time and trust yourself in this process.\n- I will try to remember that. Thank you for your guidance.\n- Anytime. Just know that I\'m here for you whenever you need to talk.']

# %%
processed_texts = []
for text in texts:
    split_text = text.split('===')[0].strip().split('\n')

    # Extracting alternating messages
    intrigue_messages = split_text[::2]
    peacemaker_messages = split_text[1::2]

    # Creating schema
    result = []
    for i in range(len(intrigue_messages)):
        result.append({
            "agent": "agente intrigante",
            "message": intrigue_messages[i].replace('- ', '')
        })
        if i < len(peacemaker_messages):
            result.append({
                "agent": "agente empático",
                "message": peacemaker_messages[i].replace('- ', '')
            })
    
    print(len(result))
    processed_texts.append(result[0:12])

processed_texts
# Out:
# 22
# 18
# 15
# 17
# 16
# 17
# 17
# 17
# 18
# 18
# 17
# 16
# 12
# 15
# 13
# 15
# 17
# 17
# 16
# 12
# 16
# 15
# 16
# [[{'agent': 'agente intrigante',
#    'message': "I don't know what to do. I was waiting to get out of my doctoral scholarship at the university, but they're dragging me around and I don't think I can get out. A month ago I had a meeting, they said that they really liked my line of research and that they didn't let me down. Yesterday, everything changed. They want me to pay, but I can't afford it. After years of dedication as a teacher, I was counting on that money. It would be very important for my income. I don't even know what to think."},
#   {'agent': 'agente empático',
#    'message': 'I was listening to you and I think I identified some feelings there. Maybe sadness, frustration, disappointment... Could it be?'},
#   {'agent': 'agente intrigante',
#    'message': 'It could be, yes. There are certainly three. Disappointment, anxiety too.'},
#   {'agent': 'agente empático',
#    'message': "Hmm. Maybe you're also afraid of running out of income?"},
#   {'agent': 'agente intrigante',
#    'message': "Yes true. He's afraid too. I didn't realize it and it could be influenced in my reactivity towards them."},
#   {'agent': 'agente empático',
#    'message': 'And I imagine that the fear comes because you have a strong need for material security. It makes sense?'},
#   {'agent': 'agente intrigante',
#    'message': "Total. Good to find that out, I hadn't even realized it."},
#   {'agent': 'agente empático',
#    'message': 'And the disappointment I think came because you need greater reciprocity and attention to the years of dedication and it seems that this is not being met...'},
#   {'agent': 'agente intrigante',
#    'message': "Yes, in several situations where the university needed me, I was there. Now that I need it, and it's fair, they don't help me."},
#   {'agent': 'agente empático', 'message': 'Yes, I understand.'},
#   {'agent': 'agente intrigante',
#    'message': "It's understandable that you feel let down by the university after all the effort you've put in."},
#   {'agent': 'agente empático',
#    'message': "Yes, it's just frustrating to feel like my hard work isn't being recognized."}],
#  [{'agent': 'agente intrigante',
#    'message': "Yesterday I came home and the sink was once again full of dirty dishes. The guy doesn't care. I've already asked him to wash it as he cooks so it doesn't accumulate, but it's no use! I can not take it anymore."},
#   {'agent': 'agente empático',
#    'message': "I'm listening to you and realizing that there's anger, frustration there, does that make sense?"},
#   {'agent': 'agente intrigante', 'message': 'Yes, and tiredness as well.'},
#   {'agent': 'agente empático',
#    'message': 'And perhaps these feelings are present because you need reciprocity and respect.'},
#   {'agent': 'agente intrigante',
#    'message': "That's it, I really need it. Of consideration as well."},
#   {'agent': 'agente empático',
#    'message': "It sounds like you've been feeling overwhelmed by the situation."},
#   {'agent': 'agente intrigante',
#    'message': "Yes, exactly. I feel like I'm the only one taking care of things in the house."},
#   {'agent': 'agente empático',
#    'message': "It must be exhausting to constantly feel like you're carrying all the responsibility."},
#   {'agent': 'agente intrigante',
#    'message': "It really is. I just wish he would listen and understand how I'm feeling."},
#   {'agent': 'agente empático',
#    'message': "It sounds like you're seeking understanding and support from him."},
#   {'agent': 'agente intrigante',
#    'message': "Yes, that's exactly it. I feel like I'm not being heard."},
#   {'agent': 'agente empático',
#    'message': "It's important to feel heard and validated in your feelings."}],
#  [{'agent': 'agente intrigante',
#    'message': "She didn't give a signal and crossed in front of me. If I hadn't been paying close attention, I would have gotten it right. I got mad because people ignore others and go in. Why so much of a rush? I don't like honking and swearing in traffic, but sometimes I can't stand it."},
#   {'agent': 'agente empático',
#    'message': 'Yes, I hear anger and fear. Anger at her attitude, but also fear at the possible consequences. That?'},
#   {'agent': 'agente intrigante',
#    'message': "Fear... it's true. I hadn't thought about fear. And when I feel afraid I usually become more explosive."},
#   {'agent': 'agente empático',
#    'message': 'Yes, maybe because safety is very important to you...'},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, even more so with a child in the car.'},
#   {'agent': 'agente empático',
#    'message': 'I can imagine how important it is to keep your child safe. It must be tough when other drivers disregard that.'},
#   {'agent': 'agente intrigante',
#    'message': "It is tough. I just want to protect my family and it's hard when others don't consider that."},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you have a strong need for security and protection for your loved ones.'},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, exactly. I just want to make sure they are safe.'},
#   {'agent': 'agente empático',
#    'message': "It must be frustrating when others don't share the same values or priorities."},
#   {'agent': 'agente intrigante',
#    'message': 'Definitely. It feels like no one cares about anyone else these days.'},
#   {'agent': 'agente empático',
#    'message': "It sounds like you're feeling a bit disillusioned with the way people behave on the road."}],
#  [{'agent': 'agente intrigante',
#    'message': "My boss simply doesn’t recognize the effort I make. I stay late, meet deadlines, but he only points out what needs to be done. I'm exhausted and unmotivated. "},
#   {'agent': 'agente empático',
#    'message': 'I see this makes you really sad and discouraged. You would like to have the feeling that you are being seen.'},
#   {'agent': 'agente intrigante',
#    'message': "Exactly, it's as if I were invisible. "},
#   {'agent': 'agente empático',
#    'message': 'It seems that what you are really looking for is recognition and consideration. '},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, that would make a big difference to me.'},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you are feeling unappreciated and undervalued in your work.'},
#   {'agent': 'agente intrigante',
#    'message': "Definitely, it's really frustrating to put in so much effort and not feel acknowledged."},
#   {'agent': 'agente empático',
#    'message': "It must be really tough to continue giving your best when you don't feel like it's making a difference."},
#   {'agent': 'agente intrigante',
#    'message': "It really is. I feel like I'm stuck in a cycle of working hard and not getting any recognition."},
#   {'agent': 'agente empático',
#    'message': 'That sounds really disheartening. Have you tried talking to your boss about how you feel?'},
#   {'agent': 'agente intrigante',
#    'message': "I have, but it doesn't seem to change anything. It's like talking to a wall."},
#   {'agent': 'agente empático',
#    'message': 'It must be really disheartening to feel like your efforts are going unnoticed despite voicing your concerns.'}],
#  [{'agent': 'agente intrigante',
#    'message': "Every time I try to talk to my sister about our travel plans, she changes the subject. I feel like she's not taking it seriously. "},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you are feeling alone and worried about her commitment, am I right? '},
#   {'agent': 'agente intrigante',
#    'message': "Yes, that's it. I want her to understand that she is important to me and that I need company in this. "},
#   {'agent': 'agente empático',
#    'message': 'Maybe deep down, you are looking for her cooperation so that you feel connected in this project together. '},
#   {'agent': 'agente intrigante',
#    'message': 'Exactly, I want to feel like we’re on the same page.'},
#   {'agent': 'agente empático',
#    'message': 'It must be frustrating to feel like you’re not getting the support you need from someone close to you. '},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, it is. I just wish she would prioritize our plans like I do. '},
#   {'agent': 'agente empático',
#    'message': 'It seems like you value the idea of teamwork and shared experiences. '},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I do. It’s important to me to have that bond with my sister. '},
#   {'agent': 'agente empático',
#    'message': 'Have you tried expressing these feelings to her directly? '},
#   {'agent': 'agente intrigante',
#    'message': 'I have, but she always dismisses it or changes the subject. '},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you’re feeling dismissed and unheard. '}],
#  [{'agent': 'agente intrigante',
#    'message': 'Whenever I see news about the environment, I feel enormous anguish. It seems like no one cares enough to make real changes. '},
#   {'agent': 'agente empático',
#    'message': 'You seem to be carrying great concern and sadness regarding the future of our planet, does this resonate with you? '},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, it is a feeling of helplessness. '},
#   {'agent': 'agente empático',
#    'message': 'And perhaps this sadness comes from a place where there is a lack of support and communion with the same values \u200b\u200bas yours. '},
#   {'agent': 'agente intrigante',
#    'message': "That's right, I want everyone to do their part."},
#   {'agent': 'agente empático',
#    'message': "It must be frustrating to feel like you're the only one who cares about such an important issue."},
#   {'agent': 'agente intrigante',
#    'message': 'Very frustrating indeed. Sometimes I feel like giving up.'},
#   {'agent': 'agente empático',
#    'message': "It's completely understandable to feel that way when it seems like progress is so slow."},
#   {'agent': 'agente intrigante',
#    'message': "Yes, it's hard to stay motivated when it feels like nothing is changing."},
#   {'agent': 'agente empático',
#    'message': "I hear you. It's important to remember that even small actions can make a difference."},
#   {'agent': 'agente intrigante',
#    'message': "You're right. I'll try to focus on the positive changes that are happening."},
#   {'agent': 'agente empático',
#    'message': "That sounds like a good plan. It's also important to take care of yourself during these challenging times."}],
#  [{'agent': 'agente intrigante',
#    'message': 'I feel like no one understands me. I try to explain my feelings, but people seem indifferent. '},
#   {'agent': 'agente empático',
#    'message': 'It seems like you are seeking connection and feel distant when you are not understood. Does this make sense to you? '},
#   {'agent': 'agente intrigante', 'message': 'Yes, exactly that. '},
#   {'agent': 'agente empático',
#    'message': 'So, deep down, you want to be heard and understood, even if they don’t agree with you. '},
#   {'agent': 'agente intrigante',
#    'message': 'That’s it, I want to feel part of something.'},
#   {'agent': 'agente empático',
#    'message': "I can imagine how lonely and frustrating it must be to feel like you're talking to a wall."},
#   {'agent': 'agente intrigante',
#    'message': "It really is. It's like I'm screaming into the void and no one hears me."},
#   {'agent': 'agente empático',
#    'message': 'It must be exhausting to constantly feel unheard and overlooked.'},
#   {'agent': 'agente intrigante',
#    'message': "It is. I feel like I'm invisible sometimes."},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you need a safe space where you can truly express yourself without fear of judgment.'},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, exactly. I just want to feel accepted for who I am.'},
#   {'agent': 'agente empático',
#    'message': "It's important to feel validated and respected in your relationships."}],
#  [{'agent': 'agente intrigante',
#    'message': "My son won’t stop crying at night and I don’t know what to do anymore. I'm exhausted. "},
#   {'agent': 'agente empático',
#    'message': 'In addition to exhaustion, I understand that you feel lost and insecure.'},
#   {'agent': 'agente intrigante',
#    'message': "Yes, I'm at my limit, I need help. "},
#   {'agent': 'agente empático',
#    'message': 'Maybe you are looking for more clarity and support from someone. '},
#   {'agent': 'agente intrigante',
#    'message': 'Of course, I need to understand what is happening to reduce the tension.'},
#   {'agent': 'agente empático',
#    'message': "It sounds like you're feeling overwhelmed and in need of some relief."},
#   {'agent': 'agente intrigante',
#    'message': "Yes, exactly. I can't keep up with this situation."},
#   {'agent': 'agente empático',
#    'message': "It seems like you're also feeling a bit helpless and frustrated."},
#   {'agent': 'agente intrigante',
#    'message': "Yes, I feel like I've tried everything and nothing is working."},
#   {'agent': 'agente empático',
#    'message': 'It must be really hard to see your son in distress and not know how to help.'},
#   {'agent': 'agente intrigante',
#    'message': 'It breaks my heart to hear him cry and not be able to soothe him.'},
#   {'agent': 'agente empático',
#    'message': "It sounds like you're experiencing a lot of empathy for your son's emotions."}],
#  [{'agent': 'agente intrigante',
#    'message': "I can’t concentrate on my studies. Every five minutes, I pick up my cell phone to see if there's anything new. "},
#   {'agent': 'agente empático',
#    'message': 'I notice that you are apprehensive about not being able to study and disappointed with your lack of focus. And that?'},
#   {'agent': 'agente intrigante',
#    'message': "Yes, that way I won’t pass the year. And it's true, they're disappointed in me too."},
#   {'agent': 'agente empático',
#    'message': 'If you could be less distracted, would that meet your desire for efficiency and safety? '},
#   {'agent': 'agente intrigante', 'message': 'That would help a lot, yes.'},
#   {'agent': 'agente empático',
#    'message': "It seems like you're feeling overwhelmed by the pressure to perform well in your studies. "},
#   {'agent': 'agente intrigante',
#    'message': "Yes, I feel a lot of pressure to succeed and meet everyone's expectations. "},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you have a strong need for approval and validation from others. '},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I always seek recognition for my efforts and hard work. '},
#   {'agent': 'agente empático',
#    'message': 'Maybe setting some boundaries with your phone and creating a study routine could help you focus better. '},
#   {'agent': 'agente intrigante',
#    'message': "That's a good idea. I'll try to implement some new habits to improve my concentration. "},
#   {'agent': 'agente empático',
#    'message': "It's important to take care of yourself and prioritize your well-being during stressful times. "}],
#  [{'agent': 'agente intrigante',
#    'message': "I'm so relieved to have finished the project on time. It was a race against the clock. "},
#   {'agent': 'agente empático',
#    'message': 'Wow, you must be feeling accomplished having met the deadline and satisfied with your ability to manage time. '},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I was worried I wouldn’t make it. '},
#   {'agent': 'agente empático',
#    'message': 'So, this also touches on your need for confidence in your abilities and competence to overcome challenges. '},
#   {'agent': 'agente intrigante', 'message': "Exactly, that's it."},
#   {'agent': 'agente empático',
#    'message': 'It must have been quite stressful for you to have that weight on your shoulders.'},
#   {'agent': 'agente intrigante',
#    'message': 'Definitely, I was feeling a lot of pressure.'},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you value meeting your commitments and expectations.'},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I always strive to do my best.'},
#   {'agent': 'agente empático',
#    'message': 'I can see that you have a strong sense of responsibility.'},
#   {'agent': 'agente intrigante',
#    'message': 'Thank you for acknowledging that.'},
#   {'agent': 'agente empático',
#    'message': "You're welcome, it's important to recognize your hard work and dedication."}],
#  [{'agent': 'agente intrigante',
#    'message': "My son finally started walking. I'm so proud! "},
#   {'agent': 'agente empático',
#    'message': 'How wonderful! You seem to be in awe of his achievements. '},
#   {'agent': 'agente intrigante',
#    'message': "And I am. It's a big milestone. "},
#   {'agent': 'agente empático',
#    'message': 'This reflects your need to celebrate special moments and support his growth. '},
#   {'agent': 'agente intrigante',
#    'message': 'Of course, it is very important to me.'},
#   {'agent': 'agente empático',
#    'message': 'I see how much joy and pride this brings you. '},
#   {'agent': 'agente intrigante',
#    'message': "Yes, definitely. It's a big moment for our family. "},
#   {'agent': 'agente empático',
#    'message': 'It must also show your need for connection and closeness with your son. '},
#   {'agent': 'agente intrigante',
#    'message': "Absolutely, it's a bonding experience for us. "},
#   {'agent': 'agente empático',
#    'message': "It's great that you're able to recognize and appreciate these moments. "},
#   {'agent': 'agente intrigante',
#    'message': 'Thank you, it means a lot to me. '},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you have a strong emotional connection with your son. '}],
#  [{'agent': 'agente intrigante',
#    'message': 'I managed to solve that complicated problem at work today. '},
#   {'agent': 'agente empático',
#    'message': 'Oops, you must be feeling very confident and also relieved to have found a solution. '},
#   {'agent': 'agente intrigante',
#    'message': 'Actually, it was a big problem. '},
#   {'agent': 'agente empático',
#    'message': 'This shows your need for effectiveness and to be recognized for your ability to solve problems. '},
#   {'agent': 'agente intrigante', 'message': 'Yes, that motivates me.'},
#   {'agent': 'agente empático',
#    'message': "It's great that you were able to tap into your strengths and tackle the problem head-on."},
#   {'agent': 'agente intrigante',
#    'message': 'Thank you for acknowledging that. It feels good to be appreciated.'},
#   {'agent': 'agente empático',
#    'message': 'I can see how important recognition is to you in your work.'},
#   {'agent': 'agente intrigante',
#    'message': "Absolutely, it's one of the things that keeps me going."},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you thrive on challenges and pushing yourself to find solutions.'},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I do enjoy a good challenge and the satisfaction of overcoming it.'},
#   {'agent': 'agente empático',
#    'message': "It's impressive how you can maintain that level of determination and focus."}],
#  [{'agent': 'agente intrigante',
#    'message': 'I finally managed to save enough to buy my car. '},
#   {'agent': 'agente empático',
#    'message': 'Congratulations! You must be feeling very accomplished and even admired by your own abilities. '},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, it was a goal I pursued for a long time. '},
#   {'agent': 'agente empático',
#    'message': 'So, this meets your need for autonomy and effectiveness in achieving personal goals. '},
#   {'agent': 'agente intrigante',
#    'message': 'Exactly, it’s an incredible feeling.'},
#   {'agent': 'agente empático',
#    'message': 'I imagine that you are also feeling a sense of relief now that you have achieved this goal. '},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, absolutely. It feels like a weight has been lifted off my shoulders. '},
#   {'agent': 'agente empático',
#    'message': "It's important to acknowledge and celebrate your hard work paying off. "},
#   {'agent': 'agente intrigante',
#    'message': 'Thank you, I appreciate your kind words. '},
#   {'agent': 'agente empático',
#    'message': 'Enjoy this moment of success and remember that you are capable of reaching your goals. '},
#   {'agent': 'agente intrigante',
#    'message': 'I will, thank you for reminding me of that. '},
#   {'agent': 'agente empático',
#    'message': "You're welcome. I'm here to support and celebrate your accomplishments with you."}],
#  [{'agent': 'agente intrigante',
#    'message': 'After months of practice, I played the piano in front of an audience for the first time. '},
#   {'agent': 'agente empático',
#    'message': 'This is fantastic! You must be feeling radiant and excited to share more of your talent. '},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I was nervous, but it went well. '},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you are seeking recognition and also want to challenge yourself to grow as a musician. '},
#   {'agent': 'agente intrigante',
#    'message': 'That’s right, I want to continue improving myself.'},
#   {'agent': 'agente empático',
#    'message': "It's great that you have this passion for music and the courage to share your talent with others."},
#   {'agent': 'agente intrigante',
#    'message': 'Thank you, music means everything to me.'},
#   {'agent': 'agente empático',
#    'message': 'I can see that music is a big part of your identity and brings you a lot of joy.'},
#   {'agent': 'agente intrigante',
#    'message': "Definitely, it's my way of expressing myself and connecting with others."},
#   {'agent': 'agente empático',
#    'message': "It's wonderful that you have found this creative outlet to express your emotions."},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, music helps me process my feelings and experiences in a unique way.'},
#   {'agent': 'agente empático',
#    'message': "It's amazing how art can have such a powerful impact on our emotional well-being."}],
#  [{'agent': 'agente intrigante',
#    'message': "I'm feeling so anxious about this job interview tomorrow. "},
#   {'agent': 'agente empático',
#    'message': 'You seem worried about the result and perhaps need more reassurance. And that? '},
#   {'agent': 'agente intrigante', 'message': "Yes, I'm very insecure. "},
#   {'agent': 'agente empático',
#    'message': 'Maybe you are looking for confidence and a little peace of mind to face this challenge. '},
#   {'agent': 'agente intrigante', 'message': 'That would help a lot.'},
#   {'agent': 'agente empático',
#    'message': "It's completely understandable to feel that way before a big event like a job interview."},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I just really want to make a good impression and get this opportunity.'},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you have a strong desire for success and validation in this situation.'},
#   {'agent': 'agente intrigante',
#    'message': "Absolutely. I've been working towards this for a long time and I really want it to pay off."},
#   {'agent': 'agente empático',
#    'message': "Your hard work and dedication are definitely shining through. It's important to acknowledge that."},
#   {'agent': 'agente intrigante',
#    'message': 'Thank you, I appreciate you recognizing that. It means a lot.'},
#   {'agent': 'agente empático',
#    'message': "It's important to remember to believe in yourself and your abilities, even in moments of doubt."}],
#  [{'agent': 'agente intrigante',
#    'message': "I can't stop thinking about the mistake I made at work. "},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you are afraid of the consequences and need to understand why you did what you did. Am I right? '},
#   {'agent': 'agente intrigante',
#    'message': 'Exactly, I wanted to understand what happened. '},
#   {'agent': 'agente empático',
#    'message': 'And this clarity would help you move forward and not make mistakes next time.'},
#   {'agent': 'agente intrigante', 'message': 'Yes definitely.'},
#   {'agent': 'agente empático',
#    'message': "It's important to acknowledge that we all make mistakes sometimes."},
#   {'agent': 'agente intrigante',
#    'message': "I appreciate your understanding. It's just hard not to dwell on it."},
#   {'agent': 'agente empático',
#    'message': 'I understand, it can be tough to let go of those feelings.'},
#   {'agent': 'agente intrigante', 'message': 'I feel like I let my team down.'},
#   {'agent': 'agente empático',
#    'message': "It's natural to feel that way, but remember that everyone makes mistakes."},
#   {'agent': 'agente intrigante',
#    'message': 'Thanks for reminding me of that. It helps to talk about it.'},
#   {'agent': 'agente empático',
#    'message': "I'm glad I could offer some support. It's important to be kind to yourself during these times."}],
#  [{'agent': 'agente intrigante',
#    'message': 'I feel so alone since I moved to this new city. '},
#   {'agent': 'agente empático',
#    'message': 'Yes, connection and company must be needed. '},
#   {'agent': 'agente intrigante', 'message': 'I miss having friends around. '},
#   {'agent': 'agente empático',
#    'message': 'I also imagine a sense of community in your new environment. '},
#   {'agent': 'agente intrigante',
#    'message': 'That would definitely make a big difference.'},
#   {'agent': 'agente empático',
#    'message': "It sounds like you're craving a sense of belonging."},
#   {'agent': 'agente intrigante',
#    'message': "Yes, exactly. I feel like I don't fit in here."},
#   {'agent': 'agente empático',
#    'message': 'It must be tough to feel like an outsider.'},
#   {'agent': 'agente intrigante',
#    'message': "It is. I thought moving would be exciting, but it's been harder than I expected."},
#   {'agent': 'agente empático',
#    'message': 'Change can be really challenging, especially when it involves leaving a familiar support system behind.'},
#   {'agent': 'agente intrigante',
#    'message': "That's true. I didn't realize how much I depended on my friends back home."},
#   {'agent': 'agente empático',
#    'message': "It's natural to feel that way. Transitioning to a new place takes time and effort."}],
#  [{'agent': 'agente intrigante',
#    'message': "My mother is sick and I have to take care of her, but I also have to work. It's too much. "},
#   {'agent': 'agente empático',
#    'message': 'You seem to be divided between responsibilities...'},
#   {'agent': 'agente intrigante',
#    'message': "Yes, divided and tired. I'm overwhelmed. "},
#   {'agent': 'agente empático',
#    'message': 'Perhaps you are looking for balance and support to manage these demands. '},
#   {'agent': 'agente intrigante', 'message': 'That would be ideal.'},
#   {'agent': 'agente empático',
#    'message': "It's understandable that you feel overwhelmed with everything on your plate."},
#   {'agent': 'agente intrigante',
#    'message': "Yes, it's a lot to handle all at once."},
#   {'agent': 'agente empático',
#    'message': 'Have you considered seeking help or delegating some tasks to lighten your load?'},
#   {'agent': 'agente intrigante',
#    'message': "I have, but it's hard to find reliable help sometimes."},
#   {'agent': 'agente empático',
#    'message': 'It must be difficult to juggle so many responsibilities.'},
#   {'agent': 'agente intrigante',
#    'message': "It really is. I feel like I'm being pulled in different directions."},
#   {'agent': 'agente empático',
#    'message': "It's important to take care of yourself too during this challenging time."}],
#  [{'agent': 'agente intrigante',
#    'message': "My partner and I have been arguing a lot lately. I'm frustrated. "},
#   {'agent': 'agente empático',
#    'message': 'You seem to be feeling worn out and need harmony. Am I interpreting correctly? '},
#   {'agent': 'agente intrigante',
#    'message': 'Not just harmony, more reciprocity on his part. '},
#   {'agent': 'agente empático',
#    'message': 'I understood. As if you wanted support to resolve this together. '},
#   {'agent': 'agente intrigante',
#    'message': 'Exactly, that would help us sort things out.'},
#   {'agent': 'agente empático',
#    'message': "It sounds like you're looking for more collaboration and understanding in your relationship."},
#   {'agent': 'agente intrigante',
#    'message': "Yes, that's it. I feel like I'm the only one making an effort to make things work."},
#   {'agent': 'agente empático',
#    'message': "It must be tough feeling like you're carrying the weight of the relationship on your shoulders."},
#   {'agent': 'agente intrigante', 'message': "It is, it's exhausting."},
#   {'agent': 'agente empático',
#    'message': "Have you talked to your partner about how you're feeling?"},
#   {'agent': 'agente intrigante',
#    'message': "I tried, but it seems like he's not really listening."},
#   {'agent': 'agente empático',
#    'message': "It's important for both partners to feel heard and understood in a relationship."}],
#  [{'agent': 'agente intrigante',
#    'message': "My dog \u200b\u200bran away and I'm so worried. "},
#   {'agent': 'agente empático',
#    'message': 'You seem to be distressed by the lack of information about how he is doing.'},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I feel desperate thinking about the possibilities. '},
#   {'agent': 'agente empático',
#    'message': 'Yes, I wish I could hope that he is okay and have some company to help find him, is that it? '},
#   {'agent': 'agente intrigante', 'message': 'Yes, any help would be welcome.'},
#   {'agent': 'agente empático',
#    'message': 'It must be really hard not knowing where your dog is. '},
#   {'agent': 'agente intrigante',
#    'message': 'It is, I keep imagining all sorts of scenarios in my head. '},
#   {'agent': 'agente empático',
#    'message': 'It makes sense that you feel overwhelmed by all the possibilities. '},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I just want him to be safe and come back home. '},
#   {'agent': 'agente empático',
#    'message': 'I understand, your dog is like family to you. '},
#   {'agent': 'agente intrigante', 'message': 'Yes, he is my best friend. '},
#   {'agent': 'agente empático',
#    'message': 'I hope you find him soon and everything turns out okay.'}],
#  [{'agent': 'agente intrigante',
#    'message': "I'm trying to lose weight, but it's so hard to stick to the diet. "},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you are frustrated and need more motivation. That makes sense? '},
#   {'agent': 'agente intrigante', 'message': 'Yes, it’s a constant battle. '},
#   {'agent': 'agente empático',
#    'message': 'I also understand that you are trying to take care of something very important, which is health, but that you need more efficiency. '},
#   {'agent': 'agente intrigante', 'message': "That's right."},
#   {'agent': 'agente empático',
#    'message': 'Have you tried finding a support system to help you stay motivated during this process?'},
#   {'agent': 'agente intrigante',
#    'message': "I have tried, but sometimes it feels like no one understands the struggle I'm going through."},
#   {'agent': 'agente empático',
#    'message': "It must be tough feeling like you're going through this alone."},
#   {'agent': 'agente intrigante',
#    'message': 'It is. Sometimes I just wish someone would truly listen and give me the encouragement I need.'},
#   {'agent': 'agente empático',
#    'message': "It's important to feel supported and understood when you're going through a challenging journey like this."},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, it really is. I guess I just need to keep pushing through and find my own inner strength.'},
#   {'agent': 'agente empático',
#    'message': "Remember that it's okay to ask for help when you need it. You don't have to do this alone."}],
#  [{'agent': 'agente intrigante',
#    'message': 'I feel like my teenage son is moving away from me. '},
#   {'agent': 'agente empático',
#    'message': 'You seem to be worried about your connection and even his safety. And that? '},
#   {'agent': 'agente intrigante',
#    'message': "Yes, I feel like I'm losing my son. "},
#   {'agent': 'agente empático',
#    'message': 'I also notice a need for clarity as to why this happened and how it could change.'},
#   {'agent': 'agente intrigante', 'message': 'This is very important to me.'},
#   {'agent': 'agente empático',
#    'message': 'I can imagine how difficult it must be for you to feel that distance growing.'},
#   {'agent': 'agente intrigante',
#    'message': "It's heartbreaking, really. I just want to understand what's going on."},
#   {'agent': 'agente empático',
#    'message': "Have you tried talking to your son about how you're feeling?"},
#   {'agent': 'agente intrigante',
#    'message': "I have, but he just shuts down and doesn't want to talk."},
#   {'agent': 'agente empático',
#    'message': 'That must be so frustrating for you.'},
#   {'agent': 'agente intrigante',
#    'message': 'It really is. I just want to know how to help him.'},
#   {'agent': 'agente empático',
#    'message': "Maybe he's going through a tough time and doesn't know how to express it."}],
#  [{'agent': 'agente intrigante',
#    'message': "I'm feeling pressured when deciding to choose a career. "},
#   {'agent': 'agente empático',
#    'message': 'Behind the "pressure" I notice that there is a feeling of loneliness and lack of company and even more understanding of the options. '},
#   {'agent': 'agente intrigante',
#    'message': 'No, I already have all the information. I want to be able to decide alone and with more time.'},
#   {'agent': 'agente empático',
#    'message': 'Maybe you are looking for space and autonomy to make the right choice for you.'},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I need that: space and autonomy.'},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you value independence and taking your time to make important decisions.'},
#   {'agent': 'agente intrigante',
#    'message': "Yes, exactly. I want to make sure I'm choosing the right path for myself."},
#   {'agent': 'agente empático',
#    'message': "It's important to prioritize your own needs and desires when making career decisions."},
#   {'agent': 'agente intrigante',
#    'message': 'I agree. I just hope I can make the right choice in the end.'},
#   {'agent': 'agente empático',
#    'message': "It's okay to feel uncertain, but trust that you have the ability to make the best decision for yourself."},
#   {'agent': 'agente intrigante',
#    'message': 'Thank you for reassuring me. I really appreciate your support.'},
#   {'agent': 'agente empático',
#    'message': "Of course, I'm here to listen and help however I can."}]]

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

sid = SentimentIntensityAnalyzer()

for text in processed_texts:
    for message in text:

        tokens = word_tokenize(message['message'].lower())
        filtered_tokens = [token for token in tokens if token not in stopwords.words('english')]

        lemmatizer = WordNetLemmatizer()
        lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

        processed_text = ' '.join(lemmatized_tokens)
        message.update(sid.polarity_scores(processed_text))

processed_texts
# Out:
# [[{'agent': 'agente intrigante',
#    'message': "I don't know what to do. I was waiting to get out of my doctoral scholarship at the university, but they're dragging me around and I don't think I can get out. A month ago I had a meeting, they said that they really liked my line of research and that they didn't let me down. Yesterday, everything changed. They want me to pay, but I can't afford it. After years of dedication as a teacher, I was counting on that money. It would be very important for my income. I don't even know what to think.",
#    'neg': 0.03,
#    'neu': 0.837,
#    'pos': 0.133,
#    'compound': 0.5849},
#   {'agent': 'agente empático',
#    'message': 'I was listening to you and I think I identified some feelings there. Maybe sadness, frustration, disappointment... Could it be?',
#    'neg': 0.554,
#    'neu': 0.357,
#    'pos': 0.089,
#    'compound': -0.8316},
#   {'agent': 'agente intrigante',
#    'message': 'It could be, yes. There are certainly three. Disappointment, anxiety too.',
#    'neg': 0.413,
#    'neu': 0.165,
#    'pos': 0.421,
#    'compound': 0.0258},
#   {'agent': 'agente empático',
#    'message': "Hmm. Maybe you're also afraid of running out of income?",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente intrigante',
#    'message': "Yes true. He's afraid too. I didn't realize it and it could be influenced in my reactivity towards them.",
#    'neg': 0.0,
#    'neu': 0.593,
#    'pos': 0.407,
#    'compound': 0.6705},
#   {'agent': 'agente empático',
#    'message': 'And I imagine that the fear comes because you have a strong need for material security. It makes sense?',
#    'neg': 0.215,
#    'neu': 0.403,
#    'pos': 0.383,
#    'compound': 0.3612},
#   {'agent': 'agente intrigante',
#    'message': "Total. Good to find that out, I hadn't even realized it.",
#    'neg': 0.0,
#    'neu': 0.633,
#    'pos': 0.367,
#    'compound': 0.4404},
#   {'agent': 'agente empático',
#    'message': 'And the disappointment I think came because you need greater reciprocity and attention to the years of dedication and it seems that this is not being met...',
#    'neg': 0.209,
#    'neu': 0.633,
#    'pos': 0.158,
#    'compound': -0.2023},
#   {'agent': 'agente intrigante',
#    'message': "Yes, in several situations where the university needed me, I was there. Now that I need it, and it's fair, they don't help me.",
#    'neg': 0.158,
#    'neu': 0.491,
#    'pos': 0.351,
#    'compound': 0.4102},
#   {'agent': 'agente empático',
#    'message': 'Yes, I understand.',
#    'neg': 0.0,
#    'neu': 0.27,
#    'pos': 0.73,
#    'compound': 0.4019},
#   {'agent': 'agente intrigante',
#    'message': "It's understandable that you feel let down by the university after all the effort you've put in.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente empático',
#    'message': "Yes, it's just frustrating to feel like my hard work isn't being recognized.",
#    'neg': 0.297,
#    'neu': 0.345,
#    'pos': 0.359,
#    'compound': 0.2263}],
#  [{'agent': 'agente intrigante',
#    'message': "Yesterday I came home and the sink was once again full of dirty dishes. The guy doesn't care. I've already asked him to wash it as he cooks so it doesn't accumulate, but it's no use! I can not take it anymore.",
#    'neg': 0.234,
#    'neu': 0.766,
#    'pos': 0.0,
#    'compound': -0.7022},
#   {'agent': 'agente empático',
#    'message': "I'm listening to you and realizing that there's anger, frustration there, does that make sense?",
#    'neg': 0.531,
#    'neu': 0.469,
#    'pos': 0.0,
#    'compound': -0.7783},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, and tiredness as well.',
#    'neg': 0.0,
#    'neu': 0.172,
#    'pos': 0.828,
#    'compound': 0.5859},
#   {'agent': 'agente empático',
#    'message': 'And perhaps these feelings are present because you need reciprocity and respect.',
#    'neg': 0.0,
#    'neu': 0.465,
#    'pos': 0.535,
#    'compound': 0.5574},
#   {'agent': 'agente intrigante',
#    'message': "That's it, I really need it. Of consideration as well.",
#    'neg': 0.0,
#    'neu': 0.629,
#    'pos': 0.371,
#    'compound': 0.3321},
#   {'agent': 'agente empático',
#    'message': "It sounds like you've been feeling overwhelmed by the situation.",
#    'neg': 0.0,
#    'neu': 0.366,
#    'pos': 0.634,
#    'compound': 0.4939},
#   {'agent': 'agente intrigante',
#    'message': "Yes, exactly. I feel like I'm the only one taking care of things in the house.",
#    'neg': 0.0,
#    'neu': 0.455,
#    'pos': 0.545,
#    'compound': 0.8126},
#   {'agent': 'agente empático',
#    'message': "It must be exhausting to constantly feel like you're carrying all the responsibility.",
#    'neg': 0.227,
#    'neu': 0.545,
#    'pos': 0.227,
#    'compound': 0.0},
#   {'agent': 'agente intrigante',
#    'message': "It really is. I just wish he would listen and understand how I'm feeling.",
#    'neg': 0.0,
#    'neu': 0.527,
#    'pos': 0.473,
#    'compound': 0.5413},
#   {'agent': 'agente empático',
#    'message': "It sounds like you're seeking understanding and support from him.",
#    'neg': 0.0,
#    'neu': 0.435,
#    'pos': 0.565,
#    'compound': 0.6369},
#   {'agent': 'agente intrigante',
#    'message': "Yes, that's exactly it. I feel like I'm not being heard.",
#    'neg': 0.0,
#    'neu': 0.49,
#    'pos': 0.51,
#    'compound': 0.6369},
#   {'agent': 'agente empático',
#    'message': "It's important to feel heard and validated in your feelings.",
#    'neg': 0.0,
#    'neu': 0.366,
#    'pos': 0.634,
#    'compound': 0.4939}],
#  [{'agent': 'agente intrigante',
#    'message': "She didn't give a signal and crossed in front of me. If I hadn't been paying close attention, I would have gotten it right. I got mad because people ignore others and go in. Why so much of a rush? I don't like honking and swearing in traffic, but sometimes I can't stand it.",
#    'neg': 0.226,
#    'neu': 0.724,
#    'pos': 0.05,
#    'compound': -0.7244},
#   {'agent': 'agente empático',
#    'message': 'Yes, I hear anger and fear. Anger at her attitude, but also fear at the possible consequences. That?',
#    'neg': 0.642,
#    'neu': 0.233,
#    'pos': 0.126,
#    'compound': -0.9022},
#   {'agent': 'agente intrigante',
#    'message': "Fear... it's true. I hadn't thought about fear. And when I feel afraid I usually become more explosive.",
#    'neg': 0.352,
#    'neu': 0.495,
#    'pos': 0.154,
#    'compound': -0.5574},
#   {'agent': 'agente empático',
#    'message': 'Yes, maybe because safety is very important to you...',
#    'neg': 0.0,
#    'neu': 0.215,
#    'pos': 0.785,
#    'compound': 0.743},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, even more so with a child in the car.',
#    'neg': 0.0,
#    'neu': 0.526,
#    'pos': 0.474,
#    'compound': 0.4019},
#   {'agent': 'agente empático',
#    'message': 'I can imagine how important it is to keep your child safe. It must be tough when other drivers disregard that.',
#    'neg': 0.271,
#    'neu': 0.376,
#    'pos': 0.353,
#    'compound': 0.2732},
#   {'agent': 'agente intrigante',
#    'message': "It is tough. I just want to protect my family and it's hard when others don't consider that.",
#    'neg': 0.246,
#    'neu': 0.424,
#    'pos': 0.331,
#    'compound': 0.25},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you have a strong need for security and protection for your loved ones.',
#    'neg': 0.0,
#    'neu': 0.248,
#    'pos': 0.752,
#    'compound': 0.9022},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, exactly. I just want to make sure they are safe.',
#    'neg': 0.0,
#    'neu': 0.179,
#    'pos': 0.821,
#    'compound': 0.802},
#   {'agent': 'agente empático',
#    'message': "It must be frustrating when others don't share the same values or priorities.",
#    'neg': 0.63,
#    'neu': 0.37,
#    'pos': 0.0,
#    'compound': -0.7026},
#   {'agent': 'agente intrigante',
#    'message': 'Definitely. It feels like no one cares about anyone else these days.',
#    'neg': 0.0,
#    'neu': 0.373,
#    'pos': 0.627,
#    'compound': 0.8126},
#   {'agent': 'agente empático',
#    'message': "It sounds like you're feeling a bit disillusioned with the way people behave on the road.",
#    'neg': 0.209,
#    'neu': 0.504,
#    'pos': 0.288,
#    'compound': 0.0258}],
#  [{'agent': 'agente intrigante',
#    'message': "My boss simply doesn’t recognize the effort I make. I stay late, meet deadlines, but he only points out what needs to be done. I'm exhausted and unmotivated. ",
#    'neg': 0.274,
#    'neu': 0.726,
#    'pos': 0.0,
#    'compound': -0.5994},
#   {'agent': 'agente empático',
#    'message': 'I see this makes you really sad and discouraged. You would like to have the feeling that you are being seen.',
#    'neg': 0.414,
#    'neu': 0.325,
#    'pos': 0.26,
#    'compound': -0.5222},
#   {'agent': 'agente intrigante',
#    'message': "Exactly, it's as if I were invisible. ",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente empático',
#    'message': 'It seems that what you are really looking for is recognition and consideration. ',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, that would make a big difference to me.',
#    'neg': 0.0,
#    'neu': 0.597,
#    'pos': 0.403,
#    'compound': 0.4019},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you are feeling unappreciated and undervalued in your work.',
#    'neg': 0.278,
#    'neu': 0.309,
#    'pos': 0.412,
#    'compound': 0.0772},
#   {'agent': 'agente intrigante',
#    'message': "Definitely, it's really frustrating to put in so much effort and not feel acknowledged.",
#    'neg': 0.248,
#    'neu': 0.543,
#    'pos': 0.209,
#    'compound': -0.1263},
#   {'agent': 'agente empático',
#    'message': "It must be really tough to continue giving your best when you don't feel like it's making a difference.",
#    'neg': 0.208,
#    'neu': 0.426,
#    'pos': 0.366,
#    'compound': 0.6073},
#   {'agent': 'agente intrigante',
#    'message': "It really is. I feel like I'm stuck in a cycle of working hard and not getting any recognition.",
#    'neg': 0.258,
#    'neu': 0.531,
#    'pos': 0.211,
#    'compound': 0.0972},
#   {'agent': 'agente empático',
#    'message': 'That sounds really disheartening. Have you tried talking to your boss about how you feel?',
#    'neg': 0.34,
#    'neu': 0.66,
#    'pos': 0.0,
#    'compound': -0.4754},
#   {'agent': 'agente intrigante',
#    'message': "I have, but it doesn't seem to change anything. It's like talking to a wall.",
#    'neg': 0.0,
#    'neu': 0.737,
#    'pos': 0.263,
#    'compound': 0.3612},
#   {'agent': 'agente empático',
#    'message': 'It must be really disheartening to feel like your efforts are going unnoticed despite voicing your concerns.',
#    'neg': 0.208,
#    'neu': 0.606,
#    'pos': 0.186,
#    'compound': -0.0847}],
#  [{'agent': 'agente intrigante',
#    'message': "Every time I try to talk to my sister about our travel plans, she changes the subject. I feel like she's not taking it seriously. ",
#    'neg': 0.105,
#    'neu': 0.741,
#    'pos': 0.154,
#    'compound': 0.2023},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you are feeling alone and worried about her commitment, am I right? ',
#    'neg': 0.328,
#    'neu': 0.156,
#    'pos': 0.516,
#    'compound': 0.34},
#   {'agent': 'agente intrigante',
#    'message': "Yes, that's it. I want her to understand that she is important to me and that I need company in this. ",
#    'neg': 0.0,
#    'neu': 0.408,
#    'pos': 0.592,
#    'compound': 0.5859},
#   {'agent': 'agente empático',
#    'message': 'Maybe deep down, you are looking for her cooperation so that you feel connected in this project together. ',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente intrigante',
#    'message': 'Exactly, I want to feel like we’re on the same page.',
#    'neg': 0.0,
#    'neu': 0.441,
#    'pos': 0.559,
#    'compound': 0.4215},
#   {'agent': 'agente empático',
#    'message': 'It must be frustrating to feel like you’re not getting the support you need from someone close to you. ',
#    'neg': 0.206,
#    'neu': 0.426,
#    'pos': 0.369,
#    'compound': 0.3182},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, it is. I just wish she would prioritize our plans like I do. ',
#    'neg': 0.0,
#    'neu': 0.275,
#    'pos': 0.725,
#    'compound': 0.7845},
#   {'agent': 'agente empático',
#    'message': 'It seems like you value the idea of teamwork and shared experiences. ',
#    'neg': 0.0,
#    'neu': 0.354,
#    'pos': 0.646,
#    'compound': 0.743},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I do. It’s important to me to have that bond with my sister. ',
#    'neg': 0.0,
#    'neu': 0.308,
#    'pos': 0.692,
#    'compound': 0.5423},
#   {'agent': 'agente empático',
#    'message': 'Have you tried expressing these feelings to her directly? ',
#    'neg': 0.0,
#    'neu': 0.667,
#    'pos': 0.333,
#    'compound': 0.128},
#   {'agent': 'agente intrigante',
#    'message': 'I have, but she always dismisses it or changes the subject. ',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you’re feeling dismissed and unheard. ',
#    'neg': 0.0,
#    'neu': 0.429,
#    'pos': 0.571,
#    'compound': 0.4588}],
#  [{'agent': 'agente intrigante',
#    'message': 'Whenever I see news about the environment, I feel enormous anguish. It seems like no one cares enough to make real changes. ',
#    'neg': 0.181,
#    'neu': 0.556,
#    'pos': 0.264,
#    'compound': 0.2023},
#   {'agent': 'agente empático',
#    'message': 'You seem to be carrying great concern and sadness regarding the future of our planet, does this resonate with you? ',
#    'neg': 0.207,
#    'neu': 0.5,
#    'pos': 0.293,
#    'compound': 0.296},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, it is a feeling of helplessness. ',
#    'neg': 0.425,
#    'neu': 0.0,
#    'pos': 0.575,
#    'compound': 0.0258},
#   {'agent': 'agente empático',
#    'message': 'And perhaps this sadness comes from a place where there is a lack of support and communion with the same values \u200b\u200bas yours. ',
#    'neg': 0.34,
#    'neu': 0.327,
#    'pos': 0.333,
#    'compound': -0.0258},
#   {'agent': 'agente intrigante',
#    'message': "That's right, I want everyone to do their part.",
#    'neg': 0.0,
#    'neu': 0.755,
#    'pos': 0.245,
#    'compound': 0.0772},
#   {'agent': 'agente empático',
#    'message': "It must be frustrating to feel like you're the only one who cares about such an important issue.",
#    'neg': 0.188,
#    'neu': 0.325,
#    'pos': 0.487,
#    'compound': 0.5574},
#   {'agent': 'agente intrigante',
#    'message': 'Very frustrating indeed. Sometimes I feel like giving up.',
#    'neg': 0.269,
#    'neu': 0.278,
#    'pos': 0.454,
#    'compound': 0.25},
#   {'agent': 'agente empático',
#    'message': "It's completely understandable to feel that way when it seems like progress is so slow.",
#    'neg': 0.0,
#    'neu': 0.569,
#    'pos': 0.431,
#    'compound': 0.6486},
#   {'agent': 'agente intrigante',
#    'message': "Yes, it's hard to stay motivated when it feels like nothing is changing.",
#    'neg': 0.096,
#    'neu': 0.342,
#    'pos': 0.562,
#    'compound': 0.7783},
#   {'agent': 'agente empático',
#    'message': "I hear you. It's important to remember that even small actions can make a difference.",
#    'neg': 0.0,
#    'neu': 0.816,
#    'pos': 0.184,
#    'compound': 0.2023},
#   {'agent': 'agente intrigante',
#    'message': "You're right. I'll try to focus on the positive changes that are happening.",
#    'neg': 0.0,
#    'neu': 0.66,
#    'pos': 0.34,
#    'compound': 0.5574},
#   {'agent': 'agente empático',
#    'message': "That sounds like a good plan. It's also important to take care of yourself during these challenging times.",
#    'neg': 0.0,
#    'neu': 0.333,
#    'pos': 0.667,
#    'compound': 0.875}],
#  [{'agent': 'agente intrigante',
#    'message': 'I feel like no one understands me. I try to explain my feelings, but people seem indifferent. ',
#    'neg': 0.141,
#    'neu': 0.547,
#    'pos': 0.312,
#    'compound': 0.296},
#   {'agent': 'agente empático',
#    'message': 'It seems like you are seeking connection and feel distant when you are not understood. Does this make sense to you? ',
#    'neg': 0.0,
#    'neu': 0.762,
#    'pos': 0.238,
#    'compound': 0.3612},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, exactly that. ',
#    'neg': 0.0,
#    'neu': 0.27,
#    'pos': 0.73,
#    'compound': 0.4019},
#   {'agent': 'agente empático',
#    'message': 'So, deep down, you want to be heard and understood, even if they don’t agree with you. ',
#    'neg': 0.0,
#    'neu': 0.513,
#    'pos': 0.487,
#    'compound': 0.4215},
#   {'agent': 'agente intrigante',
#    'message': 'That’s it, I want to feel part of something.',
#    'neg': 0.0,
#    'neu': 0.698,
#    'pos': 0.302,
#    'compound': 0.0772},
#   {'agent': 'agente empático',
#    'message': "I can imagine how lonely and frustrating it must be to feel like you're talking to a wall.",
#    'neg': 0.388,
#    'neu': 0.432,
#    'pos': 0.18,
#    'compound': -0.4404},
#   {'agent': 'agente intrigante',
#    'message': "It really is. It's like I'm screaming into the void and no one hears me.",
#    'neg': 0.229,
#    'neu': 0.527,
#    'pos': 0.244,
#    'compound': 0.046},
#   {'agent': 'agente empático',
#    'message': 'It must be exhausting to constantly feel unheard and overlooked.',
#    'neg': 0.474,
#    'neu': 0.526,
#    'pos': 0.0,
#    'compound': -0.3818},
#   {'agent': 'agente intrigante',
#    'message': "It is. I feel like I'm invisible sometimes.",
#    'neg': 0.0,
#    'neu': 0.615,
#    'pos': 0.385,
#    'compound': 0.3612},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you need a safe space where you can truly express yourself without fear of judgment.',
#    'neg': 0.0,
#    'neu': 0.354,
#    'pos': 0.646,
#    'compound': 0.8729},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, exactly. I just want to feel accepted for who I am.',
#    'neg': 0.0,
#    'neu': 0.247,
#    'pos': 0.753,
#    'compound': 0.6249},
#   {'agent': 'agente empático',
#    'message': "It's important to feel validated and respected in your relationships.",
#    'neg': 0.0,
#    'neu': 0.306,
#    'pos': 0.694,
#    'compound': 0.7003}],
#  [{'agent': 'agente intrigante',
#    'message': "My son won’t stop crying at night and I don’t know what to do anymore. I'm exhausted. ",
#    'neg': 0.609,
#    'neu': 0.391,
#    'pos': 0.0,
#    'compound': -0.7783},
#   {'agent': 'agente empático',
#    'message': 'In addition to exhaustion, I understand that you feel lost and insecure.',
#    'neg': 0.717,
#    'neu': 0.283,
#    'pos': 0.0,
#    'compound': -0.765},
#   {'agent': 'agente intrigante',
#    'message': "Yes, I'm at my limit, I need help. ",
#    'neg': 0.0,
#    'neu': 0.357,
#    'pos': 0.643,
#    'compound': 0.6597},
#   {'agent': 'agente empático',
#    'message': 'Maybe you are looking for more clarity and support from someone. ',
#    'neg': 0.0,
#    'neu': 0.357,
#    'pos': 0.643,
#    'compound': 0.6597},
#   {'agent': 'agente intrigante',
#    'message': 'Of course, I need to understand what is happening to reduce the tension.',
#    'neg': 0.315,
#    'neu': 0.685,
#    'pos': 0.0,
#    'compound': -0.3182},
#   {'agent': 'agente empático',
#    'message': "It sounds like you're feeling overwhelmed and in need of some relief.",
#    'neg': 0.0,
#    'neu': 0.265,
#    'pos': 0.735,
#    'compound': 0.743},
#   {'agent': 'agente intrigante',
#    'message': "Yes, exactly. I can't keep up with this situation.",
#    'neg': 0.0,
#    'neu': 0.649,
#    'pos': 0.351,
#    'compound': 0.4019},
#   {'agent': 'agente empático',
#    'message': "It seems like you're also feeling a bit helpless and frustrated.",
#    'neg': 0.444,
#    'neu': 0.278,
#    'pos': 0.278,
#    'compound': -0.5267},
#   {'agent': 'agente intrigante',
#    'message': "Yes, I feel like I've tried everything and nothing is working.",
#    'neg': 0.0,
#    'neu': 0.536,
#    'pos': 0.464,
#    'compound': 0.6369},
#   {'agent': 'agente empático',
#    'message': 'It must be really hard to see your son in distress and not know how to help.',
#    'neg': 0.398,
#    'neu': 0.391,
#    'pos': 0.211,
#    'compound': -0.3384},
#   {'agent': 'agente intrigante',
#    'message': 'It breaks my heart to hear him cry and not be able to soothe him.',
#    'neg': 0.323,
#    'neu': 0.417,
#    'pos': 0.26,
#    'compound': -0.1531},
#   {'agent': 'agente empático',
#    'message': "It sounds like you're experiencing a lot of empathy for your son's emotions.",
#    'neg': 0.0,
#    'neu': 0.762,
#    'pos': 0.238,
#    'compound': 0.3612}],
#  [{'agent': 'agente intrigante',
#    'message': "I can’t concentrate on my studies. Every five minutes, I pick up my cell phone to see if there's anything new. ",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente empático',
#    'message': 'I notice that you are apprehensive about not being able to study and disappointed with your lack of focus. And that?',
#    'neg': 0.519,
#    'neu': 0.481,
#    'pos': 0.0,
#    'compound': -0.6597},
#   {'agent': 'agente intrigante',
#    'message': "Yes, that way I won’t pass the year. And it's true, they're disappointed in me too.",
#    'neg': 0.228,
#    'neu': 0.368,
#    'pos': 0.404,
#    'compound': 0.34},
#   {'agent': 'agente empático',
#    'message': 'If you could be less distracted, would that meet your desire for efficiency and safety? ',
#    'neg': 0.167,
#    'neu': 0.278,
#    'pos': 0.556,
#    'compound': 0.6808},
#   {'agent': 'agente intrigante',
#    'message': 'That would help a lot, yes.',
#    'neg': 0.0,
#    'neu': 0.27,
#    'pos': 0.73,
#    'compound': 0.6597},
#   {'agent': 'agente empático',
#    'message': "It seems like you're feeling overwhelmed by the pressure to perform well in your studies. ",
#    'neg': 0.163,
#    'neu': 0.296,
#    'pos': 0.541,
#    'compound': 0.4767},
#   {'agent': 'agente intrigante',
#    'message': "Yes, I feel a lot of pressure to succeed and meet everyone's expectations. ",
#    'neg': 0.156,
#    'neu': 0.426,
#    'pos': 0.418,
#    'compound': 0.5719},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you have a strong need for approval and validation from others. ',
#    'neg': 0.0,
#    'neu': 0.31,
#    'pos': 0.69,
#    'compound': 0.836},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I always seek recognition for my efforts and hard work. ',
#    'neg': 0.154,
#    'neu': 0.549,
#    'pos': 0.297,
#    'compound': 0.3182},
#   {'agent': 'agente empático',
#    'message': 'Maybe setting some boundaries with your phone and creating a study routine could help you focus better. ',
#    'neg': 0.0,
#    'neu': 0.506,
#    'pos': 0.494,
#    'compound': 0.7783},
#   {'agent': 'agente intrigante',
#    'message': "That's a good idea. I'll try to implement some new habits to improve my concentration. ",
#    'neg': 0.0,
#    'neu': 0.58,
#    'pos': 0.42,
#    'compound': 0.7003},
#   {'agent': 'agente empático',
#    'message': "It's important to take care of yourself and prioritize your well-being during stressful times. ",
#    'neg': 0.248,
#    'neu': 0.376,
#    'pos': 0.376,
#    'compound': 0.1779}],
#  [{'agent': 'agente intrigante',
#    'message': "I'm so relieved to have finished the project on time. It was a race against the clock. ",
#    'neg': 0.0,
#    'neu': 0.698,
#    'pos': 0.302,
#    'compound': 0.3818},
#   {'agent': 'agente empático',
#    'message': 'Wow, you must be feeling accomplished having met the deadline and satisfied with your ability to manage time. ',
#    'neg': 0.0,
#    'neu': 0.273,
#    'pos': 0.727,
#    'compound': 0.9062},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I was worried I wouldn’t make it. ',
#    'neg': 0.373,
#    'neu': 0.169,
#    'pos': 0.458,
#    'compound': 0.128},
#   {'agent': 'agente empático',
#    'message': 'So, this also touches on your need for confidence in your abilities and competence to overcome challenges. ',
#    'neg': 0.0,
#    'neu': 0.42,
#    'pos': 0.58,
#    'compound': 0.7096},
#   {'agent': 'agente intrigante',
#    'message': "Exactly, that's it.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente empático',
#    'message': 'It must have been quite stressful for you to have that weight on your shoulders.',
#    'neg': 0.473,
#    'neu': 0.527,
#    'pos': 0.0,
#    'compound': -0.5563},
#   {'agent': 'agente intrigante',
#    'message': 'Definitely, I was feeling a lot of pressure.',
#    'neg': 0.297,
#    'neu': 0.135,
#    'pos': 0.568,
#    'compound': 0.25},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you value meeting your commitments and expectations.',
#    'neg': 0.0,
#    'neu': 0.286,
#    'pos': 0.714,
#    'compound': 0.7579},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I always strive to do my best.',
#    'neg': 0.0,
#    'neu': 0.225,
#    'pos': 0.775,
#    'compound': 0.7845},
#   {'agent': 'agente empático',
#    'message': 'I can see that you have a strong sense of responsibility.',
#    'neg': 0.0,
#    'neu': 0.476,
#    'pos': 0.524,
#    'compound': 0.5106},
#   {'agent': 'agente intrigante',
#    'message': 'Thank you for acknowledging that.',
#    'neg': 0.0,
#    'neu': 0.286,
#    'pos': 0.714,
#    'compound': 0.3612},
#   {'agent': 'agente empático',
#    'message': "You're welcome, it's important to recognize your hard work and dedication.",
#    'neg': 0.125,
#    'neu': 0.446,
#    'pos': 0.429,
#    'compound': 0.5267}],
#  [{'agent': 'agente intrigante',
#    'message': "My son finally started walking. I'm so proud! ",
#    'neg': 0.0,
#    'neu': 0.596,
#    'pos': 0.404,
#    'compound': 0.5255},
#   {'agent': 'agente empático',
#    'message': 'How wonderful! You seem to be in awe of his achievements. ',
#    'neg': 0.0,
#    'neu': 0.429,
#    'pos': 0.571,
#    'compound': 0.6114},
#   {'agent': 'agente intrigante',
#    'message': "And I am. It's a big milestone. ",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente empático',
#    'message': 'This reflects your need to celebrate special moments and support his growth. ',
#    'neg': 0.0,
#    'neu': 0.204,
#    'pos': 0.796,
#    'compound': 0.8934},
#   {'agent': 'agente intrigante',
#    'message': 'Of course, it is very important to me.',
#    'neg': 0.0,
#    'neu': 0.357,
#    'pos': 0.643,
#    'compound': 0.2023},
#   {'agent': 'agente empático',
#    'message': 'I see how much joy and pride this brings you. ',
#    'neg': 0.0,
#    'neu': 0.326,
#    'pos': 0.674,
#    'compound': 0.7351},
#   {'agent': 'agente intrigante',
#    'message': "Yes, definitely. It's a big moment for our family. ",
#    'neg': 0.0,
#    'neu': 0.426,
#    'pos': 0.574,
#    'compound': 0.6597},
#   {'agent': 'agente empático',
#    'message': 'It must also show your need for connection and closeness with your son. ',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente intrigante',
#    'message': "Absolutely, it's a bonding experience for us. ",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente empático',
#    'message': "It's great that you're able to recognize and appreciate these moments. ",
#    'neg': 0.0,
#    'neu': 0.424,
#    'pos': 0.576,
#    'compound': 0.7783},
#   {'agent': 'agente intrigante',
#    'message': 'Thank you, it means a lot to me. ',
#    'neg': 0.0,
#    'neu': 0.444,
#    'pos': 0.556,
#    'compound': 0.3612},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you have a strong emotional connection with your son. ',
#    'neg': 0.0,
#    'neu': 0.288,
#    'pos': 0.712,
#    'compound': 0.7506}],
#  [{'agent': 'agente intrigante',
#    'message': 'I managed to solve that complicated problem at work today. ',
#    'neg': 0.318,
#    'neu': 0.471,
#    'pos': 0.212,
#    'compound': -0.2263},
#   {'agent': 'agente empático',
#    'message': 'Oops, you must be feeling very confident and also relieved to have found a solution. ',
#    'neg': 0.0,
#    'neu': 0.294,
#    'pos': 0.706,
#    'compound': 0.8225},
#   {'agent': 'agente intrigante',
#    'message': 'Actually, it was a big problem. ',
#    'neg': 0.574,
#    'neu': 0.426,
#    'pos': 0.0,
#    'compound': -0.4019},
#   {'agent': 'agente empático',
#    'message': 'This shows your need for effectiveness and to be recognized for your ability to solve problems. ',
#    'neg': 0.25,
#    'neu': 0.37,
#    'pos': 0.38,
#    'compound': 0.1027},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, that motivates me.',
#    'neg': 0.0,
#    'neu': 0.27,
#    'pos': 0.73,
#    'compound': 0.4019},
#   {'agent': 'agente empático',
#    'message': "It's great that you were able to tap into your strengths and tackle the problem head-on.",
#    'neg': 0.18,
#    'neu': 0.333,
#    'pos': 0.487,
#    'compound': 0.6808},
#   {'agent': 'agente intrigante',
#    'message': 'Thank you for acknowledging that. It feels good to be appreciated.',
#    'neg': 0.0,
#    'neu': 0.187,
#    'pos': 0.813,
#    'compound': 0.8271},
#   {'agent': 'agente empático',
#    'message': 'I can see how important recognition is to you in your work.',
#    'neg': 0.0,
#    'neu': 0.625,
#    'pos': 0.375,
#    'compound': 0.2023},
#   {'agent': 'agente intrigante',
#    'message': "Absolutely, it's one of the things that keeps me going.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you thrive on challenges and pushing yourself to find solutions.',
#    'neg': 0.0,
#    'neu': 0.396,
#    'pos': 0.604,
#    'compound': 0.6249},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I do enjoy a good challenge and the satisfaction of overcoming it.',
#    'neg': 0.0,
#    'neu': 0.071,
#    'pos': 0.929,
#    'compound': 0.9001},
#   {'agent': 'agente empático',
#    'message': "It's impressive how you can maintain that level of determination and focus.",
#    'neg': 0.0,
#    'neu': 0.4,
#    'pos': 0.6,
#    'compound': 0.7184}],
#  [{'agent': 'agente intrigante',
#    'message': 'I finally managed to save enough to buy my car. ',
#    'neg': 0.0,
#    'neu': 0.61,
#    'pos': 0.39,
#    'compound': 0.4939},
#   {'agent': 'agente empático',
#    'message': 'Congratulations! You must be feeling very accomplished and even admired by your own abilities. ',
#    'neg': 0.0,
#    'neu': 0.124,
#    'pos': 0.876,
#    'compound': 0.9215},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, it was a goal I pursued for a long time. ',
#    'neg': 0.0,
#    'neu': 0.597,
#    'pos': 0.403,
#    'compound': 0.4019},
#   {'agent': 'agente empático',
#    'message': 'So, this meets your need for autonomy and effectiveness in achieving personal goals. ',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente intrigante',
#    'message': 'Exactly, it’s an incredible feeling.',
#    'neg': 0.0,
#    'neu': 0.571,
#    'pos': 0.429,
#    'compound': 0.128},
#   {'agent': 'agente empático',
#    'message': 'I imagine that you are also feeling a sense of relief now that you have achieved this goal. ',
#    'neg': 0.0,
#    'neu': 0.521,
#    'pos': 0.479,
#    'compound': 0.5574},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, absolutely. It feels like a weight has been lifted off my shoulders. ',
#    'neg': 0.0,
#    'neu': 0.477,
#    'pos': 0.523,
#    'compound': 0.6682},
#   {'agent': 'agente empático',
#    'message': "It's important to acknowledge and celebrate your hard work paying off. ",
#    'neg': 0.128,
#    'neu': 0.367,
#    'pos': 0.505,
#    'compound': 0.6249},
#   {'agent': 'agente intrigante',
#    'message': 'Thank you, I appreciate your kind words. ',
#    'neg': 0.0,
#    'neu': 0.104,
#    'pos': 0.896,
#    'compound': 0.8225},
#   {'agent': 'agente empático',
#    'message': 'Enjoy this moment of success and remember that you are capable of reaching your goals. ',
#    'neg': 0.0,
#    'neu': 0.21,
#    'pos': 0.79,
#    'compound': 0.8834},
#   {'agent': 'agente intrigante',
#    'message': 'I will, thank you for reminding me of that. ',
#    'neg': 0.0,
#    'neu': 0.286,
#    'pos': 0.714,
#    'compound': 0.3612},
#   {'agent': 'agente empático',
#    'message': "You're welcome. I'm here to support and celebrate your accomplishments with you.",
#    'neg': 0.0,
#    'neu': 0.242,
#    'pos': 0.758,
#    'compound': 0.8555}],
#  [{'agent': 'agente intrigante',
#    'message': 'After months of practice, I played the piano in front of an audience for the first time. ',
#    'neg': 0.0,
#    'neu': 0.745,
#    'pos': 0.255,
#    'compound': 0.34},
#   {'agent': 'agente empático',
#    'message': 'This is fantastic! You must be feeling radiant and excited to share more of your talent. ',
#    'neg': 0.0,
#    'neu': 0.059,
#    'pos': 0.941,
#    'compound': 0.9312},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I was nervous, but it went well. ',
#    'neg': 0.266,
#    'neu': 0.127,
#    'pos': 0.608,
#    'compound': 0.4019},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you are seeking recognition and also want to challenge yourself to grow as a musician. ',
#    'neg': 0.0,
#    'neu': 0.541,
#    'pos': 0.459,
#    'compound': 0.4767},
#   {'agent': 'agente intrigante',
#    'message': 'That’s right, I want to continue improving myself.',
#    'neg': 0.0,
#    'neu': 0.328,
#    'pos': 0.672,
#    'compound': 0.4767},
#   {'agent': 'agente empático',
#    'message': "It's great that you have this passion for music and the courage to share your talent with others.",
#    'neg': 0.0,
#    'neu': 0.164,
#    'pos': 0.836,
#    'compound': 0.936},
#   {'agent': 'agente intrigante',
#    'message': 'Thank you, music means everything to me.',
#    'neg': 0.0,
#    'neu': 0.545,
#    'pos': 0.455,
#    'compound': 0.3612},
#   {'agent': 'agente empático',
#    'message': 'I can see that music is a big part of your identity and brings you a lot of joy.',
#    'neg': 0.0,
#    'neu': 0.648,
#    'pos': 0.352,
#    'compound': 0.5859},
#   {'agent': 'agente intrigante',
#    'message': "Definitely, it's my way of expressing myself and connecting with others.",
#    'neg': 0.0,
#    'neu': 0.649,
#    'pos': 0.351,
#    'compound': 0.4019},
#   {'agent': 'agente empático',
#    'message': "It's wonderful that you have found this creative outlet to express your emotions.",
#    'neg': 0.0,
#    'neu': 0.431,
#    'pos': 0.569,
#    'compound': 0.765},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, music helps me process my feelings and experiences in a unique way.',
#    'neg': 0.0,
#    'neu': 0.42,
#    'pos': 0.58,
#    'compound': 0.7096},
#   {'agent': 'agente empático',
#    'message': "It's amazing how art can have such a powerful impact on our emotional well-being.",
#    'neg': 0.0,
#    'neu': 0.328,
#    'pos': 0.672,
#    'compound': 0.802}],
#  [{'agent': 'agente intrigante',
#    'message': "I'm feeling so anxious about this job interview tomorrow. ",
#    'neg': 0.267,
#    'neu': 0.533,
#    'pos': 0.2,
#    'compound': -0.128},
#   {'agent': 'agente empático',
#    'message': 'You seem worried about the result and perhaps need more reassurance. And that? ',
#    'neg': 0.253,
#    'neu': 0.46,
#    'pos': 0.287,
#    'compound': 0.0772},
#   {'agent': 'agente intrigante',
#    'message': "Yes, I'm very insecure. ",
#    'neg': 0.431,
#    'neu': 0.154,
#    'pos': 0.415,
#    'compound': -0.0258},
#   {'agent': 'agente empático',
#    'message': 'Maybe you are looking for confidence and a little peace of mind to face this challenge. ',
#    'neg': 0.0,
#    'neu': 0.39,
#    'pos': 0.61,
#    'compound': 0.7787},
#   {'agent': 'agente intrigante',
#    'message': 'That would help a lot.',
#    'neg': 0.0,
#    'neu': 0.426,
#    'pos': 0.574,
#    'compound': 0.4019},
#   {'agent': 'agente empático',
#    'message': "It's completely understandable to feel that way before a big event like a job interview.",
#    'neg': 0.0,
#    'neu': 0.783,
#    'pos': 0.217,
#    'compound': 0.3612},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I just really want to make a good impression and get this opportunity.',
#    'neg': 0.0,
#    'neu': 0.198,
#    'pos': 0.802,
#    'compound': 0.8795},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you have a strong desire for success and validation in this situation.',
#    'neg': 0.0,
#    'neu': 0.197,
#    'pos': 0.803,
#    'compound': 0.9042},
#   {'agent': 'agente intrigante',
#    'message': "Absolutely. I've been working towards this for a long time and I really want it to pay off.",
#    'neg': 0.163,
#    'neu': 0.682,
#    'pos': 0.155,
#    'compound': -0.022},
#   {'agent': 'agente empático',
#    'message': "Your hard work and dedication are definitely shining through. It's important to acknowledge that.",
#    'neg': 0.128,
#    'neu': 0.459,
#    'pos': 0.413,
#    'compound': 0.4767},
#   {'agent': 'agente intrigante',
#    'message': 'Thank you, I appreciate you recognizing that. It means a lot.',
#    'neg': 0.0,
#    'neu': 0.366,
#    'pos': 0.634,
#    'compound': 0.6369},
#   {'agent': 'agente empático',
#    'message': "It's important to remember to believe in yourself and your abilities, even in moments of doubt.",
#    'neg': 0.216,
#    'neu': 0.431,
#    'pos': 0.353,
#    'compound': 0.1531}],
#  [{'agent': 'agente intrigante',
#    'message': "I can't stop thinking about the mistake I made at work. ",
#    'neg': 0.0,
#    'neu': 0.56,
#    'pos': 0.44,
#    'compound': 0.4449},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you are afraid of the consequences and need to understand why you did what you did. Am I right? ',
#    'neg': 0.0,
#    'neu': 0.706,
#    'pos': 0.294,
#    'compound': 0.3612},
#   {'agent': 'agente intrigante',
#    'message': 'Exactly, I wanted to understand what happened. ',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente empático',
#    'message': 'And this clarity would help you move forward and not make mistakes next time.',
#    'neg': 0.174,
#    'neu': 0.435,
#    'pos': 0.391,
#    'compound': 0.4588},
#   {'agent': 'agente intrigante',
#    'message': 'Yes definitely.',
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 1.0,
#    'compound': 0.6597},
#   {'agent': 'agente empático',
#    'message': "It's important to acknowledge that we all make mistakes sometimes.",
#    'neg': 0.293,
#    'neu': 0.488,
#    'pos': 0.22,
#    'compound': -0.1531},
#   {'agent': 'agente intrigante',
#    'message': "I appreciate your understanding. It's just hard not to dwell on it.",
#    'neg': 0.184,
#    'neu': 0.263,
#    'pos': 0.553,
#    'compound': 0.4215},
#   {'agent': 'agente empático',
#    'message': 'I understand, it can be tough to let go of those feelings.',
#    'neg': 0.25,
#    'neu': 0.5,
#    'pos': 0.25,
#    'compound': 0.0},
#   {'agent': 'agente intrigante',
#    'message': 'I feel like I let my team down.',
#    'neg': 0.0,
#    'neu': 0.545,
#    'pos': 0.455,
#    'compound': 0.3612},
#   {'agent': 'agente empático',
#    'message': "It's natural to feel that way, but remember that everyone makes mistakes.",
#    'neg': 0.22,
#    'neu': 0.55,
#    'pos': 0.229,
#    'compound': 0.0258},
#   {'agent': 'agente intrigante',
#    'message': 'Thanks for reminding me of that. It helps to talk about it.',
#    'neg': 0.0,
#    'neu': 0.263,
#    'pos': 0.737,
#    'compound': 0.6808},
#   {'agent': 'agente empático',
#    'message': "I'm glad I could offer some support. It's important to be kind to yourself during these times.",
#    'neg': 0.0,
#    'neu': 0.314,
#    'pos': 0.686,
#    'compound': 0.872}],
#  [{'agent': 'agente intrigante',
#    'message': 'I feel so alone since I moved to this new city. ',
#    'neg': 0.286,
#    'neu': 0.714,
#    'pos': 0.0,
#    'compound': -0.25},
#   {'agent': 'agente empático',
#    'message': 'Yes, connection and company must be needed. ',
#    'neg': 0.0,
#    'neu': 0.597,
#    'pos': 0.403,
#    'compound': 0.4019},
#   {'agent': 'agente intrigante',
#    'message': 'I miss having friends around. ',
#    'neg': 0.276,
#    'neu': 0.172,
#    'pos': 0.552,
#    'compound': 0.3818},
#   {'agent': 'agente empático',
#    'message': 'I also imagine a sense of community in your new environment. ',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente intrigante',
#    'message': 'That would definitely make a big difference.',
#    'neg': 0.0,
#    'neu': 0.597,
#    'pos': 0.403,
#    'compound': 0.4019},
#   {'agent': 'agente empático',
#    'message': "It sounds like you're craving a sense of belonging.",
#    'neg': 0.0,
#    'neu': 0.667,
#    'pos': 0.333,
#    'compound': 0.3612},
#   {'agent': 'agente intrigante',
#    'message': "Yes, exactly. I feel like I don't fit in here.",
#    'neg': 0.205,
#    'neu': 0.291,
#    'pos': 0.504,
#    'compound': 0.4749},
#   {'agent': 'agente empático',
#    'message': 'It must be tough to feel like an outsider.',
#    'neg': 0.214,
#    'neu': 0.429,
#    'pos': 0.357,
#    'compound': 0.25},
#   {'agent': 'agente intrigante',
#    'message': "It is. I thought moving would be exciting, but it's been harder than I expected.",
#    'neg': 0.0,
#    'neu': 0.652,
#    'pos': 0.348,
#    'compound': 0.4939},
#   {'agent': 'agente empático',
#    'message': 'Change can be really challenging, especially when it involves leaving a familiar support system behind.',
#    'neg': 0.0,
#    'neu': 0.635,
#    'pos': 0.365,
#    'compound': 0.5563},
#   {'agent': 'agente intrigante',
#    'message': "That's true. I didn't realize how much I depended on my friends back home.",
#    'neg': 0.0,
#    'neu': 0.538,
#    'pos': 0.462,
#    'compound': 0.7184},
#   {'agent': 'agente empático',
#    'message': "It's natural to feel that way. Transitioning to a new place takes time and effort.",
#    'neg': 0.0,
#    'neu': 0.783,
#    'pos': 0.217,
#    'compound': 0.3612}],
#  [{'agent': 'agente intrigante',
#    'message': "My mother is sick and I have to take care of her, but I also have to work. It's too much. ",
#    'neg': 0.264,
#    'neu': 0.48,
#    'pos': 0.256,
#    'compound': -0.0258},
#   {'agent': 'agente empático',
#    'message': 'You seem to be divided between responsibilities...',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente intrigante',
#    'message': "Yes, divided and tired. I'm overwhelmed. ",
#    'neg': 0.33,
#    'neu': 0.227,
#    'pos': 0.443,
#    'compound': 0.0},
#   {'agent': 'agente empático',
#    'message': 'Perhaps you are looking for balance and support to manage these demands. ',
#    'neg': 0.183,
#    'neu': 0.488,
#    'pos': 0.329,
#    'compound': 0.296},
#   {'agent': 'agente intrigante',
#    'message': 'That would be ideal.',
#    'neg': 0.0,
#    'neu': 0.227,
#    'pos': 0.773,
#    'compound': 0.5267},
#   {'agent': 'agente empático',
#    'message': "It's understandable that you feel overwhelmed with everything on your plate.",
#    'neg': 0.0,
#    'neu': 0.806,
#    'pos': 0.194,
#    'compound': 0.0516},
#   {'agent': 'agente intrigante',
#    'message': "Yes, it's a lot to handle all at once.",
#    'neg': 0.0,
#    'neu': 0.526,
#    'pos': 0.474,
#    'compound': 0.4019},
#   {'agent': 'agente empático',
#    'message': 'Have you considered seeking help or delegating some tasks to lighten your load?',
#    'neg': 0.0,
#    'neu': 0.69,
#    'pos': 0.31,
#    'compound': 0.4019},
#   {'agent': 'agente intrigante',
#    'message': "I have, but it's hard to find reliable help sometimes.",
#    'neg': 0.173,
#    'neu': 0.494,
#    'pos': 0.333,
#    'compound': 0.3182},
#   {'agent': 'agente empático',
#    'message': 'It must be difficult to juggle so many responsibilities.',
#    'neg': 0.385,
#    'neu': 0.615,
#    'pos': 0.0,
#    'compound': -0.3612},
#   {'agent': 'agente intrigante',
#    'message': "It really is. I feel like I'm being pulled in different directions.",
#    'neg': 0.0,
#    'neu': 0.683,
#    'pos': 0.317,
#    'compound': 0.4173},
#   {'agent': 'agente empático',
#    'message': "It's important to take care of yourself too during this challenging time.",
#    'neg': 0.0,
#    'neu': 0.312,
#    'pos': 0.688,
#    'compound': 0.6808}],
#  [{'agent': 'agente intrigante',
#    'message': "My partner and I have been arguing a lot lately. I'm frustrated. ",
#    'neg': 0.615,
#    'neu': 0.385,
#    'pos': 0.0,
#    'compound': -0.7506},
#   {'agent': 'agente empático',
#    'message': 'You seem to be feeling worn out and need harmony. Am I interpreting correctly? ',
#    'neg': 0.212,
#    'neu': 0.385,
#    'pos': 0.404,
#    'compound': 0.25},
#   {'agent': 'agente intrigante',
#    'message': 'Not just harmony, more reciprocity on his part. ',
#    'neg': 0.0,
#    'neu': 0.426,
#    'pos': 0.574,
#    'compound': 0.4019},
#   {'agent': 'agente empático',
#    'message': 'I understood. As if you wanted support to resolve this together. ',
#    'neg': 0.0,
#    'neu': 0.361,
#    'pos': 0.639,
#    'compound': 0.6486},
#   {'agent': 'agente intrigante',
#    'message': 'Exactly, that would help us sort things out.',
#    'neg': 0.0,
#    'neu': 0.597,
#    'pos': 0.403,
#    'compound': 0.4019},
#   {'agent': 'agente empático',
#    'message': "It sounds like you're looking for more collaboration and understanding in your relationship.",
#    'neg': 0.0,
#    'neu': 0.706,
#    'pos': 0.294,
#    'compound': 0.3612},
#   {'agent': 'agente intrigante',
#    'message': "Yes, that's it. I feel like I'm the only one making an effort to make things work.",
#    'neg': 0.0,
#    'neu': 0.634,
#    'pos': 0.366,
#    'compound': 0.6369},
#   {'agent': 'agente empático',
#    'message': "It must be tough feeling like you're carrying the weight of the relationship on your shoulders.",
#    'neg': 0.13,
#    'neu': 0.522,
#    'pos': 0.348,
#    'compound': 0.3612},
#   {'agent': 'agente intrigante',
#    'message': "It is, it's exhausting.",
#    'neg': 0.714,
#    'neu': 0.286,
#    'pos': 0.0,
#    'compound': -0.3612},
#   {'agent': 'agente empático',
#    'message': "Have you talked to your partner about how you're feeling?",
#    'neg': 0.0,
#    'neu': 0.667,
#    'pos': 0.333,
#    'compound': 0.128},
#   {'agent': 'agente intrigante',
#    'message': "I tried, but it seems like he's not really listening.",
#    'neg': 0.0,
#    'neu': 0.667,
#    'pos': 0.333,
#    'compound': 0.3612},
#   {'agent': 'agente empático',
#    'message': "It's important for both partners to feel heard and understood in a relationship.",
#    'neg': 0.0,
#    'neu': 0.769,
#    'pos': 0.231,
#    'compound': 0.2023}],
#  [{'agent': 'agente intrigante',
#    'message': "My dog \u200b\u200bran away and I'm so worried. ",
#    'neg': 0.355,
#    'neu': 0.645,
#    'pos': 0.0,
#    'compound': -0.296},
#   {'agent': 'agente empático',
#    'message': 'You seem to be distressed by the lack of information about how he is doing.',
#    'neg': 0.718,
#    'neu': 0.282,
#    'pos': 0.0,
#    'compound': -0.6249},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I feel desperate thinking about the possibilities. ',
#    'neg': 0.287,
#    'neu': 0.375,
#    'pos': 0.338,
#    'compound': 0.1027},
#   {'agent': 'agente empático',
#    'message': 'Yes, I wish I could hope that he is okay and have some company to help find him, is that it? ',
#    'neg': 0.0,
#    'neu': 0.189,
#    'pos': 0.811,
#    'compound': 0.8979},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, any help would be welcome.',
#    'neg': 0.0,
#    'neu': 0.106,
#    'pos': 0.894,
#    'compound': 0.8126},
#   {'agent': 'agente empático',
#    'message': 'It must be really hard not knowing where your dog is. ',
#    'neg': 0.297,
#    'neu': 0.703,
#    'pos': 0.0,
#    'compound': -0.1761},
#   {'agent': 'agente intrigante',
#    'message': 'It is, I keep imagining all sorts of scenarios in my head. ',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente empático',
#    'message': 'It makes sense that you feel overwhelmed by all the possibilities. ',
#    'neg': 0.0,
#    'neu': 0.769,
#    'pos': 0.231,
#    'compound': 0.0516},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I just want him to be safe and come back home. ',
#    'neg': 0.0,
#    'neu': 0.303,
#    'pos': 0.697,
#    'compound': 0.7096},
#   {'agent': 'agente empático',
#    'message': 'I understand, your dog is like family to you. ',
#    'neg': 0.0,
#    'neu': 0.545,
#    'pos': 0.455,
#    'compound': 0.3612},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, he is my best friend. ',
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 1.0,
#    'compound': 0.8779},
#   {'agent': 'agente empático',
#    'message': 'I hope you find him soon and everything turns out okay.',
#    'neg': 0.0,
#    'neu': 0.455,
#    'pos': 0.545,
#    'compound': 0.5859}],
#  [{'agent': 'agente intrigante',
#    'message': "I'm trying to lose weight, but it's so hard to stick to the diet. ",
#    'neg': 0.406,
#    'neu': 0.594,
#    'pos': 0.0,
#    'compound': -0.4767},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you are frustrated and need more motivation. That makes sense? ',
#    'neg': 0.276,
#    'neu': 0.325,
#    'pos': 0.398,
#    'compound': 0.128},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, it’s a constant battle. ',
#    'neg': 0.413,
#    'neu': 0.159,
#    'pos': 0.429,
#    'compound': 0.0258},
#   {'agent': 'agente empático',
#    'message': 'I also understand that you are trying to take care of something very important, which is health, but that you need more efficiency. ',
#    'neg': 0.0,
#    'neu': 0.483,
#    'pos': 0.517,
#    'compound': 0.7579},
#   {'agent': 'agente intrigante',
#    'message': "That's right.",
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente empático',
#    'message': 'Have you tried finding a support system to help you stay motivated during this process?',
#    'neg': 0.0,
#    'neu': 0.373,
#    'pos': 0.627,
#    'compound': 0.8126},
#   {'agent': 'agente intrigante',
#    'message': "I have tried, but sometimes it feels like no one understands the struggle I'm going through.",
#    'neg': 0.195,
#    'neu': 0.593,
#    'pos': 0.212,
#    'compound': 0.0516},
#   {'agent': 'agente empático',
#    'message': "It must be tough feeling like you're going through this alone.",
#    'neg': 0.333,
#    'neu': 0.286,
#    'pos': 0.381,
#    'compound': 0.128},
#   {'agent': 'agente intrigante',
#    'message': 'It is. Sometimes I just wish someone would truly listen and give me the encouragement I need.',
#    'neg': 0.0,
#    'neu': 0.417,
#    'pos': 0.583,
#    'compound': 0.8126},
#   {'agent': 'agente empático',
#    'message': "It's important to feel supported and understood when you're going through a challenging journey like this.",
#    'neg': 0.0,
#    'neu': 0.423,
#    'pos': 0.577,
#    'compound': 0.7351},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, it really is. I guess I just need to keep pushing through and find my own inner strength.',
#    'neg': 0.0,
#    'neu': 0.543,
#    'pos': 0.457,
#    'compound': 0.7096},
#   {'agent': 'agente empático',
#    'message': "Remember that it's okay to ask for help when you need it. You don't have to do this alone.",
#    'neg': 0.0,
#    'neu': 0.441,
#    'pos': 0.559,
#    'compound': 0.6531}],
#  [{'agent': 'agente intrigante',
#    'message': 'I feel like my teenage son is moving away from me. ',
#    'neg': 0.0,
#    'neu': 0.667,
#    'pos': 0.333,
#    'compound': 0.3612},
#   {'agent': 'agente empático',
#    'message': 'You seem to be worried about your connection and even his safety. And that? ',
#    'neg': 0.275,
#    'neu': 0.375,
#    'pos': 0.35,
#    'compound': 0.1531},
#   {'agent': 'agente intrigante',
#    'message': "Yes, I feel like I'm losing my son. ",
#    'neg': 0.241,
#    'neu': 0.278,
#    'pos': 0.481,
#    'compound': 0.3818},
#   {'agent': 'agente empático',
#    'message': 'I also notice a need for clarity as to why this happened and how it could change.',
#    'neg': 0.0,
#    'neu': 0.69,
#    'pos': 0.31,
#    'compound': 0.4019},
#   {'agent': 'agente intrigante',
#    'message': 'This is very important to me.',
#    'neg': 0.0,
#    'neu': 0.0,
#    'pos': 1.0,
#    'compound': 0.2023},
#   {'agent': 'agente empático',
#    'message': 'I can imagine how difficult it must be for you to feel that distance growing.',
#    'neg': 0.305,
#    'neu': 0.488,
#    'pos': 0.207,
#    'compound': -0.2023},
#   {'agent': 'agente intrigante',
#    'message': "It's heartbreaking, really. I just want to understand what's going on.",
#    'neg': 0.313,
#    'neu': 0.521,
#    'pos': 0.166,
#    'compound': -0.3415},
#   {'agent': 'agente empático',
#    'message': "Have you tried talking to your son about how you're feeling?",
#    'neg': 0.0,
#    'neu': 0.727,
#    'pos': 0.273,
#    'compound': 0.128},
#   {'agent': 'agente intrigante',
#    'message': "I have, but he just shuts down and doesn't want to talk.",
#    'neg': 0.289,
#    'neu': 0.711,
#    'pos': 0.0,
#    'compound': -0.0572},
#   {'agent': 'agente empático',
#    'message': 'That must be so frustrating for you.',
#    'neg': 0.744,
#    'neu': 0.256,
#    'pos': 0.0,
#    'compound': -0.4404},
#   {'agent': 'agente intrigante',
#    'message': 'It really is. I just want to know how to help him.',
#    'neg': 0.0,
#    'neu': 0.305,
#    'pos': 0.695,
#    'compound': 0.5509},
#   {'agent': 'agente empático',
#    'message': "Maybe he's going through a tough time and doesn't know how to express it.",
#    'neg': 0.176,
#    'neu': 0.824,
#    'pos': 0.0,
#    'compound': -0.128}],
#  [{'agent': 'agente intrigante',
#    'message': "I'm feeling pressured when deciding to choose a career. ",
#    'neg': 0.257,
#    'neu': 0.541,
#    'pos': 0.203,
#    'compound': -0.1027},
#   {'agent': 'agente empático',
#    'message': 'Behind the "pressure" I notice that there is a feeling of loneliness and lack of company and even more understanding of the options. ',
#    'neg': 0.435,
#    'neu': 0.476,
#    'pos': 0.089,
#    'compound': -0.7003},
#   {'agent': 'agente intrigante',
#    'message': 'No, I already have all the information. I want to be able to decide alone and with more time.',
#    'neg': 0.241,
#    'neu': 0.602,
#    'pos': 0.157,
#    'compound': -0.1779},
#   {'agent': 'agente empático',
#    'message': 'Maybe you are looking for space and autonomy to make the right choice for you.',
#    'neg': 0.0,
#    'neu': 1.0,
#    'pos': 0.0,
#    'compound': 0.0},
#   {'agent': 'agente intrigante',
#    'message': 'Yes, I need that: space and autonomy.',
#    'neg': 0.0,
#    'neu': 0.526,
#    'pos': 0.474,
#    'compound': 0.4019},
#   {'agent': 'agente empático',
#    'message': 'It sounds like you value independence and taking your time to make important decisions.',
#    'neg': 0.0,
#    'neu': 0.472,
#    'pos': 0.528,
#    'compound': 0.6908},
#   {'agent': 'agente intrigante',
#    'message': "Yes, exactly. I want to make sure I'm choosing the right path for myself.",
#    'neg': 0.0,
#    'neu': 0.488,
#    'pos': 0.512,
#    'compound': 0.6486},
#   {'agent': 'agente empático',
#    'message': "It's important to prioritize your own needs and desires when making career decisions.",
#    'neg': 0.0,
#    'neu': 0.571,
#    'pos': 0.429,
#    'compound': 0.5423},
#   {'agent': 'agente intrigante',
#    'message': 'I agree. I just hope I can make the right choice in the end.',
#    'neg': 0.0,
#    'neu': 0.426,
#    'pos': 0.574,
#    'compound': 0.6597},
#   {'agent': 'agente empático',
#    'message': "It's okay to feel uncertain, but trust that you have the ability to make the best decision for yourself.",
#    'neg': 0.123,
#    'neu': 0.223,
#    'pos': 0.654,
#    'compound': 0.8591},
#   {'agent': 'agente intrigante',
#    'message': 'Thank you for reassuring me. I really appreciate your support.',
#    'neg': 0.0,
#    'neu': 0.082,
#    'pos': 0.918,
#    'compound': 0.8799},
#   {'agent': 'agente empático',
#    'message': "Of course, I'm here to listen and help however I can.",
#    'neg': 0.0,
#    'neu': 0.597,
#    'pos': 0.403,
#    'compound': 0.4019}]]

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as np

for agent in ['agente intrigante', 'agente empático']:
    for category in ['pos', 'neg', 'neu', 'compound']:

        data = np.array([[d[category] for d in x if d['agent'] == agent] for x in processed_texts])
        for x in data:
            plt.plot(range(len(x)), x, '#ccc')
        data = data.T

        # x values are just indices
        x = np.arange(len(data))

        avg_y = np.mean(data, axis=1)
        min_y = np.min(data, axis=1)
        max_y = np.max(data, axis=1)

        # calculate polynomial fit (degree = 1 for linear)
        coef_avg = np.polyfit(x, avg_y, 1)
        coef_min = np.polyfit(x, min_y, 1)
        coef_max = np.polyfit(x, max_y, 1)

        poly1d_fn_avg = np.poly1d(coef_avg)
        poly1d_fn_min = np.poly1d(coef_min) 
        poly1d_fn_max = np.poly1d(coef_max)


        legends = [Line2D([0], [0], color='#ccc', label='Dados'),
                   Line2D([0], [0], color='blue', label='Tendência dos máximos', linestyle='--'),
                   Line2D([0], [0], color='red', label='Tendência da média', linestyle='--'),
                   Line2D([0], [0], color='blue', label='Tendência dos mínimos', linestyle='--'),
        ]

        plt.plot(x, poly1d_fn_avg(x), '--r')
        plt.plot(x, poly1d_fn_min(x), '--b')
        plt.plot(x, poly1d_fn_max(x), '--b')

        plt.yticks(np.arange(-1, 1.1, 0.2))

        plt.xlabel('Número da interação')
        plt.ylabel('Valor')
        plt.title(f'Propriedades do {agent}:{category}')
        plt.legend(handles=legends)
        plt.show()
